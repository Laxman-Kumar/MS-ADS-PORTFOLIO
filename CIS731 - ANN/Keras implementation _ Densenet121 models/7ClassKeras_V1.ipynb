# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the train and test folders
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

#creating test and train folders for 7 classes selected at random from the dataset
generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=7)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=7)

# %%
#creating a list to store the selected classes
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#displaying the selected classes
classtolabel
# Out:
# {0: 'chicken_quesadilla',
#  1: 'pulled_pork_sandwich',
#  2: 'tiramisu',
#  3: 'sashimi',
#  4: 'panna_cotta',
#  5: 'pancakes',
#  6: 'fish_and_chips'}

# %%
#calculating number of images in the train and test folders respectively.
#performing data augmentation on the train and test images
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 5250 images belonging to 7 classes.
# Found 1750 images belonging to 7 classes.

# %%
#Building the CNN model. adding CNN layers, Max pooling layers and Dropout layers and 1 Dense layer 
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(7, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 2.1933 - accuracy: 0.1343
# Epoch 00001: val_loss improved from inf to 2.04538, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 2.1933 - accuracy: 0.1343 - val_loss: 2.0454 - val_accuracy: 0.1497
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 2.0339 - accuracy: 0.1450
# Epoch 00002: val_loss improved from 2.04538 to 2.02392, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 2.0339 - accuracy: 0.1450 - val_loss: 2.0239 - val_accuracy: 0.1510
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 2.0201 - accuracy: 0.1454
# Epoch 00003: val_loss improved from 2.02392 to 2.01322, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 2.0201 - accuracy: 0.1454 - val_loss: 2.0132 - val_accuracy: 0.1706
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 2.0107 - accuracy: 0.1576
# Epoch 00004: val_loss improved from 2.01322 to 2.00756, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 2.0107 - accuracy: 0.1576 - val_loss: 2.0076 - val_accuracy: 0.1432
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 2.0043 - accuracy: 0.1503
# Epoch 00005: val_loss improved from 2.00756 to 2.00274, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 2.0043 - accuracy: 0.1503 - val_loss: 2.0027 - val_accuracy: 0.1367
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9994 - accuracy: 0.1476
# Epoch 00006: val_loss improved from 2.00274 to 1.99267, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.9994 - accuracy: 0.1476 - val_loss: 1.9927 - val_accuracy: 0.1458
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9953 - accuracy: 0.1566
# Epoch 00007: val_loss improved from 1.99267 to 1.99181, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9953 - accuracy: 0.1566 - val_loss: 1.9918 - val_accuracy: 0.1641
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9883 - accuracy: 0.1606
# Epoch 00008: val_loss improved from 1.99181 to 1.98679, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.9883 - accuracy: 0.1606 - val_loss: 1.9868 - val_accuracy: 0.1693
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9822 - accuracy: 0.1532
# Epoch 00009: val_loss improved from 1.98679 to 1.97764, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.9822 - accuracy: 0.1532 - val_loss: 1.9776 - val_accuracy: 0.1966
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9804 - accuracy: 0.1784
# Epoch 00010: val_loss improved from 1.97764 to 1.97466, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.9804 - accuracy: 0.1784 - val_loss: 1.9747 - val_accuracy: 0.1680
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9829 - accuracy: 0.1392
# Epoch 00011: val_loss did not improve from 1.97466
# 36/35 [==============================] - 38s 1s/step - loss: 1.9829 - accuracy: 0.1392 - val_loss: 1.9782 - val_accuracy: 0.1380
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9749 - accuracy: 0.1658
# Epoch 00012: val_loss improved from 1.97466 to 1.97190, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9749 - accuracy: 0.1658 - val_loss: 1.9719 - val_accuracy: 0.1927
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9692 - accuracy: 0.1481
# Epoch 00013: val_loss improved from 1.97190 to 1.96961, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9692 - accuracy: 0.1481 - val_loss: 1.9696 - val_accuracy: 0.1536
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9693 - accuracy: 0.1723
# Epoch 00014: val_loss improved from 1.96961 to 1.96943, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.9693 - accuracy: 0.1723 - val_loss: 1.9694 - val_accuracy: 0.1549
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9709 - accuracy: 0.1543
# Epoch 00015: val_loss improved from 1.96943 to 1.96206, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.9709 - accuracy: 0.1543 - val_loss: 1.9621 - val_accuracy: 0.1823
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9655 - accuracy: 0.1619
# Epoch 00016: val_loss improved from 1.96206 to 1.95615, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.9655 - accuracy: 0.1619 - val_loss: 1.9562 - val_accuracy: 0.2135
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9590 - accuracy: 0.1780
# Epoch 00017: val_loss did not improve from 1.95615
# 36/35 [==============================] - 37s 1s/step - loss: 1.9590 - accuracy: 0.1780 - val_loss: 1.9659 - val_accuracy: 0.1510
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9553 - accuracy: 0.1740
# Epoch 00018: val_loss improved from 1.95615 to 1.95472, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.9553 - accuracy: 0.1740 - val_loss: 1.9547 - val_accuracy: 0.1836
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9487 - accuracy: 0.1853
# Epoch 00019: val_loss improved from 1.95472 to 1.93534, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9487 - accuracy: 0.1853 - val_loss: 1.9353 - val_accuracy: 0.1862
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9458 - accuracy: 0.1784
# Epoch 00020: val_loss did not improve from 1.93534
# 36/35 [==============================] - 37s 1s/step - loss: 1.9458 - accuracy: 0.1784 - val_loss: 1.9468 - val_accuracy: 0.1549
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9474 - accuracy: 0.1855
# Epoch 00021: val_loss did not improve from 1.93534
# 36/35 [==============================] - 36s 1s/step - loss: 1.9474 - accuracy: 0.1855 - val_loss: 1.9522 - val_accuracy: 0.1667
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9563 - accuracy: 0.1619
# Epoch 00022: val_loss did not improve from 1.93534
# 36/35 [==============================] - 37s 1s/step - loss: 1.9563 - accuracy: 0.1619 - val_loss: 1.9493 - val_accuracy: 0.1836
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9494 - accuracy: 0.1815
# Epoch 00023: val_loss did not improve from 1.93534
# 36/35 [==============================] - 36s 1s/step - loss: 1.9494 - accuracy: 0.1815 - val_loss: 1.9440 - val_accuracy: 0.1901
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9391 - accuracy: 0.1793
# Epoch 00024: val_loss improved from 1.93534 to 1.93116, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9391 - accuracy: 0.1793 - val_loss: 1.9312 - val_accuracy: 0.2135
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9403 - accuracy: 0.1923
# Epoch 00025: val_loss improved from 1.93116 to 1.93003, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9403 - accuracy: 0.1923 - val_loss: 1.9300 - val_accuracy: 0.2057
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9251 - accuracy: 0.1931
# Epoch 00026: val_loss improved from 1.93003 to 1.89475, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.9251 - accuracy: 0.1931 - val_loss: 1.8948 - val_accuracy: 0.2018
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9078 - accuracy: 0.2070
# Epoch 00027: val_loss improved from 1.89475 to 1.87353, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.9078 - accuracy: 0.2070 - val_loss: 1.8735 - val_accuracy: 0.2057
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9069 - accuracy: 0.2087
# Epoch 00028: val_loss did not improve from 1.87353
# 36/35 [==============================] - 37s 1s/step - loss: 1.9069 - accuracy: 0.2087 - val_loss: 1.8756 - val_accuracy: 0.2344
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8748 - accuracy: 0.2203
# Epoch 00029: val_loss improved from 1.87353 to 1.86098, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.8748 - accuracy: 0.2203 - val_loss: 1.8610 - val_accuracy: 0.2044
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8713 - accuracy: 0.2257
# Epoch 00030: val_loss improved from 1.86098 to 1.85005, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.8713 - accuracy: 0.2257 - val_loss: 1.8501 - val_accuracy: 0.2174
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8473 - accuracy: 0.2513
# Epoch 00031: val_loss did not improve from 1.85005
# 36/35 [==============================] - 37s 1s/step - loss: 1.8473 - accuracy: 0.2513 - val_loss: 1.8611 - val_accuracy: 0.2135
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8550 - accuracy: 0.2310
# Epoch 00032: val_loss improved from 1.85005 to 1.84839, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.8550 - accuracy: 0.2310 - val_loss: 1.8484 - val_accuracy: 0.2292
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8440 - accuracy: 0.2574
# Epoch 00033: val_loss did not improve from 1.84839
# 36/35 [==============================] - 37s 1s/step - loss: 1.8440 - accuracy: 0.2574 - val_loss: 1.8665 - val_accuracy: 0.2253
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8558 - accuracy: 0.2266
# Epoch 00034: val_loss improved from 1.84839 to 1.81411, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.8558 - accuracy: 0.2266 - val_loss: 1.8141 - val_accuracy: 0.2630
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8106 - accuracy: 0.2609
# Epoch 00035: val_loss did not improve from 1.81411
# 36/35 [==============================] - 38s 1s/step - loss: 1.8106 - accuracy: 0.2609 - val_loss: 1.8481 - val_accuracy: 0.2201
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8312 - accuracy: 0.2565
# Epoch 00036: val_loss did not improve from 1.81411
# 36/35 [==============================] - 39s 1s/step - loss: 1.8312 - accuracy: 0.2565 - val_loss: 1.8207 - val_accuracy: 0.2695
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7838 - accuracy: 0.2609
# Epoch 00037: val_loss did not improve from 1.81411
# 36/35 [==============================] - 37s 1s/step - loss: 1.7838 - accuracy: 0.2609 - val_loss: 1.8476 - val_accuracy: 0.2643
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8221 - accuracy: 0.2587
# Epoch 00038: val_loss improved from 1.81411 to 1.77111, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.8221 - accuracy: 0.2587 - val_loss: 1.7711 - val_accuracy: 0.2760
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7975 - accuracy: 0.2806
# Epoch 00039: val_loss did not improve from 1.77111
# 36/35 [==============================] - 37s 1s/step - loss: 1.7975 - accuracy: 0.2806 - val_loss: 1.7784 - val_accuracy: 0.2747
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7894 - accuracy: 0.2786
# Epoch 00040: val_loss did not improve from 1.77111
# 36/35 [==============================] - 37s 1s/step - loss: 1.7894 - accuracy: 0.2786 - val_loss: 1.7850 - val_accuracy: 0.2695
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7996 - accuracy: 0.2756
# Epoch 00041: val_loss did not improve from 1.77111
# 36/35 [==============================] - 37s 1s/step - loss: 1.7996 - accuracy: 0.2756 - val_loss: 1.8129 - val_accuracy: 0.2513
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7846 - accuracy: 0.2791
# Epoch 00042: val_loss improved from 1.77111 to 1.75148, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.7846 - accuracy: 0.2791 - val_loss: 1.7515 - val_accuracy: 0.2956
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7230 - accuracy: 0.3186
# Epoch 00043: val_loss improved from 1.75148 to 1.70734, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.7230 - accuracy: 0.3186 - val_loss: 1.7073 - val_accuracy: 0.2969
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7385 - accuracy: 0.3160
# Epoch 00044: val_loss improved from 1.70734 to 1.70490, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.7385 - accuracy: 0.3160 - val_loss: 1.7049 - val_accuracy: 0.3008
# Epoch 45/200
# 35/35 [============================>.] - ETA: 0s - loss: 1.7099 - accuracy: 0.3089
# Epoch 00045: val_loss did not improve from 1.70490
# 36/35 [==============================] - 37s 1s/step - loss: 1.7103 - accuracy: 0.3091 - val_loss: 1.7289 - val_accuracy: 0.2904
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7704 - accuracy: 0.2868
# Epoch 00046: val_loss improved from 1.70490 to 1.67403, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.7704 - accuracy: 0.2868 - val_loss: 1.6740 - val_accuracy: 0.3203
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7112 - accuracy: 0.3203
# Epoch 00047: val_loss did not improve from 1.67403
# 36/35 [==============================] - 38s 1s/step - loss: 1.7112 - accuracy: 0.3203 - val_loss: 1.6803 - val_accuracy: 0.3177
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6594 - accuracy: 0.3498
# Epoch 00048: val_loss did not improve from 1.67403
# 36/35 [==============================] - 38s 1s/step - loss: 1.6594 - accuracy: 0.3498 - val_loss: 1.7449 - val_accuracy: 0.2852
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6725 - accuracy: 0.3299
# Epoch 00049: val_loss improved from 1.67403 to 1.65131, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.6725 - accuracy: 0.3299 - val_loss: 1.6513 - val_accuracy: 0.3398
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6980 - accuracy: 0.3260
# Epoch 00050: val_loss did not improve from 1.65131
# 36/35 [==============================] - 38s 1s/step - loss: 1.6980 - accuracy: 0.3260 - val_loss: 1.6791 - val_accuracy: 0.3242
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6859 - accuracy: 0.3318
# Epoch 00051: val_loss did not improve from 1.65131
# 36/35 [==============================] - 37s 1s/step - loss: 1.6859 - accuracy: 0.3318 - val_loss: 1.6557 - val_accuracy: 0.3594
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7261 - accuracy: 0.3100
# Epoch 00052: val_loss did not improve from 1.65131
# 36/35 [==============================] - 38s 1s/step - loss: 1.7261 - accuracy: 0.3100 - val_loss: 1.8392 - val_accuracy: 0.2174
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7215 - accuracy: 0.3243
# Epoch 00053: val_loss did not improve from 1.65131
# 36/35 [==============================] - 37s 1s/step - loss: 1.7215 - accuracy: 0.3243 - val_loss: 1.6981 - val_accuracy: 0.3164
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6518 - accuracy: 0.3494
# Epoch 00054: val_loss did not improve from 1.65131
# 36/35 [==============================] - 38s 1s/step - loss: 1.6518 - accuracy: 0.3494 - val_loss: 1.7177 - val_accuracy: 0.3216
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6101 - accuracy: 0.3694
# Epoch 00055: val_loss improved from 1.65131 to 1.63842, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.6101 - accuracy: 0.3694 - val_loss: 1.6384 - val_accuracy: 0.3385
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6069 - accuracy: 0.3655
# Epoch 00056: val_loss did not improve from 1.63842
# 36/35 [==============================] - 39s 1s/step - loss: 1.6069 - accuracy: 0.3655 - val_loss: 1.6524 - val_accuracy: 0.3385
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5600 - accuracy: 0.3971
# Epoch 00057: val_loss improved from 1.63842 to 1.63046, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.5600 - accuracy: 0.3971 - val_loss: 1.6305 - val_accuracy: 0.3385
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5882 - accuracy: 0.3858
# Epoch 00058: val_loss improved from 1.63046 to 1.55838, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.5882 - accuracy: 0.3858 - val_loss: 1.5584 - val_accuracy: 0.3958
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5485 - accuracy: 0.4054
# Epoch 00059: val_loss improved from 1.55838 to 1.47471, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.5485 - accuracy: 0.4054 - val_loss: 1.4747 - val_accuracy: 0.4336
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5432 - accuracy: 0.3919
# Epoch 00060: val_loss did not improve from 1.47471
# 36/35 [==============================] - 38s 1s/step - loss: 1.5432 - accuracy: 0.3919 - val_loss: 1.6125 - val_accuracy: 0.3620
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5122 - accuracy: 0.4171
# Epoch 00061: val_loss did not improve from 1.47471
# 36/35 [==============================] - 39s 1s/step - loss: 1.5122 - accuracy: 0.4171 - val_loss: 1.5725 - val_accuracy: 0.4036
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5224 - accuracy: 0.4282
# Epoch 00062: val_loss did not improve from 1.47471
# 36/35 [==============================] - 38s 1s/step - loss: 1.5224 - accuracy: 0.4282 - val_loss: 1.5648 - val_accuracy: 0.3997
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5324 - accuracy: 0.4076
# Epoch 00063: val_loss did not improve from 1.47471
# 36/35 [==============================] - 39s 1s/step - loss: 1.5324 - accuracy: 0.4076 - val_loss: 1.6303 - val_accuracy: 0.3867
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5014 - accuracy: 0.4240
# Epoch 00064: val_loss did not improve from 1.47471
# 36/35 [==============================] - 39s 1s/step - loss: 1.5014 - accuracy: 0.4240 - val_loss: 1.5317 - val_accuracy: 0.4349
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5085 - accuracy: 0.4175
# Epoch 00065: val_loss did not improve from 1.47471
# 36/35 [==============================] - 37s 1s/step - loss: 1.5085 - accuracy: 0.4175 - val_loss: 1.5992 - val_accuracy: 0.3789
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5229 - accuracy: 0.4023
# Epoch 00066: val_loss did not improve from 1.47471
# 36/35 [==============================] - 37s 1s/step - loss: 1.5229 - accuracy: 0.4023 - val_loss: 1.5960 - val_accuracy: 0.3607
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4526 - accuracy: 0.4393
# Epoch 00067: val_loss did not improve from 1.47471
# 36/35 [==============================] - 38s 1s/step - loss: 1.4526 - accuracy: 0.4393 - val_loss: 1.5853 - val_accuracy: 0.3815
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4313 - accuracy: 0.4492
# Epoch 00068: val_loss did not improve from 1.47471
# 36/35 [==============================] - 38s 1s/step - loss: 1.4313 - accuracy: 0.4492 - val_loss: 1.6025 - val_accuracy: 0.3789
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4829 - accuracy: 0.4246
# Epoch 00069: val_loss did not improve from 1.47471
# 36/35 [==============================] - 37s 1s/step - loss: 1.4829 - accuracy: 0.4246 - val_loss: 1.5016 - val_accuracy: 0.4323
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4389 - accuracy: 0.4436
# Epoch 00070: val_loss improved from 1.47471 to 1.44995, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.4389 - accuracy: 0.4436 - val_loss: 1.4499 - val_accuracy: 0.4349
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3712 - accuracy: 0.4644
# Epoch 00071: val_loss did not improve from 1.44995
# 36/35 [==============================] - 37s 1s/step - loss: 1.3712 - accuracy: 0.4644 - val_loss: 1.5063 - val_accuracy: 0.4128
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3693 - accuracy: 0.4661
# Epoch 00072: val_loss did not improve from 1.44995
# 36/35 [==============================] - 39s 1s/step - loss: 1.3693 - accuracy: 0.4661 - val_loss: 1.5087 - val_accuracy: 0.4297
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3894 - accuracy: 0.4652
# Epoch 00073: val_loss did not improve from 1.44995
# 36/35 [==============================] - 38s 1s/step - loss: 1.3894 - accuracy: 0.4652 - val_loss: 1.5037 - val_accuracy: 0.4453
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3654 - accuracy: 0.4792
# Epoch 00074: val_loss did not improve from 1.44995
# 36/35 [==============================] - 39s 1s/step - loss: 1.3654 - accuracy: 0.4792 - val_loss: 1.5417 - val_accuracy: 0.4128
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3579 - accuracy: 0.4822
# Epoch 00075: val_loss did not improve from 1.44995
# 36/35 [==============================] - 39s 1s/step - loss: 1.3579 - accuracy: 0.4822 - val_loss: 1.6021 - val_accuracy: 0.3971
# Epoch 76/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3558 - accuracy: 0.4805
# Epoch 00076: val_loss did not improve from 1.44995
# 36/35 [==============================] - 40s 1s/step - loss: 1.3558 - accuracy: 0.4805 - val_loss: 1.4612 - val_accuracy: 0.4714
# Epoch 77/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3422 - accuracy: 0.4931
# Epoch 00077: val_loss did not improve from 1.44995
# 36/35 [==============================] - 38s 1s/step - loss: 1.3422 - accuracy: 0.4931 - val_loss: 1.5280 - val_accuracy: 0.4258
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3035 - accuracy: 0.5094
# Epoch 00078: val_loss improved from 1.44995 to 1.38507, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.3035 - accuracy: 0.5094 - val_loss: 1.3851 - val_accuracy: 0.4714
# Epoch 79/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3530 - accuracy: 0.4808
# Epoch 00079: val_loss did not improve from 1.38507
# 36/35 [==============================] - 37s 1s/step - loss: 1.3530 - accuracy: 0.4808 - val_loss: 1.4820 - val_accuracy: 0.4466
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2997 - accuracy: 0.5026
# Epoch 00080: val_loss did not improve from 1.38507
# 36/35 [==============================] - 37s 1s/step - loss: 1.2997 - accuracy: 0.5026 - val_loss: 1.4880 - val_accuracy: 0.4297
# Epoch 81/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3340 - accuracy: 0.4871
# Epoch 00081: val_loss did not improve from 1.38507
# 36/35 [==============================] - 37s 1s/step - loss: 1.3340 - accuracy: 0.4871 - val_loss: 1.6517 - val_accuracy: 0.3867
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4024 - accuracy: 0.4688
# Epoch 00082: val_loss improved from 1.38507 to 1.35246, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.4024 - accuracy: 0.4688 - val_loss: 1.3525 - val_accuracy: 0.5039
# Epoch 83/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3141 - accuracy: 0.5000
# Epoch 00083: val_loss did not improve from 1.35246
# 36/35 [==============================] - 38s 1s/step - loss: 1.3141 - accuracy: 0.5000 - val_loss: 1.4465 - val_accuracy: 0.4284
# Epoch 84/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3214 - accuracy: 0.4920
# Epoch 00084: val_loss did not improve from 1.35246
# 36/35 [==============================] - 38s 1s/step - loss: 1.3214 - accuracy: 0.4920 - val_loss: 1.3754 - val_accuracy: 0.4674
# Epoch 85/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3120 - accuracy: 0.4915
# Epoch 00085: val_loss did not improve from 1.35246
# 36/35 [==============================] - 37s 1s/step - loss: 1.3120 - accuracy: 0.4915 - val_loss: 1.4730 - val_accuracy: 0.4492
# Epoch 86/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2578 - accuracy: 0.5234
# Epoch 00086: val_loss did not improve from 1.35246
# 36/35 [==============================] - 39s 1s/step - loss: 1.2578 - accuracy: 0.5234 - val_loss: 1.4990 - val_accuracy: 0.4505
# Epoch 87/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2613 - accuracy: 0.5304
# Epoch 00087: val_loss did not improve from 1.35246
# 36/35 [==============================] - 39s 1s/step - loss: 1.2613 - accuracy: 0.5304 - val_loss: 1.4034 - val_accuracy: 0.4440
# Epoch 88/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3063 - accuracy: 0.5169
# Epoch 00088: val_loss did not improve from 1.35246
# 36/35 [==============================] - 37s 1s/step - loss: 1.3063 - accuracy: 0.5169 - val_loss: 1.4468 - val_accuracy: 0.4622
# Epoch 89/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2903 - accuracy: 0.5187
# Epoch 00089: val_loss did not improve from 1.35246
# 36/35 [==============================] - 38s 1s/step - loss: 1.2903 - accuracy: 0.5187 - val_loss: 1.5100 - val_accuracy: 0.4310
# Epoch 90/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2731 - accuracy: 0.5334
# Epoch 00090: val_loss did not improve from 1.35246
# 36/35 [==============================] - 39s 1s/step - loss: 1.2731 - accuracy: 0.5334 - val_loss: 1.4221 - val_accuracy: 0.4635
# Epoch 91/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2574 - accuracy: 0.5317
# Epoch 00091: val_loss did not improve from 1.35246
# 36/35 [==============================] - 36s 1s/step - loss: 1.2574 - accuracy: 0.5317 - val_loss: 1.4494 - val_accuracy: 0.4635
# Epoch 92/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2743 - accuracy: 0.5205
# Epoch 00092: val_loss did not improve from 1.35246
# 36/35 [==============================] - 39s 1s/step - loss: 1.2743 - accuracy: 0.5205 - val_loss: 1.5665 - val_accuracy: 0.4271
# Epoch 93/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2771 - accuracy: 0.5236
# Epoch 00093: val_loss did not improve from 1.35246
# 36/35 [==============================] - 37s 1s/step - loss: 1.2771 - accuracy: 0.5236 - val_loss: 1.3828 - val_accuracy: 0.4727
# Epoch 94/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2155 - accuracy: 0.5395
# Epoch 00094: val_loss improved from 1.35246 to 1.32926, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.2155 - accuracy: 0.5395 - val_loss: 1.3293 - val_accuracy: 0.4922
# Epoch 95/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1948 - accuracy: 0.5582
# Epoch 00095: val_loss did not improve from 1.32926
# 36/35 [==============================] - 40s 1s/step - loss: 1.1948 - accuracy: 0.5582 - val_loss: 1.4053 - val_accuracy: 0.4909
# Epoch 96/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2632 - accuracy: 0.5272
# Epoch 00096: val_loss did not improve from 1.32926
# 36/35 [==============================] - 39s 1s/step - loss: 1.2632 - accuracy: 0.5272 - val_loss: 1.3884 - val_accuracy: 0.4753
# Epoch 97/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2531 - accuracy: 0.5277
# Epoch 00097: val_loss improved from 1.32926 to 1.28665, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.2531 - accuracy: 0.5277 - val_loss: 1.2866 - val_accuracy: 0.5365
# Epoch 98/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2686 - accuracy: 0.5360
# Epoch 00098: val_loss did not improve from 1.28665
# 36/35 [==============================] - 38s 1s/step - loss: 1.2686 - accuracy: 0.5360 - val_loss: 1.3987 - val_accuracy: 0.4714
# Epoch 99/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1834 - accuracy: 0.5616
# Epoch 00099: val_loss did not improve from 1.28665
# 36/35 [==============================] - 38s 1s/step - loss: 1.1834 - accuracy: 0.5616 - val_loss: 1.4152 - val_accuracy: 0.4792
# Epoch 100/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1652 - accuracy: 0.5734
# Epoch 00100: val_loss did not improve from 1.28665
# 36/35 [==============================] - 38s 1s/step - loss: 1.1652 - accuracy: 0.5734 - val_loss: 1.3703 - val_accuracy: 0.4857
# Epoch 101/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1794 - accuracy: 0.5577
# Epoch 00101: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.1794 - accuracy: 0.5577 - val_loss: 1.3915 - val_accuracy: 0.4922
# Epoch 102/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1934 - accuracy: 0.5540
# Epoch 00102: val_loss did not improve from 1.28665
# 36/35 [==============================] - 42s 1s/step - loss: 1.1934 - accuracy: 0.5540 - val_loss: 1.3183 - val_accuracy: 0.5039
# Epoch 103/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1805 - accuracy: 0.5624
# Epoch 00103: val_loss did not improve from 1.28665
# 36/35 [==============================] - 40s 1s/step - loss: 1.1805 - accuracy: 0.5624 - val_loss: 1.3757 - val_accuracy: 0.4922
# Epoch 104/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1346 - accuracy: 0.5786
# Epoch 00104: val_loss did not improve from 1.28665
# 36/35 [==============================] - 42s 1s/step - loss: 1.1346 - accuracy: 0.5786 - val_loss: 1.3952 - val_accuracy: 0.4935
# Epoch 105/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2088 - accuracy: 0.5397
# Epoch 00105: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.2088 - accuracy: 0.5397 - val_loss: 1.3605 - val_accuracy: 0.5104
# Epoch 106/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1971 - accuracy: 0.5530
# Epoch 00106: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.1971 - accuracy: 0.5530 - val_loss: 1.3513 - val_accuracy: 0.5078
# Epoch 107/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1443 - accuracy: 0.5729
# Epoch 00107: val_loss did not improve from 1.28665
# 36/35 [==============================] - 40s 1s/step - loss: 1.1443 - accuracy: 0.5729 - val_loss: 1.3332 - val_accuracy: 0.5143
# Epoch 108/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1677 - accuracy: 0.5616
# Epoch 00108: val_loss did not improve from 1.28665
# 36/35 [==============================] - 41s 1s/step - loss: 1.1677 - accuracy: 0.5616 - val_loss: 1.3878 - val_accuracy: 0.4909
# Epoch 109/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1784 - accuracy: 0.5586
# Epoch 00109: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.1784 - accuracy: 0.5586 - val_loss: 1.3531 - val_accuracy: 0.5143
# Epoch 110/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1175 - accuracy: 0.5963
# Epoch 00110: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.1175 - accuracy: 0.5963 - val_loss: 1.4017 - val_accuracy: 0.4922
# Epoch 111/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1365 - accuracy: 0.5705
# Epoch 00111: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.1365 - accuracy: 0.5705 - val_loss: 1.4984 - val_accuracy: 0.4622
# Epoch 112/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1389 - accuracy: 0.5686
# Epoch 00112: val_loss did not improve from 1.28665
# 36/35 [==============================] - 39s 1s/step - loss: 1.1389 - accuracy: 0.5686 - val_loss: 1.3600 - val_accuracy: 0.5182
# Epoch 113/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1354 - accuracy: 0.5616
# Epoch 00113: val_loss did not improve from 1.28665
# 36/35 [==============================] - 38s 1s/step - loss: 1.1354 - accuracy: 0.5616 - val_loss: 1.4396 - val_accuracy: 0.4740
# Epoch 114/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1218 - accuracy: 0.5745
# Epoch 00114: val_loss did not improve from 1.28665
# 36/35 [==============================] - 38s 1s/step - loss: 1.1218 - accuracy: 0.5745 - val_loss: 1.4003 - val_accuracy: 0.5026
# Epoch 115/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1058 - accuracy: 0.5825
# Epoch 00115: val_loss improved from 1.28665 to 1.28104, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.1058 - accuracy: 0.5825 - val_loss: 1.2810 - val_accuracy: 0.5117
# Epoch 116/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1155 - accuracy: 0.5859
# Epoch 00116: val_loss did not improve from 1.28104
# 36/35 [==============================] - 39s 1s/step - loss: 1.1155 - accuracy: 0.5859 - val_loss: 1.4783 - val_accuracy: 0.4674
# Epoch 117/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1092 - accuracy: 0.5968
# Epoch 00117: val_loss did not improve from 1.28104
# 36/35 [==============================] - 39s 1s/step - loss: 1.1092 - accuracy: 0.5968 - val_loss: 1.4327 - val_accuracy: 0.4844

# %%
#Plotting accuracy
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 1750 images belonging to 7 classes.

# %%
#calculating test accuracy score
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 42.2%

# %%
#labeling sequence of the 7 classes
list(classtolabel.keys())
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
#plotting confusion matrix
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
