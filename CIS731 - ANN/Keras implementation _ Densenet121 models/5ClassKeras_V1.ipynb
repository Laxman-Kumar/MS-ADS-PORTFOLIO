# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the data
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=5)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=5)

# %%
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#listing the 3 selected classes at random
classtolabel
# Out:
# {0: 'cannoli', 1: 'escargots', 2: 'red_velvet_cake', 3: 'ravioli', 4: 'steak'}

# %%
#performing data augmentation on train and test images
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 3750 images belonging to 5 classes.
# Found 1250 images belonging to 5 classes.

# %%
#preparing the model
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(5, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
#creating the model
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7591 - accuracy: 0.2072
# Epoch 00001: val_loss improved from inf to 1.67710, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.7591 - accuracy: 0.2072 - val_loss: 1.6771 - val_accuracy: 0.2253
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6636 - accuracy: 0.2239
# Epoch 00002: val_loss improved from 1.67710 to 1.65817, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.6636 - accuracy: 0.2239 - val_loss: 1.6582 - val_accuracy: 0.2161
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6265 - accuracy: 0.2413
# Epoch 00003: val_loss improved from 1.65817 to 1.57863, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.6265 - accuracy: 0.2413 - val_loss: 1.5786 - val_accuracy: 0.2799
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6377 - accuracy: 0.2204
# Epoch 00004: val_loss did not improve from 1.57863
# 36/35 [==============================] - 41s 1s/step - loss: 1.6377 - accuracy: 0.2204 - val_loss: 1.6074 - val_accuracy: 0.2096
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5408 - accuracy: 0.3104
# Epoch 00005: val_loss improved from 1.57863 to 1.44956, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.5408 - accuracy: 0.3104 - val_loss: 1.4496 - val_accuracy: 0.3750
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4652 - accuracy: 0.3582
# Epoch 00006: val_loss did not improve from 1.44956
# 36/35 [==============================] - 42s 1s/step - loss: 1.4652 - accuracy: 0.3582 - val_loss: 1.4640 - val_accuracy: 0.3529
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4137 - accuracy: 0.3942
# Epoch 00007: val_loss improved from 1.44956 to 1.33536, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.4137 - accuracy: 0.3942 - val_loss: 1.3354 - val_accuracy: 0.4570
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3810 - accuracy: 0.4171
# Epoch 00008: val_loss improved from 1.33536 to 1.31926, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 1.3810 - accuracy: 0.4171 - val_loss: 1.3193 - val_accuracy: 0.4401
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3392 - accuracy: 0.4410
# Epoch 00009: val_loss improved from 1.31926 to 1.30587, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.3392 - accuracy: 0.4410 - val_loss: 1.3059 - val_accuracy: 0.4622
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3362 - accuracy: 0.4475
# Epoch 00010: val_loss improved from 1.30587 to 1.25304, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.3362 - accuracy: 0.4475 - val_loss: 1.2530 - val_accuracy: 0.5104
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2967 - accuracy: 0.4536
# Epoch 00011: val_loss improved from 1.25304 to 1.18840, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 1.2967 - accuracy: 0.4536 - val_loss: 1.1884 - val_accuracy: 0.5143
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2529 - accuracy: 0.4851
# Epoch 00012: val_loss improved from 1.18840 to 1.13618, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.2529 - accuracy: 0.4851 - val_loss: 1.1362 - val_accuracy: 0.5404
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2437 - accuracy: 0.4996
# Epoch 00013: val_loss did not improve from 1.13618
# 36/35 [==============================] - 41s 1s/step - loss: 1.2437 - accuracy: 0.4996 - val_loss: 1.1644 - val_accuracy: 0.5352
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2084 - accuracy: 0.5079
# Epoch 00014: val_loss did not improve from 1.13618
# 36/35 [==============================] - 41s 1s/step - loss: 1.2084 - accuracy: 0.5079 - val_loss: 1.1594 - val_accuracy: 0.5352
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1824 - accuracy: 0.5272
# Epoch 00015: val_loss improved from 1.13618 to 1.06845, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.1824 - accuracy: 0.5272 - val_loss: 1.0684 - val_accuracy: 0.5664
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1672 - accuracy: 0.5316
# Epoch 00016: val_loss did not improve from 1.06845
# 36/35 [==============================] - 40s 1s/step - loss: 1.1672 - accuracy: 0.5316 - val_loss: 1.1286 - val_accuracy: 0.5417
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1595 - accuracy: 0.5456
# Epoch 00017: val_loss improved from 1.06845 to 1.04504, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.1595 - accuracy: 0.5456 - val_loss: 1.0450 - val_accuracy: 0.5677
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1364 - accuracy: 0.5469
# Epoch 00018: val_loss did not improve from 1.04504
# 36/35 [==============================] - 42s 1s/step - loss: 1.1364 - accuracy: 0.5469 - val_loss: 1.1333 - val_accuracy: 0.5794
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1047 - accuracy: 0.5694
# Epoch 00019: val_loss improved from 1.04504 to 0.99258, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.1047 - accuracy: 0.5694 - val_loss: 0.9926 - val_accuracy: 0.6224
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0813 - accuracy: 0.5642
# Epoch 00020: val_loss did not improve from 0.99258
# 36/35 [==============================] - 41s 1s/step - loss: 1.0813 - accuracy: 0.5642 - val_loss: 1.0294 - val_accuracy: 0.6172
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1229 - accuracy: 0.5599
# Epoch 00021: val_loss did not improve from 0.99258
# 36/35 [==============================] - 42s 1s/step - loss: 1.1229 - accuracy: 0.5599 - val_loss: 1.0071 - val_accuracy: 0.6328
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0519 - accuracy: 0.5894
# Epoch 00022: val_loss did not improve from 0.99258
# 36/35 [==============================] - 41s 1s/step - loss: 1.0519 - accuracy: 0.5894 - val_loss: 0.9935 - val_accuracy: 0.6328
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.5983
# Epoch 00023: val_loss did not improve from 0.99258
# 36/35 [==============================] - 40s 1s/step - loss: 1.0571 - accuracy: 0.5983 - val_loss: 1.0118 - val_accuracy: 0.6185
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0161 - accuracy: 0.6163
# Epoch 00024: val_loss improved from 0.99258 to 0.89195, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.0161 - accuracy: 0.6163 - val_loss: 0.8919 - val_accuracy: 0.6797
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0436 - accuracy: 0.5977
# Epoch 00025: val_loss did not improve from 0.89195
# 36/35 [==============================] - 42s 1s/step - loss: 1.0436 - accuracy: 0.5977 - val_loss: 0.9603 - val_accuracy: 0.6432
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9908 - accuracy: 0.6280
# Epoch 00026: val_loss did not improve from 0.89195
# 36/35 [==============================] - 41s 1s/step - loss: 0.9908 - accuracy: 0.6280 - val_loss: 0.9203 - val_accuracy: 0.6641
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9497 - accuracy: 0.6405
# Epoch 00027: val_loss did not improve from 0.89195
# 36/35 [==============================] - 42s 1s/step - loss: 0.9497 - accuracy: 0.6405 - val_loss: 0.9106 - val_accuracy: 0.6406
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9598 - accuracy: 0.6308
# Epoch 00028: val_loss did not improve from 0.89195
# 36/35 [==============================] - 41s 1s/step - loss: 0.9598 - accuracy: 0.6308 - val_loss: 1.0021 - val_accuracy: 0.6146
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9706 - accuracy: 0.6260
# Epoch 00029: val_loss improved from 0.89195 to 0.84136, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.9706 - accuracy: 0.6260 - val_loss: 0.8414 - val_accuracy: 0.7135
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9455 - accuracy: 0.6365
# Epoch 00030: val_loss did not improve from 0.84136
# 36/35 [==============================] - 41s 1s/step - loss: 0.9455 - accuracy: 0.6365 - val_loss: 0.8709 - val_accuracy: 0.6797
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9481 - accuracy: 0.6493
# Epoch 00031: val_loss did not improve from 0.84136
# 36/35 [==============================] - 42s 1s/step - loss: 0.9481 - accuracy: 0.6493 - val_loss: 0.8894 - val_accuracy: 0.6719
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8938 - accuracy: 0.6536
# Epoch 00032: val_loss did not improve from 0.84136
# 36/35 [==============================] - 42s 1s/step - loss: 0.8938 - accuracy: 0.6536 - val_loss: 0.8897 - val_accuracy: 0.6784
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8926 - accuracy: 0.6598
# Epoch 00033: val_loss improved from 0.84136 to 0.81737, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.8926 - accuracy: 0.6598 - val_loss: 0.8174 - val_accuracy: 0.7044
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8901 - accuracy: 0.6703
# Epoch 00034: val_loss did not improve from 0.81737
# 36/35 [==============================] - 41s 1s/step - loss: 0.8901 - accuracy: 0.6703 - val_loss: 0.8826 - val_accuracy: 0.6771
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8730 - accuracy: 0.6703
# Epoch 00035: val_loss did not improve from 0.81737
# 36/35 [==============================] - 41s 1s/step - loss: 0.8730 - accuracy: 0.6703 - val_loss: 0.8246 - val_accuracy: 0.6992
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8549 - accuracy: 0.6879
# Epoch 00036: val_loss improved from 0.81737 to 0.81229, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.8549 - accuracy: 0.6879 - val_loss: 0.8123 - val_accuracy: 0.6966
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9065 - accuracy: 0.6637
# Epoch 00037: val_loss did not improve from 0.81229
# 36/35 [==============================] - 41s 1s/step - loss: 0.9065 - accuracy: 0.6637 - val_loss: 0.8683 - val_accuracy: 0.6888
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8587 - accuracy: 0.6797
# Epoch 00038: val_loss improved from 0.81229 to 0.80370, saving model to model.hdf5
# 36/35 [==============================] - 45s 1s/step - loss: 0.8587 - accuracy: 0.6797 - val_loss: 0.8037 - val_accuracy: 0.7109
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8540 - accuracy: 0.6752
# Epoch 00039: val_loss improved from 0.80370 to 0.74176, saving model to model.hdf5
# 36/35 [==============================] - 45s 1s/step - loss: 0.8540 - accuracy: 0.6752 - val_loss: 0.7418 - val_accuracy: 0.7253
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8083 - accuracy: 0.6980
# Epoch 00040: val_loss did not improve from 0.74176
# 36/35 [==============================] - 41s 1s/step - loss: 0.8083 - accuracy: 0.6980 - val_loss: 0.7607 - val_accuracy: 0.7370
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7797 - accuracy: 0.7131
# Epoch 00041: val_loss improved from 0.74176 to 0.73196, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.7797 - accuracy: 0.7131 - val_loss: 0.7320 - val_accuracy: 0.7409
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.7057
# Epoch 00042: val_loss did not improve from 0.73196
# 36/35 [==============================] - 43s 1s/step - loss: 0.7986 - accuracy: 0.7057 - val_loss: 0.7765 - val_accuracy: 0.7135
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7826 - accuracy: 0.7083
# Epoch 00043: val_loss did not improve from 0.73196
# 36/35 [==============================] - 42s 1s/step - loss: 0.7826 - accuracy: 0.7083 - val_loss: 0.8131 - val_accuracy: 0.6875
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7801 - accuracy: 0.7079
# Epoch 00044: val_loss improved from 0.73196 to 0.72175, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.7801 - accuracy: 0.7079 - val_loss: 0.7218 - val_accuracy: 0.7253
# Epoch 45/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7913 - accuracy: 0.7050
# Epoch 00045: val_loss did not improve from 0.72175
# 36/35 [==============================] - 41s 1s/step - loss: 0.7913 - accuracy: 0.7050 - val_loss: 0.7436 - val_accuracy: 0.7188
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7584 - accuracy: 0.7191
# Epoch 00046: val_loss did not improve from 0.72175
# 36/35 [==============================] - 41s 1s/step - loss: 0.7584 - accuracy: 0.7191 - val_loss: 0.7800 - val_accuracy: 0.7070
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7888 - accuracy: 0.7059
# Epoch 00047: val_loss improved from 0.72175 to 0.69797, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 0.7888 - accuracy: 0.7059 - val_loss: 0.6980 - val_accuracy: 0.7422
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7396 - accuracy: 0.7292
# Epoch 00048: val_loss did not improve from 0.69797
# 36/35 [==============================] - 41s 1s/step - loss: 0.7396 - accuracy: 0.7292 - val_loss: 0.7009 - val_accuracy: 0.7305
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7744 - accuracy: 0.7116
# Epoch 00049: val_loss did not improve from 0.69797
# 36/35 [==============================] - 41s 1s/step - loss: 0.7744 - accuracy: 0.7116 - val_loss: 0.7152 - val_accuracy: 0.7435
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7330 - accuracy: 0.7179
# Epoch 00050: val_loss improved from 0.69797 to 0.65415, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.7330 - accuracy: 0.7179 - val_loss: 0.6542 - val_accuracy: 0.7760
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7151 - accuracy: 0.7283
# Epoch 00051: val_loss did not improve from 0.65415
# 36/35 [==============================] - 42s 1s/step - loss: 0.7151 - accuracy: 0.7283 - val_loss: 0.7133 - val_accuracy: 0.7526
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7184 - accuracy: 0.7487
# Epoch 00052: val_loss did not improve from 0.65415
# 36/35 [==============================] - 43s 1s/step - loss: 0.7184 - accuracy: 0.7487 - val_loss: 0.7064 - val_accuracy: 0.7513
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.7436
# Epoch 00053: val_loss did not improve from 0.65415
# 36/35 [==============================] - 42s 1s/step - loss: 0.7217 - accuracy: 0.7436 - val_loss: 0.7278 - val_accuracy: 0.7513
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.7480
# Epoch 00054: val_loss did not improve from 0.65415
# 36/35 [==============================] - 41s 1s/step - loss: 0.6947 - accuracy: 0.7480 - val_loss: 0.6969 - val_accuracy: 0.7526
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7202 - accuracy: 0.7445
# Epoch 00055: val_loss did not improve from 0.65415
# 36/35 [==============================] - 42s 1s/step - loss: 0.7202 - accuracy: 0.7445 - val_loss: 0.7076 - val_accuracy: 0.7539
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7054 - accuracy: 0.7366
# Epoch 00056: val_loss did not improve from 0.65415
# 36/35 [==============================] - 41s 1s/step - loss: 0.7054 - accuracy: 0.7366 - val_loss: 0.6809 - val_accuracy: 0.7565
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6808 - accuracy: 0.7550
# Epoch 00057: val_loss did not improve from 0.65415
# 36/35 [==============================] - 41s 1s/step - loss: 0.6808 - accuracy: 0.7550 - val_loss: 0.6953 - val_accuracy: 0.7435
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.7383
# Epoch 00058: val_loss did not improve from 0.65415
# 36/35 [==============================] - 41s 1s/step - loss: 0.7023 - accuracy: 0.7383 - val_loss: 0.7411 - val_accuracy: 0.7448
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6491 - accuracy: 0.7600
# Epoch 00059: val_loss did not improve from 0.65415
# 36/35 [==============================] - 41s 1s/step - loss: 0.6491 - accuracy: 0.7600 - val_loss: 0.6991 - val_accuracy: 0.7487
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.7587
# Epoch 00060: val_loss improved from 0.65415 to 0.64740, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.6445 - accuracy: 0.7587 - val_loss: 0.6474 - val_accuracy: 0.7799
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6644 - accuracy: 0.7594
# Epoch 00061: val_loss did not improve from 0.64740
# 36/35 [==============================] - 41s 1s/step - loss: 0.6644 - accuracy: 0.7594 - val_loss: 0.7537 - val_accuracy: 0.7292
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6678 - accuracy: 0.7574
# Epoch 00062: val_loss improved from 0.64740 to 0.59555, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.6678 - accuracy: 0.7574 - val_loss: 0.5956 - val_accuracy: 0.7904
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6583 - accuracy: 0.7656
# Epoch 00063: val_loss did not improve from 0.59555
# 36/35 [==============================] - 44s 1s/step - loss: 0.6583 - accuracy: 0.7656 - val_loss: 0.6591 - val_accuracy: 0.7617
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.7691
# Epoch 00064: val_loss did not improve from 0.59555
# 36/35 [==============================] - 46s 1s/step - loss: 0.6358 - accuracy: 0.7691 - val_loss: 0.6547 - val_accuracy: 0.7526
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6145 - accuracy: 0.7735
# Epoch 00065: val_loss improved from 0.59555 to 0.59291, saving model to model.hdf5
# 36/35 [==============================] - 45s 1s/step - loss: 0.6145 - accuracy: 0.7735 - val_loss: 0.5929 - val_accuracy: 0.7930
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6987 - accuracy: 0.7493
# Epoch 00066: val_loss did not improve from 0.59291
# 36/35 [==============================] - 46s 1s/step - loss: 0.6987 - accuracy: 0.7493 - val_loss: 0.7489 - val_accuracy: 0.7435
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6161 - accuracy: 0.7801
# Epoch 00067: val_loss did not improve from 0.59291
# 36/35 [==============================] - 45s 1s/step - loss: 0.6161 - accuracy: 0.7801 - val_loss: 0.6518 - val_accuracy: 0.7760
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6026 - accuracy: 0.7805
# Epoch 00068: val_loss did not improve from 0.59291
# 36/35 [==============================] - 46s 1s/step - loss: 0.6026 - accuracy: 0.7805 - val_loss: 0.6295 - val_accuracy: 0.7956
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5680 - accuracy: 0.7919
# Epoch 00069: val_loss did not improve from 0.59291
# 36/35 [==============================] - 46s 1s/step - loss: 0.5680 - accuracy: 0.7919 - val_loss: 0.6737 - val_accuracy: 0.7643
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6323 - accuracy: 0.7786
# Epoch 00070: val_loss did not improve from 0.59291
# 36/35 [==============================] - 46s 1s/step - loss: 0.6323 - accuracy: 0.7786 - val_loss: 0.6855 - val_accuracy: 0.7552
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5931 - accuracy: 0.7834
# Epoch 00071: val_loss did not improve from 0.59291
# 36/35 [==============================] - 48s 1s/step - loss: 0.5931 - accuracy: 0.7834 - val_loss: 0.6873 - val_accuracy: 0.7669
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5871 - accuracy: 0.7801
# Epoch 00072: val_loss did not improve from 0.59291
# 36/35 [==============================] - 47s 1s/step - loss: 0.5871 - accuracy: 0.7801 - val_loss: 0.6757 - val_accuracy: 0.7852
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5619 - accuracy: 0.8003
# Epoch 00073: val_loss did not improve from 0.59291
# 36/35 [==============================] - 48s 1s/step - loss: 0.5619 - accuracy: 0.8003 - val_loss: 0.6674 - val_accuracy: 0.7643
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6099 - accuracy: 0.7709
# Epoch 00074: val_loss did not improve from 0.59291
# 36/35 [==============================] - 47s 1s/step - loss: 0.6099 - accuracy: 0.7709 - val_loss: 0.6232 - val_accuracy: 0.7865
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5489 - accuracy: 0.7994
# Epoch 00075: val_loss did not improve from 0.59291
# 36/35 [==============================] - 47s 1s/step - loss: 0.5489 - accuracy: 0.7994 - val_loss: 0.7040 - val_accuracy: 0.7747
# Epoch 76/200
# 36/35 [==============================] - ETA: -1s - loss: 0.5495 - accuracy: 0.7912
# Epoch 00076: val_loss did not improve from 0.59291
# 36/35 [==============================] - 48s 1s/step - loss: 0.5495 - accuracy: 0.7912 - val_loss: 0.6339 - val_accuracy: 0.7904
# Epoch 77/200
# 36/35 [==============================] - ETA: -1s - loss: 0.5062 - accuracy: 0.8152
# Epoch 00077: val_loss did not improve from 0.59291
# 36/35 [==============================] - 48s 1s/step - loss: 0.5062 - accuracy: 0.8152 - val_loss: 0.6034 - val_accuracy: 0.7891
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5151 - accuracy: 0.8142
# Epoch 00078: val_loss did not improve from 0.59291
# 36/35 [==============================] - 48s 1s/step - loss: 0.5151 - accuracy: 0.8142 - val_loss: 0.6403 - val_accuracy: 0.7786
# Epoch 79/200
# 36/35 [==============================] - ETA: -1s - loss: 0.5045 - accuracy: 0.8174
# Epoch 00079: val_loss did not improve from 0.59291
# 36/35 [==============================] - 49s 1s/step - loss: 0.5045 - accuracy: 0.8174 - val_loss: 0.6363 - val_accuracy: 0.7799
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5203 - accuracy: 0.8126
# Epoch 00080: val_loss did not improve from 0.59291
# 36/35 [==============================] - 47s 1s/step - loss: 0.5203 - accuracy: 0.8126 - val_loss: 0.6320 - val_accuracy: 0.7839
# Epoch 81/200
# 36/35 [==============================] - ETA: -1s - loss: 0.4904 - accuracy: 0.8290
# Epoch 00081: val_loss did not improve from 0.59291
# 36/35 [==============================] - 49s 1s/step - loss: 0.4904 - accuracy: 0.8290 - val_loss: 0.5976 - val_accuracy: 0.7943
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4683 - accuracy: 0.8284
# Epoch 00082: val_loss did not improve from 0.59291
# 36/35 [==============================] - 48s 1s/step - loss: 0.4683 - accuracy: 0.8284 - val_loss: 0.6150 - val_accuracy: 0.7969

# %%
#plotting the observations
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
#Generation of image with ImageDataGenerator
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 1250 images belonging to 5 classes.

# %%
#returning accuracy
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 79.7%

# %%
list(classtolabel.keys())
# Out:
# [0, 1, 2, 3, 4]

# %%
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1886f2901dc0> in <module>
# ----> 1 show_wrongest_label(x_test,y_test,y_pred_conf)
#
# <ipython-input-14-811cd163323b> in show_wrongest_label(x_test, y_test, y_pred_conf)
#      40                 n += 1
#      41
# ---> 42     display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)
#
# <ipython-input-14-811cd163323b> in display_errors(errors_index, img_errors, pred_errors, obs_errors)
#      31         for row in range(nrows):
#      32             for col in range(ncols):
# ---> 33                 error = errors_index[n]
#      34                 ax[row,col].imshow((img_errors[error]))
#      35                 #print(pred_errors[error])
#
# IndexError: index 13 is out of bounds for axis 0 with size 13
