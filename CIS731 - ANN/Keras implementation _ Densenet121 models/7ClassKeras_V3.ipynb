# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the train and test folders
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

#creating test and train folders for 7 classes selected at random from the dataset
generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=7)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=7)

# %%
#creating a list to store the selected classes
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#displaying the selected classes
classtolabel
# Out:
# {0: 'panna_cotta',
#  1: 'sashimi',
#  2: 'fish_and_chips',
#  3: 'pancakes',
#  4: 'tiramisu',
#  5: 'chicken_quesadilla',
#  6: 'pulled_pork_sandwich'}

# %%
#calculating number of images in the train and test folders respectively.
#performing data augmentation on the train and test images 
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 5250 images belonging to 7 classes.
# Found 1750 images belonging to 7 classes.

# %%
#Building the CNN model. adding CNN layers, Max pooling layers and Dropout layers and 1 Dense layer   
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(7, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 2.3595 - accuracy: 0.1494
# Epoch 00001: val_loss improved from inf to 2.04792, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 2.3595 - accuracy: 0.1494 - val_loss: 2.0479 - val_accuracy: 0.1510
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 2.0305 - accuracy: 0.1510
# Epoch 00002: val_loss improved from 2.04792 to 2.01502, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 2.0305 - accuracy: 0.1510 - val_loss: 2.0150 - val_accuracy: 0.1797
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9954 - accuracy: 0.2070
# Epoch 00003: val_loss improved from 2.01502 to 1.98872, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.9954 - accuracy: 0.2070 - val_loss: 1.9887 - val_accuracy: 0.2253
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9667 - accuracy: 0.2153
# Epoch 00004: val_loss improved from 1.98872 to 1.93138, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.9667 - accuracy: 0.2153 - val_loss: 1.9314 - val_accuracy: 0.2552
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9349 - accuracy: 0.2315
# Epoch 00005: val_loss did not improve from 1.93138
# 36/35 [==============================] - 37s 1s/step - loss: 1.9349 - accuracy: 0.2315 - val_loss: 1.9476 - val_accuracy: 0.2057
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9101 - accuracy: 0.2467
# Epoch 00006: val_loss improved from 1.93138 to 1.88017, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.9101 - accuracy: 0.2467 - val_loss: 1.8802 - val_accuracy: 0.2617
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8720 - accuracy: 0.2538
# Epoch 00007: val_loss did not improve from 1.88017
# 36/35 [==============================] - 37s 1s/step - loss: 1.8720 - accuracy: 0.2538 - val_loss: 1.9349 - val_accuracy: 0.2214
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8400 - accuracy: 0.2808
# Epoch 00008: val_loss did not improve from 1.88017
# 36/35 [==============================] - 38s 1s/step - loss: 1.8400 - accuracy: 0.2808 - val_loss: 2.0211 - val_accuracy: 0.1810
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8353 - accuracy: 0.2765
# Epoch 00009: val_loss improved from 1.88017 to 1.79850, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.8353 - accuracy: 0.2765 - val_loss: 1.7985 - val_accuracy: 0.2656
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7816 - accuracy: 0.3064
# Epoch 00010: val_loss did not improve from 1.79850
# 36/35 [==============================] - 37s 1s/step - loss: 1.7816 - accuracy: 0.3064 - val_loss: 1.8631 - val_accuracy: 0.2578
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8098 - accuracy: 0.2859
# Epoch 00011: val_loss did not improve from 1.79850
# 36/35 [==============================] - 36s 993ms/step - loss: 1.8098 - accuracy: 0.2859 - val_loss: 1.9205 - val_accuracy: 0.2266
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7426 - accuracy: 0.3212
# Epoch 00012: val_loss improved from 1.79850 to 1.77427, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.7426 - accuracy: 0.3212 - val_loss: 1.7743 - val_accuracy: 0.3047
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7605 - accuracy: 0.3153
# Epoch 00013: val_loss improved from 1.77427 to 1.70037, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.7605 - accuracy: 0.3153 - val_loss: 1.7004 - val_accuracy: 0.3190
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7090 - accuracy: 0.3472
# Epoch 00014: val_loss did not improve from 1.70037
# 36/35 [==============================] - 37s 1s/step - loss: 1.7090 - accuracy: 0.3472 - val_loss: 1.7241 - val_accuracy: 0.3268
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7110 - accuracy: 0.3350
# Epoch 00015: val_loss did not improve from 1.70037
# 36/35 [==============================] - 36s 1s/step - loss: 1.7110 - accuracy: 0.3350 - val_loss: 1.9075 - val_accuracy: 0.2500
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6853 - accuracy: 0.3477
# Epoch 00016: val_loss improved from 1.70037 to 1.69925, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.6853 - accuracy: 0.3477 - val_loss: 1.6993 - val_accuracy: 0.3307
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6366 - accuracy: 0.3628
# Epoch 00017: val_loss did not improve from 1.69925
# 36/35 [==============================] - 37s 1s/step - loss: 1.6366 - accuracy: 0.3628 - val_loss: 1.8116 - val_accuracy: 0.2878
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8000 - accuracy: 0.3109
# Epoch 00018: val_loss did not improve from 1.69925
# 36/35 [==============================] - 37s 1s/step - loss: 1.8000 - accuracy: 0.3109 - val_loss: 1.9703 - val_accuracy: 0.2344
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6810 - accuracy: 0.3481
# Epoch 00019: val_loss did not improve from 1.69925
# 36/35 [==============================] - 37s 1s/step - loss: 1.6810 - accuracy: 0.3481 - val_loss: 1.7309 - val_accuracy: 0.3372
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6534 - accuracy: 0.3481
# Epoch 00020: val_loss did not improve from 1.69925
# 36/35 [==============================] - 37s 1s/step - loss: 1.6534 - accuracy: 0.3481 - val_loss: 1.9063 - val_accuracy: 0.2500
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6181 - accuracy: 0.3715
# Epoch 00021: val_loss improved from 1.69925 to 1.57305, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.6181 - accuracy: 0.3715 - val_loss: 1.5730 - val_accuracy: 0.4310
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5956 - accuracy: 0.3711
# Epoch 00022: val_loss did not improve from 1.57305
# 36/35 [==============================] - 35s 986ms/step - loss: 1.5956 - accuracy: 0.3711 - val_loss: 1.6503 - val_accuracy: 0.3503
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6237 - accuracy: 0.3684
# Epoch 00023: val_loss did not improve from 1.57305
# 36/35 [==============================] - 38s 1s/step - loss: 1.6237 - accuracy: 0.3684 - val_loss: 1.5828 - val_accuracy: 0.3997
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5726 - accuracy: 0.3924
# Epoch 00024: val_loss did not improve from 1.57305
# 36/35 [==============================] - 38s 1s/step - loss: 1.5726 - accuracy: 0.3924 - val_loss: 1.5784 - val_accuracy: 0.3776
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5577 - accuracy: 0.3971
# Epoch 00025: val_loss improved from 1.57305 to 1.50778, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.5577 - accuracy: 0.3971 - val_loss: 1.5078 - val_accuracy: 0.4232
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5362 - accuracy: 0.3889
# Epoch 00026: val_loss improved from 1.50778 to 1.50702, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.5362 - accuracy: 0.3889 - val_loss: 1.5070 - val_accuracy: 0.4141
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5395 - accuracy: 0.4126
# Epoch 00027: val_loss did not improve from 1.50702
# 36/35 [==============================] - 36s 998ms/step - loss: 1.5395 - accuracy: 0.4126 - val_loss: 1.6102 - val_accuracy: 0.3711
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5559 - accuracy: 0.4050
# Epoch 00028: val_loss did not improve from 1.50702
# 36/35 [==============================] - 36s 1s/step - loss: 1.5559 - accuracy: 0.4050 - val_loss: 1.6020 - val_accuracy: 0.3685
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5483 - accuracy: 0.3988
# Epoch 00029: val_loss did not improve from 1.50702
# 36/35 [==============================] - 37s 1s/step - loss: 1.5483 - accuracy: 0.3988 - val_loss: 1.7549 - val_accuracy: 0.2695
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5737 - accuracy: 0.3889
# Epoch 00030: val_loss did not improve from 1.50702
# 36/35 [==============================] - 36s 1s/step - loss: 1.5737 - accuracy: 0.3889 - val_loss: 1.6019 - val_accuracy: 0.3490
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5168 - accuracy: 0.4067
# Epoch 00031: val_loss did not improve from 1.50702
# 36/35 [==============================] - 37s 1s/step - loss: 1.5168 - accuracy: 0.4067 - val_loss: 1.6509 - val_accuracy: 0.3438
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4775 - accuracy: 0.4318
# Epoch 00032: val_loss improved from 1.50702 to 1.43911, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.4775 - accuracy: 0.4318 - val_loss: 1.4391 - val_accuracy: 0.4648
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5093 - accuracy: 0.4228
# Epoch 00033: val_loss did not improve from 1.43911
# 36/35 [==============================] - 36s 990ms/step - loss: 1.5093 - accuracy: 0.4228 - val_loss: 1.7388 - val_accuracy: 0.3607
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4714 - accuracy: 0.4371
# Epoch 00034: val_loss did not improve from 1.43911
# 36/35 [==============================] - 36s 1s/step - loss: 1.4714 - accuracy: 0.4371 - val_loss: 1.4853 - val_accuracy: 0.4245
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4513 - accuracy: 0.4427
# Epoch 00035: val_loss did not improve from 1.43911
# 36/35 [==============================] - 37s 1s/step - loss: 1.4513 - accuracy: 0.4427 - val_loss: 1.5495 - val_accuracy: 0.4089
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4648 - accuracy: 0.4301
# Epoch 00036: val_loss did not improve from 1.43911
# 36/35 [==============================] - 37s 1s/step - loss: 1.4648 - accuracy: 0.4301 - val_loss: 1.4645 - val_accuracy: 0.4336
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4668 - accuracy: 0.4280
# Epoch 00037: val_loss did not improve from 1.43911
# 36/35 [==============================] - 38s 1s/step - loss: 1.4668 - accuracy: 0.4280 - val_loss: 1.5688 - val_accuracy: 0.4180
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4868 - accuracy: 0.4184
# Epoch 00038: val_loss did not improve from 1.43911
# 36/35 [==============================] - 36s 989ms/step - loss: 1.4868 - accuracy: 0.4184 - val_loss: 1.5033 - val_accuracy: 0.4336
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4115 - accuracy: 0.4442
# Epoch 00039: val_loss did not improve from 1.43911
# 36/35 [==============================] - 36s 1s/step - loss: 1.4115 - accuracy: 0.4442 - val_loss: 1.5171 - val_accuracy: 0.4180
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4282 - accuracy: 0.4531
# Epoch 00040: val_loss did not improve from 1.43911
# 36/35 [==============================] - 37s 1s/step - loss: 1.4282 - accuracy: 0.4531 - val_loss: 1.7679 - val_accuracy: 0.3372
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4467 - accuracy: 0.4371
# Epoch 00041: val_loss did not improve from 1.43911
# 36/35 [==============================] - 36s 986ms/step - loss: 1.4467 - accuracy: 0.4371 - val_loss: 1.5857 - val_accuracy: 0.4023
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4239 - accuracy: 0.4553
# Epoch 00042: val_loss did not improve from 1.43911
# 36/35 [==============================] - 37s 1s/step - loss: 1.4239 - accuracy: 0.4553 - val_loss: 1.4610 - val_accuracy: 0.4492
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3780 - accuracy: 0.4787
# Epoch 00043: val_loss did not improve from 1.43911
# 36/35 [==============================] - 37s 1s/step - loss: 1.3780 - accuracy: 0.4787 - val_loss: 1.5325 - val_accuracy: 0.4310
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3720 - accuracy: 0.4674
# Epoch 00044: val_loss improved from 1.43911 to 1.37610, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.3720 - accuracy: 0.4674 - val_loss: 1.3761 - val_accuracy: 0.4688
# Epoch 45/200
# 35/35 [============================>.] - ETA: 0s - loss: 1.3458 - accuracy: 0.4946
# Epoch 00045: val_loss did not improve from 1.37610
# 36/35 [==============================] - 37s 1s/step - loss: 1.3447 - accuracy: 0.4951 - val_loss: 1.4633 - val_accuracy: 0.4622
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3358 - accuracy: 0.4888
# Epoch 00046: val_loss did not improve from 1.37610
# 36/35 [==============================] - 35s 985ms/step - loss: 1.3358 - accuracy: 0.4888 - val_loss: 1.4824 - val_accuracy: 0.4544
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3486 - accuracy: 0.4861
# Epoch 00047: val_loss did not improve from 1.37610
# 36/35 [==============================] - 38s 1s/step - loss: 1.3486 - accuracy: 0.4861 - val_loss: 1.5576 - val_accuracy: 0.4128
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2992 - accuracy: 0.5139
# Epoch 00048: val_loss did not improve from 1.37610
# 36/35 [==============================] - 37s 1s/step - loss: 1.2992 - accuracy: 0.5139 - val_loss: 1.7658 - val_accuracy: 0.3919
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3295 - accuracy: 0.4957
# Epoch 00049: val_loss did not improve from 1.37610
# 36/35 [==============================] - 37s 1s/step - loss: 1.3295 - accuracy: 0.4957 - val_loss: 1.7460 - val_accuracy: 0.3932
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3744 - accuracy: 0.4768
# Epoch 00050: val_loss did not improve from 1.37610
# 36/35 [==============================] - 36s 1s/step - loss: 1.3744 - accuracy: 0.4768 - val_loss: 1.6398 - val_accuracy: 0.3932
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3864 - accuracy: 0.4790
# Epoch 00051: val_loss did not improve from 1.37610
# 36/35 [==============================] - 36s 1s/step - loss: 1.3864 - accuracy: 0.4790 - val_loss: 1.4627 - val_accuracy: 0.4518
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3339 - accuracy: 0.4880
# Epoch 00052: val_loss did not improve from 1.37610
# 36/35 [==============================] - 36s 992ms/step - loss: 1.3339 - accuracy: 0.4880 - val_loss: 1.5275 - val_accuracy: 0.4219
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3051 - accuracy: 0.5125
# Epoch 00053: val_loss improved from 1.37610 to 1.31253, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.3051 - accuracy: 0.5125 - val_loss: 1.3125 - val_accuracy: 0.4961
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2826 - accuracy: 0.5056
# Epoch 00054: val_loss did not improve from 1.31253
# 36/35 [==============================] - 37s 1s/step - loss: 1.2826 - accuracy: 0.5056 - val_loss: 1.4094 - val_accuracy: 0.4596
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2816 - accuracy: 0.5091
# Epoch 00055: val_loss did not improve from 1.31253
# 36/35 [==============================] - 38s 1s/step - loss: 1.2816 - accuracy: 0.5091 - val_loss: 1.3990 - val_accuracy: 0.4805
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2650 - accuracy: 0.5200
# Epoch 00056: val_loss did not improve from 1.31253
# 36/35 [==============================] - 37s 1s/step - loss: 1.2650 - accuracy: 0.5200 - val_loss: 1.4578 - val_accuracy: 0.4622
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2113 - accuracy: 0.5391
# Epoch 00057: val_loss did not improve from 1.31253
# 36/35 [==============================] - 36s 994ms/step - loss: 1.2113 - accuracy: 0.5391 - val_loss: 1.4741 - val_accuracy: 0.4479
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2651 - accuracy: 0.5326
# Epoch 00058: val_loss improved from 1.31253 to 1.29374, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.2651 - accuracy: 0.5326 - val_loss: 1.2937 - val_accuracy: 0.5052
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2354 - accuracy: 0.5382
# Epoch 00059: val_loss did not improve from 1.29374
# 36/35 [==============================] - 37s 1s/step - loss: 1.2354 - accuracy: 0.5382 - val_loss: 1.4552 - val_accuracy: 0.4531
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2313 - accuracy: 0.5356
# Epoch 00060: val_loss did not improve from 1.29374
# 36/35 [==============================] - 36s 1s/step - loss: 1.2313 - accuracy: 0.5356 - val_loss: 1.4554 - val_accuracy: 0.4714
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1975 - accuracy: 0.5412
# Epoch 00061: val_loss did not improve from 1.29374
# 36/35 [==============================] - 37s 1s/step - loss: 1.1975 - accuracy: 0.5412 - val_loss: 1.4114 - val_accuracy: 0.4870
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2553 - accuracy: 0.5446
# Epoch 00062: val_loss did not improve from 1.29374
# 36/35 [==============================] - 37s 1s/step - loss: 1.2553 - accuracy: 0.5446 - val_loss: 1.3848 - val_accuracy: 0.4753
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2062 - accuracy: 0.5460
# Epoch 00063: val_loss did not improve from 1.29374
# 36/35 [==============================] - 37s 1s/step - loss: 1.2062 - accuracy: 0.5460 - val_loss: 1.4894 - val_accuracy: 0.4727
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2112 - accuracy: 0.5499
# Epoch 00064: val_loss did not improve from 1.29374
# 36/35 [==============================] - 37s 1s/step - loss: 1.2112 - accuracy: 0.5499 - val_loss: 1.5082 - val_accuracy: 0.4622
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2187 - accuracy: 0.5393
# Epoch 00065: val_loss did not improve from 1.29374
# 36/35 [==============================] - 36s 994ms/step - loss: 1.2187 - accuracy: 0.5393 - val_loss: 1.7691 - val_accuracy: 0.4128
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2353 - accuracy: 0.5433
# Epoch 00066: val_loss did not improve from 1.29374
# 36/35 [==============================] - 36s 1s/step - loss: 1.2353 - accuracy: 0.5433 - val_loss: 1.6181 - val_accuracy: 0.4310
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2370 - accuracy: 0.5299
# Epoch 00067: val_loss did not improve from 1.29374
# 36/35 [==============================] - 37s 1s/step - loss: 1.2370 - accuracy: 0.5299 - val_loss: 1.6919 - val_accuracy: 0.4284
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1839 - accuracy: 0.5543
# Epoch 00068: val_loss improved from 1.29374 to 1.27648, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.1839 - accuracy: 0.5543 - val_loss: 1.2765 - val_accuracy: 0.5443
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1456 - accuracy: 0.5772
# Epoch 00069: val_loss improved from 1.27648 to 1.23280, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.1456 - accuracy: 0.5772 - val_loss: 1.2328 - val_accuracy: 0.5612
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1800 - accuracy: 0.5803
# Epoch 00070: val_loss did not improve from 1.23280
# 36/35 [==============================] - 37s 1s/step - loss: 1.1800 - accuracy: 0.5803 - val_loss: 1.3542 - val_accuracy: 0.5091
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1607 - accuracy: 0.5686
# Epoch 00071: val_loss did not improve from 1.23280
# 36/35 [==============================] - 38s 1s/step - loss: 1.1607 - accuracy: 0.5686 - val_loss: 1.5870 - val_accuracy: 0.4492
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1396 - accuracy: 0.5859
# Epoch 00072: val_loss did not improve from 1.23280
# 36/35 [==============================] - 38s 1s/step - loss: 1.1396 - accuracy: 0.5859 - val_loss: 1.2975 - val_accuracy: 0.5182
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1455 - accuracy: 0.5834
# Epoch 00073: val_loss did not improve from 1.23280
# 36/35 [==============================] - 36s 996ms/step - loss: 1.1455 - accuracy: 0.5834 - val_loss: 1.4051 - val_accuracy: 0.4818
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1291 - accuracy: 0.5955
# Epoch 00074: val_loss did not improve from 1.23280
# 36/35 [==============================] - 38s 1s/step - loss: 1.1291 - accuracy: 0.5955 - val_loss: 1.7079 - val_accuracy: 0.4570
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0939 - accuracy: 0.6033
# Epoch 00075: val_loss did not improve from 1.23280
# 36/35 [==============================] - 37s 1s/step - loss: 1.0939 - accuracy: 0.6033 - val_loss: 1.3919 - val_accuracy: 0.5000
# Epoch 76/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1089 - accuracy: 0.5964
# Epoch 00076: val_loss did not improve from 1.23280
# 36/35 [==============================] - 37s 1s/step - loss: 1.1089 - accuracy: 0.5964 - val_loss: 1.2883 - val_accuracy: 0.5508
# Epoch 77/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0757 - accuracy: 0.6076
# Epoch 00077: val_loss did not improve from 1.23280
# 36/35 [==============================] - 37s 1s/step - loss: 1.0757 - accuracy: 0.6076 - val_loss: 1.2583 - val_accuracy: 0.5638
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1327 - accuracy: 0.5955
# Epoch 00078: val_loss did not improve from 1.23280
# 36/35 [==============================] - 37s 1s/step - loss: 1.1327 - accuracy: 0.5955 - val_loss: 1.2792 - val_accuracy: 0.5326
# Epoch 79/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1825 - accuracy: 0.5602
# Epoch 00079: val_loss improved from 1.23280 to 1.20579, saving model to model.hdf5
# 36/35 [==============================] - 36s 998ms/step - loss: 1.1825 - accuracy: 0.5602 - val_loss: 1.2058 - val_accuracy: 0.5534
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1209 - accuracy: 0.5890
# Epoch 00080: val_loss did not improve from 1.20579
# 36/35 [==============================] - 37s 1s/step - loss: 1.1209 - accuracy: 0.5890 - val_loss: 1.2505 - val_accuracy: 0.5365
# Epoch 81/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0985 - accuracy: 0.5883
# Epoch 00081: val_loss did not improve from 1.20579
# 36/35 [==============================] - 36s 997ms/step - loss: 1.0985 - accuracy: 0.5883 - val_loss: 1.2278 - val_accuracy: 0.5664
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1071 - accuracy: 0.5986
# Epoch 00082: val_loss did not improve from 1.20579
# 36/35 [==============================] - 36s 1s/step - loss: 1.1071 - accuracy: 0.5986 - val_loss: 1.2591 - val_accuracy: 0.5690
# Epoch 83/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0716 - accuracy: 0.6085
# Epoch 00083: val_loss did not improve from 1.20579
# 36/35 [==============================] - 37s 1s/step - loss: 1.0716 - accuracy: 0.6085 - val_loss: 1.3426 - val_accuracy: 0.5273
# Epoch 84/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1320 - accuracy: 0.5847
# Epoch 00084: val_loss did not improve from 1.20579
# 36/35 [==============================] - 36s 999ms/step - loss: 1.1320 - accuracy: 0.5847 - val_loss: 1.2948 - val_accuracy: 0.5286
# Epoch 85/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1208 - accuracy: 0.6008
# Epoch 00085: val_loss improved from 1.20579 to 1.18242, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.1208 - accuracy: 0.6008 - val_loss: 1.1824 - val_accuracy: 0.5651
# Epoch 86/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1049 - accuracy: 0.5898
# Epoch 00086: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.1049 - accuracy: 0.5898 - val_loss: 1.2990 - val_accuracy: 0.5443
# Epoch 87/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0302 - accuracy: 0.6332
# Epoch 00087: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.0302 - accuracy: 0.6332 - val_loss: 1.2016 - val_accuracy: 0.5729
# Epoch 88/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0842 - accuracy: 0.5910
# Epoch 00088: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.0842 - accuracy: 0.5910 - val_loss: 1.2282 - val_accuracy: 0.5664
# Epoch 89/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0830 - accuracy: 0.6075
# Epoch 00089: val_loss did not improve from 1.18242
# 36/35 [==============================] - 36s 1s/step - loss: 1.0830 - accuracy: 0.6075 - val_loss: 1.4603 - val_accuracy: 0.5117
# Epoch 90/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0382 - accuracy: 0.6224
# Epoch 00090: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.0382 - accuracy: 0.6224 - val_loss: 1.2197 - val_accuracy: 0.5729
# Epoch 91/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0077 - accuracy: 0.6209
# Epoch 00091: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.0077 - accuracy: 0.6209 - val_loss: 1.2589 - val_accuracy: 0.5651
# Epoch 92/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0178 - accuracy: 0.6280
# Epoch 00092: val_loss did not improve from 1.18242
# 36/35 [==============================] - 36s 988ms/step - loss: 1.0178 - accuracy: 0.6280 - val_loss: 1.2205 - val_accuracy: 0.5990
# Epoch 93/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1036 - accuracy: 0.6062
# Epoch 00093: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.1036 - accuracy: 0.6062 - val_loss: 1.2708 - val_accuracy: 0.5391
# Epoch 94/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0191 - accuracy: 0.6337
# Epoch 00094: val_loss did not improve from 1.18242
# 36/35 [==============================] - 38s 1s/step - loss: 1.0191 - accuracy: 0.6337 - val_loss: 1.3003 - val_accuracy: 0.5339
# Epoch 95/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0246 - accuracy: 0.6293
# Epoch 00095: val_loss did not improve from 1.18242
# 36/35 [==============================] - 37s 1s/step - loss: 1.0246 - accuracy: 0.6293 - val_loss: 1.4538 - val_accuracy: 0.5417
# Epoch 96/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0331 - accuracy: 0.6280
# Epoch 00096: val_loss improved from 1.18242 to 1.10227, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.0331 - accuracy: 0.6280 - val_loss: 1.1023 - val_accuracy: 0.6029
# Epoch 97/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9569 - accuracy: 0.6530
# Epoch 00097: val_loss did not improve from 1.10227
# 36/35 [==============================] - 37s 1s/step - loss: 0.9569 - accuracy: 0.6530 - val_loss: 1.3747 - val_accuracy: 0.5286
# Epoch 98/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9166 - accuracy: 0.6710
# Epoch 00098: val_loss did not improve from 1.10227
# 36/35 [==============================] - 36s 1s/step - loss: 0.9166 - accuracy: 0.6710 - val_loss: 1.1609 - val_accuracy: 0.5938
# Epoch 99/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9505 - accuracy: 0.6615
# Epoch 00099: val_loss did not improve from 1.10227
# 36/35 [==============================] - 37s 1s/step - loss: 0.9505 - accuracy: 0.6615 - val_loss: 1.3206 - val_accuracy: 0.5638
# Epoch 100/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9560 - accuracy: 0.6523
# Epoch 00100: val_loss improved from 1.10227 to 1.05086, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 0.9560 - accuracy: 0.6523 - val_loss: 1.0509 - val_accuracy: 0.6185
# Epoch 101/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9523 - accuracy: 0.6597
# Epoch 00101: val_loss did not improve from 1.05086
# 36/35 [==============================] - 37s 1s/step - loss: 0.9523 - accuracy: 0.6597 - val_loss: 1.2942 - val_accuracy: 0.5560
# Epoch 102/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9511 - accuracy: 0.6744
# Epoch 00102: val_loss did not improve from 1.05086
# 36/35 [==============================] - 37s 1s/step - loss: 0.9511 - accuracy: 0.6744 - val_loss: 1.2787 - val_accuracy: 0.5742
# Epoch 103/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9271 - accuracy: 0.6677
# Epoch 00103: val_loss did not improve from 1.05086
# 36/35 [==============================] - 36s 1s/step - loss: 0.9271 - accuracy: 0.6677 - val_loss: 1.4679 - val_accuracy: 0.5208
# Epoch 104/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9481 - accuracy: 0.6758
# Epoch 00104: val_loss did not improve from 1.05086
# 36/35 [==============================] - 39s 1s/step - loss: 0.9481 - accuracy: 0.6758 - val_loss: 1.1339 - val_accuracy: 0.6185
# Epoch 105/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0449 - accuracy: 0.6307
# Epoch 00105: val_loss did not improve from 1.05086
# 36/35 [==============================] - 37s 1s/step - loss: 1.0449 - accuracy: 0.6307 - val_loss: 1.1442 - val_accuracy: 0.5951
# Epoch 106/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9888 - accuracy: 0.6545
# Epoch 00106: val_loss improved from 1.05086 to 1.00611, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 0.9888 - accuracy: 0.6545 - val_loss: 1.0061 - val_accuracy: 0.6549
# Epoch 107/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.6875
# Epoch 00107: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8925 - accuracy: 0.6875 - val_loss: 1.2738 - val_accuracy: 0.5781
# Epoch 108/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8964 - accuracy: 0.6780
# Epoch 00108: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8964 - accuracy: 0.6780 - val_loss: 1.3903 - val_accuracy: 0.5534
# Epoch 109/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9219 - accuracy: 0.6749
# Epoch 00109: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.9219 - accuracy: 0.6749 - val_loss: 1.2621 - val_accuracy: 0.5807
# Epoch 110/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9238 - accuracy: 0.6708
# Epoch 00110: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.9238 - accuracy: 0.6708 - val_loss: 1.2603 - val_accuracy: 0.5781
# Epoch 111/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9049 - accuracy: 0.6699
# Epoch 00111: val_loss did not improve from 1.00611
# 36/35 [==============================] - 36s 1000ms/step - loss: 0.9049 - accuracy: 0.6699 - val_loss: 1.2511 - val_accuracy: 0.5638
# Epoch 112/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8902 - accuracy: 0.6888
# Epoch 00112: val_loss did not improve from 1.00611
# 36/35 [==============================] - 38s 1s/step - loss: 0.8902 - accuracy: 0.6888 - val_loss: 1.4388 - val_accuracy: 0.5365
# Epoch 113/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9693 - accuracy: 0.6548
# Epoch 00113: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.9693 - accuracy: 0.6548 - val_loss: 1.1792 - val_accuracy: 0.6003
# Epoch 114/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8746 - accuracy: 0.6891
# Epoch 00114: val_loss did not improve from 1.00611
# 36/35 [==============================] - 36s 995ms/step - loss: 0.8746 - accuracy: 0.6891 - val_loss: 1.1168 - val_accuracy: 0.6211
# Epoch 115/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9660 - accuracy: 0.6459
# Epoch 00115: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.9660 - accuracy: 0.6459 - val_loss: 1.0509 - val_accuracy: 0.6432
# Epoch 116/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.6845
# Epoch 00116: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8939 - accuracy: 0.6845 - val_loss: 1.2147 - val_accuracy: 0.5924
# Epoch 117/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8789 - accuracy: 0.6944
# Epoch 00117: val_loss did not improve from 1.00611
# 36/35 [==============================] - 38s 1s/step - loss: 0.8789 - accuracy: 0.6944 - val_loss: 1.2660 - val_accuracy: 0.5846
# Epoch 118/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8360 - accuracy: 0.7079
# Epoch 00118: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8360 - accuracy: 0.7079 - val_loss: 1.1417 - val_accuracy: 0.6172
# Epoch 119/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8845 - accuracy: 0.6829
# Epoch 00119: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8845 - accuracy: 0.6829 - val_loss: 1.2296 - val_accuracy: 0.5846
# Epoch 120/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8521 - accuracy: 0.6970
# Epoch 00120: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8521 - accuracy: 0.6970 - val_loss: 1.1745 - val_accuracy: 0.6068
# Epoch 121/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8397 - accuracy: 0.7023
# Epoch 00121: val_loss did not improve from 1.00611
# 36/35 [==============================] - 38s 1s/step - loss: 0.8397 - accuracy: 0.7023 - val_loss: 1.1203 - val_accuracy: 0.6276
# Epoch 122/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8788 - accuracy: 0.6853
# Epoch 00122: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8788 - accuracy: 0.6853 - val_loss: 1.0931 - val_accuracy: 0.6289
# Epoch 123/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8541 - accuracy: 0.6931
# Epoch 00123: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8541 - accuracy: 0.6931 - val_loss: 1.1098 - val_accuracy: 0.6315
# Epoch 124/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8487 - accuracy: 0.6989
# Epoch 00124: val_loss did not improve from 1.00611
# 36/35 [==============================] - 37s 1s/step - loss: 0.8487 - accuracy: 0.6989 - val_loss: 1.2713 - val_accuracy: 0.5768
# Epoch 125/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8746 - accuracy: 0.6891
# Epoch 00125: val_loss did not improve from 1.00611
# 36/35 [==============================] - 36s 1s/step - loss: 0.8746 - accuracy: 0.6891 - val_loss: 1.2613 - val_accuracy: 0.5951
# Epoch 126/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8466 - accuracy: 0.7005
# Epoch 00126: val_loss did not improve from 1.00611
# 36/35 [==============================] - 38s 1s/step - loss: 0.8466 - accuracy: 0.7005 - val_loss: 1.2850 - val_accuracy: 0.5820

# %%
#Plotting accuracy
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 1750 images belonging to 7 classes.

# %%
#calculating test accuracy score
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 65.6%

# %%
#labeling sequence of the 7 classes
list(classtolabel.keys())
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
#plotting confusion matrix
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
