# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the data
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=5)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=5)

# %%
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#listing the 3 selected classes at random
classtolabel
# Out:
# {0: 'escargots',
#  1: 'frozen_yogurt',
#  2: 'shrimp_and_grits',
#  3: 'creme_brulee',
#  4: 'risotto'}

# %%
#performing data augmentation on train and test images
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 3750 images belonging to 5 classes.
# Found 1250 images belonging to 5 classes.

# %%
#preparing the model
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(5, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
#creating the model
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7352 - accuracy: 0.1901
# Epoch 00001: val_loss improved from inf to 1.68023, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.7352 - accuracy: 0.1901 - val_loss: 1.6802 - val_accuracy: 0.2109
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6700 - accuracy: 0.2090
# Epoch 00002: val_loss improved from 1.68023 to 1.66092, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.6700 - accuracy: 0.2090 - val_loss: 1.6609 - val_accuracy: 0.1914
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6518 - accuracy: 0.2287
# Epoch 00003: val_loss improved from 1.66092 to 1.63606, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.6518 - accuracy: 0.2287 - val_loss: 1.6361 - val_accuracy: 0.2161
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6302 - accuracy: 0.2357
# Epoch 00004: val_loss improved from 1.63606 to 1.60921, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.6302 - accuracy: 0.2357 - val_loss: 1.6092 - val_accuracy: 0.2578
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6022 - accuracy: 0.2524
# Epoch 00005: val_loss improved from 1.60921 to 1.56650, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.6022 - accuracy: 0.2524 - val_loss: 1.5665 - val_accuracy: 0.2604
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5717 - accuracy: 0.2796
# Epoch 00006: val_loss improved from 1.56650 to 1.53515, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.5717 - accuracy: 0.2796 - val_loss: 1.5352 - val_accuracy: 0.2969
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5587 - accuracy: 0.2845
# Epoch 00007: val_loss improved from 1.53515 to 1.51691, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.5587 - accuracy: 0.2845 - val_loss: 1.5169 - val_accuracy: 0.3086
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5261 - accuracy: 0.3155
# Epoch 00008: val_loss improved from 1.51691 to 1.49959, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.5261 - accuracy: 0.3155 - val_loss: 1.4996 - val_accuracy: 0.3177
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5313 - accuracy: 0.3012
# Epoch 00009: val_loss did not improve from 1.49959
# 36/35 [==============================] - 38s 1s/step - loss: 1.5313 - accuracy: 0.3012 - val_loss: 1.5403 - val_accuracy: 0.3112
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5210 - accuracy: 0.3138
# Epoch 00010: val_loss improved from 1.49959 to 1.49451, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.5210 - accuracy: 0.3138 - val_loss: 1.4945 - val_accuracy: 0.3307
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5027 - accuracy: 0.3186
# Epoch 00011: val_loss improved from 1.49451 to 1.47986, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.5027 - accuracy: 0.3186 - val_loss: 1.4799 - val_accuracy: 0.3255
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4838 - accuracy: 0.3406
# Epoch 00012: val_loss improved from 1.47986 to 1.44406, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.4838 - accuracy: 0.3406 - val_loss: 1.4441 - val_accuracy: 0.3711
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4640 - accuracy: 0.3556
# Epoch 00013: val_loss improved from 1.44406 to 1.43322, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.4640 - accuracy: 0.3556 - val_loss: 1.4332 - val_accuracy: 0.3867
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4358 - accuracy: 0.3802
# Epoch 00014: val_loss improved from 1.43322 to 1.40263, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.4358 - accuracy: 0.3802 - val_loss: 1.4026 - val_accuracy: 0.4219
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4241 - accuracy: 0.3788
# Epoch 00015: val_loss did not improve from 1.40263
# 36/35 [==============================] - 41s 1s/step - loss: 1.4241 - accuracy: 0.3788 - val_loss: 1.4035 - val_accuracy: 0.4440
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4010 - accuracy: 0.4144
# Epoch 00016: val_loss improved from 1.40263 to 1.37922, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.4010 - accuracy: 0.4144 - val_loss: 1.3792 - val_accuracy: 0.4284
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3407 - accuracy: 0.4345
# Epoch 00017: val_loss improved from 1.37922 to 1.27431, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.3407 - accuracy: 0.4345 - val_loss: 1.2743 - val_accuracy: 0.4779
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3292 - accuracy: 0.4314
# Epoch 00018: val_loss improved from 1.27431 to 1.26788, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.3292 - accuracy: 0.4314 - val_loss: 1.2679 - val_accuracy: 0.4727
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3282 - accuracy: 0.4271
# Epoch 00019: val_loss did not improve from 1.26788
# 36/35 [==============================] - 42s 1s/step - loss: 1.3282 - accuracy: 0.4271 - val_loss: 1.3051 - val_accuracy: 0.4648
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2888 - accuracy: 0.4549
# Epoch 00020: val_loss improved from 1.26788 to 1.23827, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.2888 - accuracy: 0.4549 - val_loss: 1.2383 - val_accuracy: 0.4987
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2720 - accuracy: 0.4549
# Epoch 00021: val_loss did not improve from 1.23827
# 36/35 [==============================] - 40s 1s/step - loss: 1.2720 - accuracy: 0.4549 - val_loss: 1.2563 - val_accuracy: 0.4544
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2393 - accuracy: 0.4809
# Epoch 00022: val_loss improved from 1.23827 to 1.21606, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.2393 - accuracy: 0.4809 - val_loss: 1.2161 - val_accuracy: 0.4674
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2689 - accuracy: 0.4640
# Epoch 00023: val_loss did not improve from 1.21606
# 36/35 [==============================] - 40s 1s/step - loss: 1.2689 - accuracy: 0.4640 - val_loss: 1.2251 - val_accuracy: 0.4870
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2152 - accuracy: 0.4796
# Epoch 00024: val_loss improved from 1.21606 to 1.14053, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.2152 - accuracy: 0.4796 - val_loss: 1.1405 - val_accuracy: 0.5156
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1887 - accuracy: 0.4874
# Epoch 00025: val_loss did not improve from 1.14053
# 36/35 [==============================] - 41s 1s/step - loss: 1.1887 - accuracy: 0.4874 - val_loss: 1.1804 - val_accuracy: 0.4922
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1756 - accuracy: 0.4983
# Epoch 00026: val_loss did not improve from 1.14053
# 36/35 [==============================] - 41s 1s/step - loss: 1.1756 - accuracy: 0.4983 - val_loss: 1.1638 - val_accuracy: 0.4792
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1593 - accuracy: 0.5026
# Epoch 00027: val_loss improved from 1.14053 to 1.06484, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.1593 - accuracy: 0.5026 - val_loss: 1.0648 - val_accuracy: 0.5404
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1195 - accuracy: 0.5255
# Epoch 00028: val_loss did not improve from 1.06484
# 36/35 [==============================] - 42s 1s/step - loss: 1.1195 - accuracy: 0.5255 - val_loss: 1.0685 - val_accuracy: 0.5326
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1565 - accuracy: 0.5158
# Epoch 00029: val_loss did not improve from 1.06484
# 36/35 [==============================] - 44s 1s/step - loss: 1.1565 - accuracy: 0.5158 - val_loss: 1.0794 - val_accuracy: 0.5378
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1444 - accuracy: 0.5224
# Epoch 00030: val_loss did not improve from 1.06484
# 36/35 [==============================] - 41s 1s/step - loss: 1.1444 - accuracy: 0.5224 - val_loss: 1.1603 - val_accuracy: 0.5195
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1490 - accuracy: 0.5246
# Epoch 00031: val_loss improved from 1.06484 to 1.02394, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.1490 - accuracy: 0.5246 - val_loss: 1.0239 - val_accuracy: 0.5951
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0617 - accuracy: 0.5590
# Epoch 00032: val_loss improved from 1.02394 to 1.00353, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0617 - accuracy: 0.5590 - val_loss: 1.0035 - val_accuracy: 0.5703
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0896 - accuracy: 0.5421
# Epoch 00033: val_loss did not improve from 1.00353
# 36/35 [==============================] - 41s 1s/step - loss: 1.0896 - accuracy: 0.5421 - val_loss: 1.0067 - val_accuracy: 0.5716
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0617 - accuracy: 0.5544
# Epoch 00034: val_loss did not improve from 1.00353
# 36/35 [==============================] - 42s 1s/step - loss: 1.0617 - accuracy: 0.5544 - val_loss: 1.0736 - val_accuracy: 0.5482
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0705 - accuracy: 0.5492
# Epoch 00035: val_loss did not improve from 1.00353
# 36/35 [==============================] - 41s 1s/step - loss: 1.0705 - accuracy: 0.5492 - val_loss: 1.0507 - val_accuracy: 0.5495
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0262 - accuracy: 0.5660
# Epoch 00036: val_loss did not improve from 1.00353
# 36/35 [==============================] - 42s 1s/step - loss: 1.0262 - accuracy: 0.5660 - val_loss: 1.0160 - val_accuracy: 0.5690
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0023 - accuracy: 0.5847
# Epoch 00037: val_loss improved from 1.00353 to 0.99820, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0023 - accuracy: 0.5847 - val_loss: 0.9982 - val_accuracy: 0.6029
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0499 - accuracy: 0.5690
# Epoch 00038: val_loss did not improve from 0.99820
# 36/35 [==============================] - 41s 1s/step - loss: 1.0499 - accuracy: 0.5690 - val_loss: 1.1091 - val_accuracy: 0.5312
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0236 - accuracy: 0.5777
# Epoch 00039: val_loss did not improve from 0.99820
# 36/35 [==============================] - 41s 1s/step - loss: 1.0236 - accuracy: 0.5777 - val_loss: 1.0351 - val_accuracy: 0.5651
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0090 - accuracy: 0.5742
# Epoch 00040: val_loss improved from 0.99820 to 0.95973, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0090 - accuracy: 0.5742 - val_loss: 0.9597 - val_accuracy: 0.5898
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0099 - accuracy: 0.5833
# Epoch 00041: val_loss improved from 0.95973 to 0.94276, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0099 - accuracy: 0.5833 - val_loss: 0.9428 - val_accuracy: 0.6120
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9620 - accuracy: 0.6107
# Epoch 00042: val_loss improved from 0.94276 to 0.94096, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.9620 - accuracy: 0.6107 - val_loss: 0.9410 - val_accuracy: 0.6146
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0215 - accuracy: 0.5760
# Epoch 00043: val_loss did not improve from 0.94096
# 36/35 [==============================] - 42s 1s/step - loss: 1.0215 - accuracy: 0.5760 - val_loss: 0.9507 - val_accuracy: 0.6107
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9651 - accuracy: 0.6111
# Epoch 00044: val_loss improved from 0.94096 to 0.92844, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.9651 - accuracy: 0.6111 - val_loss: 0.9284 - val_accuracy: 0.6250
# Epoch 45/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9564 - accuracy: 0.6124
# Epoch 00045: val_loss improved from 0.92844 to 0.91187, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 0.9564 - accuracy: 0.6124 - val_loss: 0.9119 - val_accuracy: 0.6576
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9493 - accuracy: 0.6093
# Epoch 00046: val_loss improved from 0.91187 to 0.88339, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.9493 - accuracy: 0.6093 - val_loss: 0.8834 - val_accuracy: 0.6354
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8934 - accuracy: 0.6536
# Epoch 00047: val_loss did not improve from 0.88339
# 36/35 [==============================] - 42s 1s/step - loss: 0.8934 - accuracy: 0.6536 - val_loss: 0.9250 - val_accuracy: 0.6510
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9304 - accuracy: 0.6259
# Epoch 00048: val_loss did not improve from 0.88339
# 36/35 [==============================] - 40s 1s/step - loss: 0.9304 - accuracy: 0.6259 - val_loss: 0.8962 - val_accuracy: 0.6484
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8614 - accuracy: 0.6637
# Epoch 00049: val_loss improved from 0.88339 to 0.87840, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.8614 - accuracy: 0.6637 - val_loss: 0.8784 - val_accuracy: 0.6406
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8961 - accuracy: 0.6437
# Epoch 00050: val_loss improved from 0.87840 to 0.81698, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.8961 - accuracy: 0.6437 - val_loss: 0.8170 - val_accuracy: 0.6849
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8509 - accuracy: 0.6632
# Epoch 00051: val_loss improved from 0.81698 to 0.80160, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.8509 - accuracy: 0.6632 - val_loss: 0.8016 - val_accuracy: 0.6979
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8535 - accuracy: 0.6762
# Epoch 00052: val_loss did not improve from 0.80160
# 36/35 [==============================] - 41s 1s/step - loss: 0.8535 - accuracy: 0.6762 - val_loss: 0.8232 - val_accuracy: 0.6862
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.6730
# Epoch 00053: val_loss improved from 0.80160 to 0.79926, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.8409 - accuracy: 0.6730 - val_loss: 0.7993 - val_accuracy: 0.6979
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8209 - accuracy: 0.6883
# Epoch 00054: val_loss improved from 0.79926 to 0.79354, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.8209 - accuracy: 0.6883 - val_loss: 0.7935 - val_accuracy: 0.6901
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7912 - accuracy: 0.6958
# Epoch 00055: val_loss did not improve from 0.79354
# 36/35 [==============================] - 41s 1s/step - loss: 0.7912 - accuracy: 0.6958 - val_loss: 0.8008 - val_accuracy: 0.6927
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8335 - accuracy: 0.6734
# Epoch 00056: val_loss did not improve from 0.79354
# 36/35 [==============================] - 41s 1s/step - loss: 0.8335 - accuracy: 0.6734 - val_loss: 0.8236 - val_accuracy: 0.6758
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8189 - accuracy: 0.6765
# Epoch 00057: val_loss improved from 0.79354 to 0.78580, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.8189 - accuracy: 0.6765 - val_loss: 0.7858 - val_accuracy: 0.6810
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8206 - accuracy: 0.6840
# Epoch 00058: val_loss improved from 0.78580 to 0.78540, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.8206 - accuracy: 0.6840 - val_loss: 0.7854 - val_accuracy: 0.6992
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7747 - accuracy: 0.7018
# Epoch 00059: val_loss improved from 0.78540 to 0.74430, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.7747 - accuracy: 0.7018 - val_loss: 0.7443 - val_accuracy: 0.7135
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.7209
# Epoch 00060: val_loss did not improve from 0.74430
# 36/35 [==============================] - 42s 1s/step - loss: 0.7259 - accuracy: 0.7209 - val_loss: 0.7716 - val_accuracy: 0.7266
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7563 - accuracy: 0.7186
# Epoch 00061: val_loss improved from 0.74430 to 0.74196, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.7563 - accuracy: 0.7186 - val_loss: 0.7420 - val_accuracy: 0.7253
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7643 - accuracy: 0.7101
# Epoch 00062: val_loss improved from 0.74196 to 0.71709, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.7643 - accuracy: 0.7101 - val_loss: 0.7171 - val_accuracy: 0.7044
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7606 - accuracy: 0.7166
# Epoch 00063: val_loss improved from 0.71709 to 0.69521, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.7606 - accuracy: 0.7166 - val_loss: 0.6952 - val_accuracy: 0.7396
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7336 - accuracy: 0.7239
# Epoch 00064: val_loss did not improve from 0.69521
# 36/35 [==============================] - 43s 1s/step - loss: 0.7336 - accuracy: 0.7239 - val_loss: 0.7651 - val_accuracy: 0.7122
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7500 - accuracy: 0.7107
# Epoch 00065: val_loss improved from 0.69521 to 0.64998, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.7500 - accuracy: 0.7107 - val_loss: 0.6500 - val_accuracy: 0.7630
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6809 - accuracy: 0.7471
# Epoch 00066: val_loss did not improve from 0.64998
# 36/35 [==============================] - 42s 1s/step - loss: 0.6809 - accuracy: 0.7471 - val_loss: 0.6830 - val_accuracy: 0.7357
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7513 - accuracy: 0.7226
# Epoch 00067: val_loss improved from 0.64998 to 0.62525, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.7513 - accuracy: 0.7226 - val_loss: 0.6253 - val_accuracy: 0.7604
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.7313
# Epoch 00068: val_loss did not improve from 0.62525
# 36/35 [==============================] - 43s 1s/step - loss: 0.6983 - accuracy: 0.7313 - val_loss: 0.7066 - val_accuracy: 0.7461
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.7204
# Epoch 00069: val_loss did not improve from 0.62525
# 36/35 [==============================] - 41s 1s/step - loss: 0.7225 - accuracy: 0.7204 - val_loss: 0.7385 - val_accuracy: 0.7188
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.7509
# Epoch 00070: val_loss did not improve from 0.62525
# 36/35 [==============================] - 42s 1s/step - loss: 0.6816 - accuracy: 0.7509 - val_loss: 0.6842 - val_accuracy: 0.7435
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6839 - accuracy: 0.7383
# Epoch 00071: val_loss did not improve from 0.62525
# 36/35 [==============================] - 42s 1s/step - loss: 0.6839 - accuracy: 0.7383 - val_loss: 0.7240 - val_accuracy: 0.7435
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.7432
# Epoch 00072: val_loss did not improve from 0.62525
# 36/35 [==============================] - 42s 1s/step - loss: 0.6953 - accuracy: 0.7432 - val_loss: 0.6995 - val_accuracy: 0.7279
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7006 - accuracy: 0.7423
# Epoch 00073: val_loss did not improve from 0.62525
# 36/35 [==============================] - 40s 1s/step - loss: 0.7006 - accuracy: 0.7423 - val_loss: 0.6421 - val_accuracy: 0.7513
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.7467
# Epoch 00074: val_loss did not improve from 0.62525
# 36/35 [==============================] - 40s 1s/step - loss: 0.7134 - accuracy: 0.7467 - val_loss: 0.7278 - val_accuracy: 0.7357
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6540 - accuracy: 0.7537
# Epoch 00075: val_loss did not improve from 0.62525
# 36/35 [==============================] - 40s 1s/step - loss: 0.6540 - accuracy: 0.7537 - val_loss: 0.7012 - val_accuracy: 0.7383
# Epoch 76/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6624 - accuracy: 0.7470
# Epoch 00076: val_loss did not improve from 0.62525
# 36/35 [==============================] - 41s 1s/step - loss: 0.6624 - accuracy: 0.7470 - val_loss: 0.7790 - val_accuracy: 0.7253
# Epoch 77/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.7590
# Epoch 00077: val_loss did not improve from 0.62525
# 36/35 [==============================] - 40s 1s/step - loss: 0.6445 - accuracy: 0.7590 - val_loss: 0.6355 - val_accuracy: 0.7526
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5828 - accuracy: 0.7778
# Epoch 00078: val_loss did not improve from 0.62525
# 36/35 [==============================] - 41s 1s/step - loss: 0.5828 - accuracy: 0.7778 - val_loss: 0.6528 - val_accuracy: 0.7591
# Epoch 79/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.7687
# Epoch 00079: val_loss improved from 0.62525 to 0.60613, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.6032 - accuracy: 0.7687 - val_loss: 0.6061 - val_accuracy: 0.7812
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6003 - accuracy: 0.7709
# Epoch 00080: val_loss improved from 0.60613 to 0.56066, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.6003 - accuracy: 0.7709 - val_loss: 0.5607 - val_accuracy: 0.7852
# Epoch 81/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.7799
# Epoch 00081: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.5793 - accuracy: 0.7799 - val_loss: 0.6281 - val_accuracy: 0.7760
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5738 - accuracy: 0.7893
# Epoch 00082: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.5738 - accuracy: 0.7893 - val_loss: 0.7112 - val_accuracy: 0.7474
# Epoch 83/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5241 - accuracy: 0.8116
# Epoch 00083: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.5241 - accuracy: 0.8116 - val_loss: 0.5913 - val_accuracy: 0.7773
# Epoch 84/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5356 - accuracy: 0.8003
# Epoch 00084: val_loss did not improve from 0.56066
# 36/35 [==============================] - 40s 1s/step - loss: 0.5356 - accuracy: 0.8003 - val_loss: 0.6074 - val_accuracy: 0.7969
# Epoch 85/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5500 - accuracy: 0.7928
# Epoch 00085: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.5500 - accuracy: 0.7928 - val_loss: 0.6276 - val_accuracy: 0.7747
# Epoch 86/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5358 - accuracy: 0.8025
# Epoch 00086: val_loss did not improve from 0.56066
# 36/35 [==============================] - 44s 1s/step - loss: 0.5358 - accuracy: 0.8025 - val_loss: 0.6990 - val_accuracy: 0.7565
# Epoch 87/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5430 - accuracy: 0.8055
# Epoch 00087: val_loss did not improve from 0.56066
# 36/35 [==============================] - 41s 1s/step - loss: 0.5430 - accuracy: 0.8055 - val_loss: 0.6577 - val_accuracy: 0.7721
# Epoch 88/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5576 - accuracy: 0.7869
# Epoch 00088: val_loss did not improve from 0.56066
# 36/35 [==============================] - 43s 1s/step - loss: 0.5576 - accuracy: 0.7869 - val_loss: 0.6328 - val_accuracy: 0.7812
# Epoch 89/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5240 - accuracy: 0.8038
# Epoch 00089: val_loss did not improve from 0.56066
# 36/35 [==============================] - 44s 1s/step - loss: 0.5240 - accuracy: 0.8038 - val_loss: 0.6264 - val_accuracy: 0.7865
# Epoch 90/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.7994
# Epoch 00090: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.5253 - accuracy: 0.7994 - val_loss: 0.6026 - val_accuracy: 0.7865
# Epoch 91/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.8238
# Epoch 00091: val_loss did not improve from 0.56066
# 36/35 [==============================] - 41s 1s/step - loss: 0.4920 - accuracy: 0.8238 - val_loss: 0.6712 - val_accuracy: 0.7565
# Epoch 92/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.8183
# Epoch 00092: val_loss did not improve from 0.56066
# 36/35 [==============================] - 44s 1s/step - loss: 0.4695 - accuracy: 0.8183 - val_loss: 0.6326 - val_accuracy: 0.7917
# Epoch 93/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4892 - accuracy: 0.8196
# Epoch 00093: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.4892 - accuracy: 0.8196 - val_loss: 0.6177 - val_accuracy: 0.7917
# Epoch 94/200
# 36/35 [==============================] - ETA: -1s - loss: 0.4826 - accuracy: 0.8191
# Epoch 00094: val_loss did not improve from 0.56066
# 36/35 [==============================] - 58s 2s/step - loss: 0.4826 - accuracy: 0.8191 - val_loss: 0.6894 - val_accuracy: 0.7643
# Epoch 95/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.8099
# Epoch 00095: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.4936 - accuracy: 0.8099 - val_loss: 0.5845 - val_accuracy: 0.7812
# Epoch 96/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4536 - accuracy: 0.8292
# Epoch 00096: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.4536 - accuracy: 0.8292 - val_loss: 0.6053 - val_accuracy: 0.8034
# Epoch 97/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4459 - accuracy: 0.8333
# Epoch 00097: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.4459 - accuracy: 0.8333 - val_loss: 0.6474 - val_accuracy: 0.7760
# Epoch 98/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5130 - accuracy: 0.8051
# Epoch 00098: val_loss did not improve from 0.56066
# 36/35 [==============================] - 42s 1s/step - loss: 0.5130 - accuracy: 0.8051 - val_loss: 0.6087 - val_accuracy: 0.7747
# Epoch 99/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.8290
# Epoch 00099: val_loss did not improve from 0.56066
# 36/35 [==============================] - 41s 1s/step - loss: 0.4809 - accuracy: 0.8290 - val_loss: 0.6144 - val_accuracy: 0.7943
# Epoch 100/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4748 - accuracy: 0.8290
# Epoch 00100: val_loss did not improve from 0.56066
# 36/35 [==============================] - 44s 1s/step - loss: 0.4748 - accuracy: 0.8290 - val_loss: 0.6479 - val_accuracy: 0.7826

# %%
#plotting the observations
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
#Generation of image with ImageDataGenerator
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 1250 images belonging to 5 classes.

# %%
#returning accuracy
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 67.2%

# %%
list(classtolabel.keys())
# Out:
# [0, 1, 2, 3, 4]

# %%
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
