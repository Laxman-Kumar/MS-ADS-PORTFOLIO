# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the data
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=5)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=5)

# %%
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#listing the 3 selected classes at random
classtolabel
# Out:
# {0: 'tiramisu',
#  1: 'grilled_salmon',
#  2: 'carrot_cake',
#  3: 'lobster_roll_sandwich',
#  4: 'lasagna'}

# %%
#performing data augmentation on train and test images
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 3750 images belonging to 5 classes.
# Found 1250 images belonging to 5 classes.

# %%
#preparing the model
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(5, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
#creating the model
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7535 - accuracy: 0.2155
# Epoch 00001: val_loss improved from inf to 1.65540, saving model to model.hdf5
# 36/35 [==============================] - 36s 995ms/step - loss: 1.7535 - accuracy: 0.2155 - val_loss: 1.6554 - val_accuracy: 0.2839
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6393 - accuracy: 0.2735
# Epoch 00002: val_loss improved from 1.65540 to 1.60730, saving model to model.hdf5
# 36/35 [==============================] - 36s 994ms/step - loss: 1.6393 - accuracy: 0.2735 - val_loss: 1.6073 - val_accuracy: 0.2995
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5976 - accuracy: 0.2999
# Epoch 00003: val_loss improved from 1.60730 to 1.55184, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.5976 - accuracy: 0.2999 - val_loss: 1.5518 - val_accuracy: 0.3151
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5731 - accuracy: 0.3011
# Epoch 00004: val_loss did not improve from 1.55184
# 36/35 [==============================] - 36s 988ms/step - loss: 1.5731 - accuracy: 0.3011 - val_loss: 1.5904 - val_accuracy: 0.2812
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5674 - accuracy: 0.3055
# Epoch 00005: val_loss did not improve from 1.55184
# 36/35 [==============================] - 36s 1s/step - loss: 1.5674 - accuracy: 0.3055 - val_loss: 1.5660 - val_accuracy: 0.3320
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5444 - accuracy: 0.3082
# Epoch 00006: val_loss improved from 1.55184 to 1.50160, saving model to model.hdf5
# 36/35 [==============================] - 35s 970ms/step - loss: 1.5444 - accuracy: 0.3082 - val_loss: 1.5016 - val_accuracy: 0.3255
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5299 - accuracy: 0.3218
# Epoch 00007: val_loss improved from 1.50160 to 1.49296, saving model to model.hdf5
# 36/35 [==============================] - 36s 1000ms/step - loss: 1.5299 - accuracy: 0.3218 - val_loss: 1.4930 - val_accuracy: 0.3385
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5296 - accuracy: 0.3173
# Epoch 00008: val_loss did not improve from 1.49296
# 36/35 [==============================] - 36s 1s/step - loss: 1.5296 - accuracy: 0.3173 - val_loss: 1.5102 - val_accuracy: 0.3229
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5120 - accuracy: 0.3398
# Epoch 00009: val_loss did not improve from 1.49296
# 36/35 [==============================] - 35s 981ms/step - loss: 1.5120 - accuracy: 0.3398 - val_loss: 1.5215 - val_accuracy: 0.3034
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4778 - accuracy: 0.3472
# Epoch 00010: val_loss did not improve from 1.49296
# 36/35 [==============================] - 36s 1s/step - loss: 1.4778 - accuracy: 0.3472 - val_loss: 1.5045 - val_accuracy: 0.3411
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4496 - accuracy: 0.3685
# Epoch 00011: val_loss improved from 1.49296 to 1.43301, saving model to model.hdf5
# 36/35 [==============================] - 36s 987ms/step - loss: 1.4496 - accuracy: 0.3685 - val_loss: 1.4330 - val_accuracy: 0.3568
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4791 - accuracy: 0.3617
# Epoch 00012: val_loss improved from 1.43301 to 1.35914, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.4791 - accuracy: 0.3617 - val_loss: 1.3591 - val_accuracy: 0.4284
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4272 - accuracy: 0.3885
# Epoch 00013: val_loss did not improve from 1.35914
# 36/35 [==============================] - 36s 1s/step - loss: 1.4272 - accuracy: 0.3885 - val_loss: 1.3747 - val_accuracy: 0.4284
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4054 - accuracy: 0.3889
# Epoch 00014: val_loss did not improve from 1.35914
# 36/35 [==============================] - 36s 993ms/step - loss: 1.4054 - accuracy: 0.3889 - val_loss: 1.5099 - val_accuracy: 0.3542
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3651 - accuracy: 0.4091
# Epoch 00015: val_loss improved from 1.35914 to 1.34316, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.3651 - accuracy: 0.4091 - val_loss: 1.3432 - val_accuracy: 0.4570
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3735 - accuracy: 0.4087
# Epoch 00016: val_loss did not improve from 1.34316
# 36/35 [==============================] - 36s 1s/step - loss: 1.3735 - accuracy: 0.4087 - val_loss: 1.3538 - val_accuracy: 0.4232
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3786 - accuracy: 0.4206
# Epoch 00017: val_loss did not improve from 1.34316
# 36/35 [==============================] - 37s 1s/step - loss: 1.3786 - accuracy: 0.4206 - val_loss: 1.4502 - val_accuracy: 0.3516
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3716 - accuracy: 0.4136
# Epoch 00018: val_loss improved from 1.34316 to 1.29520, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.3716 - accuracy: 0.4136 - val_loss: 1.2952 - val_accuracy: 0.4609
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2951 - accuracy: 0.4662
# Epoch 00019: val_loss did not improve from 1.29520
# 36/35 [==============================] - 37s 1s/step - loss: 1.2951 - accuracy: 0.4662 - val_loss: 1.5421 - val_accuracy: 0.3411
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2457 - accuracy: 0.4883
# Epoch 00020: val_loss did not improve from 1.29520
# 36/35 [==============================] - 38s 1s/step - loss: 1.2457 - accuracy: 0.4883 - val_loss: 1.3184 - val_accuracy: 0.4440
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2900 - accuracy: 0.4774
# Epoch 00021: val_loss improved from 1.29520 to 1.28957, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.2900 - accuracy: 0.4774 - val_loss: 1.2896 - val_accuracy: 0.4414
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2350 - accuracy: 0.4991
# Epoch 00022: val_loss improved from 1.28957 to 1.21177, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.2350 - accuracy: 0.4991 - val_loss: 1.2118 - val_accuracy: 0.5026
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2178 - accuracy: 0.5158
# Epoch 00023: val_loss did not improve from 1.21177
# 36/35 [==============================] - 38s 1s/step - loss: 1.2178 - accuracy: 0.5158 - val_loss: 1.2374 - val_accuracy: 0.4935
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1869 - accuracy: 0.5291
# Epoch 00024: val_loss did not improve from 1.21177
# 36/35 [==============================] - 39s 1s/step - loss: 1.1869 - accuracy: 0.5291 - val_loss: 1.2864 - val_accuracy: 0.4831
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2010 - accuracy: 0.5161
# Epoch 00025: val_loss did not improve from 1.21177
# 36/35 [==============================] - 38s 1s/step - loss: 1.2010 - accuracy: 0.5161 - val_loss: 1.3360 - val_accuracy: 0.4388
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1813 - accuracy: 0.5247
# Epoch 00026: val_loss improved from 1.21177 to 1.15550, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.1813 - accuracy: 0.5247 - val_loss: 1.1555 - val_accuracy: 0.5391
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1652 - accuracy: 0.5373
# Epoch 00027: val_loss did not improve from 1.15550
# 36/35 [==============================] - 39s 1s/step - loss: 1.1652 - accuracy: 0.5373 - val_loss: 1.1812 - val_accuracy: 0.5143
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1190 - accuracy: 0.5566
# Epoch 00028: val_loss did not improve from 1.15550
# 36/35 [==============================] - 40s 1s/step - loss: 1.1190 - accuracy: 0.5566 - val_loss: 1.2259 - val_accuracy: 0.5234
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1494 - accuracy: 0.5522
# Epoch 00029: val_loss did not improve from 1.15550
# 36/35 [==============================] - 39s 1s/step - loss: 1.1494 - accuracy: 0.5522 - val_loss: 1.3350 - val_accuracy: 0.4753
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1442 - accuracy: 0.5435
# Epoch 00030: val_loss did not improve from 1.15550
# 36/35 [==============================] - 40s 1s/step - loss: 1.1442 - accuracy: 0.5435 - val_loss: 1.1680 - val_accuracy: 0.5286
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0689 - accuracy: 0.5790
# Epoch 00031: val_loss improved from 1.15550 to 1.08703, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.0689 - accuracy: 0.5790 - val_loss: 1.0870 - val_accuracy: 0.5716
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1002 - accuracy: 0.5668
# Epoch 00032: val_loss did not improve from 1.08703
# 36/35 [==============================] - 40s 1s/step - loss: 1.1002 - accuracy: 0.5668 - val_loss: 1.3446 - val_accuracy: 0.4792
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0606 - accuracy: 0.5869
# Epoch 00033: val_loss did not improve from 1.08703
# 36/35 [==============================] - 39s 1s/step - loss: 1.0606 - accuracy: 0.5869 - val_loss: 1.1784 - val_accuracy: 0.5339
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0427 - accuracy: 0.5874
# Epoch 00034: val_loss did not improve from 1.08703
# 36/35 [==============================] - 40s 1s/step - loss: 1.0427 - accuracy: 0.5874 - val_loss: 1.1047 - val_accuracy: 0.5508
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0161 - accuracy: 0.5948
# Epoch 00035: val_loss did not improve from 1.08703
# 36/35 [==============================] - 38s 1s/step - loss: 1.0161 - accuracy: 0.5948 - val_loss: 1.1001 - val_accuracy: 0.5534
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0783 - accuracy: 0.5621
# Epoch 00036: val_loss improved from 1.08703 to 1.01327, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.0783 - accuracy: 0.5621 - val_loss: 1.0133 - val_accuracy: 0.6094
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0462 - accuracy: 0.5803
# Epoch 00037: val_loss did not improve from 1.01327
# 36/35 [==============================] - 37s 1s/step - loss: 1.0462 - accuracy: 0.5803 - val_loss: 1.1493 - val_accuracy: 0.5482
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0464 - accuracy: 0.5929
# Epoch 00038: val_loss improved from 1.01327 to 1.00514, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.0464 - accuracy: 0.5929 - val_loss: 1.0051 - val_accuracy: 0.6211
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9910 - accuracy: 0.6084
# Epoch 00039: val_loss did not improve from 1.00514
# 36/35 [==============================] - 38s 1s/step - loss: 0.9910 - accuracy: 0.6084 - val_loss: 1.0431 - val_accuracy: 0.5833
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0233 - accuracy: 0.5966
# Epoch 00040: val_loss improved from 1.00514 to 0.99059, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.0233 - accuracy: 0.5966 - val_loss: 0.9906 - val_accuracy: 0.6159
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9765 - accuracy: 0.6237
# Epoch 00041: val_loss improved from 0.99059 to 0.98506, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 0.9765 - accuracy: 0.6237 - val_loss: 0.9851 - val_accuracy: 0.6289
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0191 - accuracy: 0.6124
# Epoch 00042: val_loss improved from 0.98506 to 0.98458, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.0191 - accuracy: 0.6124 - val_loss: 0.9846 - val_accuracy: 0.6263
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0022 - accuracy: 0.6137
# Epoch 00043: val_loss did not improve from 0.98458
# 36/35 [==============================] - 37s 1s/step - loss: 1.0022 - accuracy: 0.6137 - val_loss: 1.2373 - val_accuracy: 0.5312
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9556 - accuracy: 0.6259
# Epoch 00044: val_loss did not improve from 0.98458
# 36/35 [==============================] - 38s 1s/step - loss: 0.9556 - accuracy: 0.6259 - val_loss: 1.0349 - val_accuracy: 0.6016
# Epoch 45/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9634 - accuracy: 0.6282
# Epoch 00045: val_loss did not improve from 0.98458
# 36/35 [==============================] - 37s 1s/step - loss: 0.9634 - accuracy: 0.6282 - val_loss: 1.0325 - val_accuracy: 0.5964
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9530 - accuracy: 0.6339
# Epoch 00046: val_loss did not improve from 0.98458
# 36/35 [==============================] - 36s 992ms/step - loss: 0.9530 - accuracy: 0.6339 - val_loss: 1.0178 - val_accuracy: 0.6146
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9814 - accuracy: 0.6229
# Epoch 00047: val_loss did not improve from 0.98458
# 36/35 [==============================] - 37s 1s/step - loss: 0.9814 - accuracy: 0.6229 - val_loss: 1.0363 - val_accuracy: 0.5977
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9213 - accuracy: 0.6484
# Epoch 00048: val_loss improved from 0.98458 to 0.88299, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 0.9213 - accuracy: 0.6484 - val_loss: 0.8830 - val_accuracy: 0.6667
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8803 - accuracy: 0.6651
# Epoch 00049: val_loss did not improve from 0.88299
# 36/35 [==============================] - 37s 1s/step - loss: 0.8803 - accuracy: 0.6651 - val_loss: 0.9718 - val_accuracy: 0.6081
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9067 - accuracy: 0.6549
# Epoch 00050: val_loss did not improve from 0.88299
# 36/35 [==============================] - 37s 1s/step - loss: 0.9067 - accuracy: 0.6549 - val_loss: 0.9659 - val_accuracy: 0.6471
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9538 - accuracy: 0.6372
# Epoch 00051: val_loss did not improve from 0.88299
# 36/35 [==============================] - 36s 1s/step - loss: 0.9538 - accuracy: 0.6372 - val_loss: 1.0734 - val_accuracy: 0.5846
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8926 - accuracy: 0.6562
# Epoch 00052: val_loss did not improve from 0.88299
# 36/35 [==============================] - 37s 1s/step - loss: 0.8926 - accuracy: 0.6562 - val_loss: 0.9291 - val_accuracy: 0.6380
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8610 - accuracy: 0.6826
# Epoch 00053: val_loss did not improve from 0.88299
# 36/35 [==============================] - 37s 1s/step - loss: 0.8610 - accuracy: 0.6826 - val_loss: 1.0737 - val_accuracy: 0.5924
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8542 - accuracy: 0.6782
# Epoch 00054: val_loss did not improve from 0.88299
# 36/35 [==============================] - 37s 1s/step - loss: 0.8542 - accuracy: 0.6782 - val_loss: 1.0187 - val_accuracy: 0.5924
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8886 - accuracy: 0.6664
# Epoch 00055: val_loss did not improve from 0.88299
# 36/35 [==============================] - 37s 1s/step - loss: 0.8886 - accuracy: 0.6664 - val_loss: 0.9708 - val_accuracy: 0.6172
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8793 - accuracy: 0.6677
# Epoch 00056: val_loss improved from 0.88299 to 0.84931, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 0.8793 - accuracy: 0.6677 - val_loss: 0.8493 - val_accuracy: 0.6823
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8382 - accuracy: 0.6839
# Epoch 00057: val_loss did not improve from 0.84931
# 36/35 [==============================] - 36s 1s/step - loss: 0.8382 - accuracy: 0.6839 - val_loss: 0.9642 - val_accuracy: 0.6406
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8782 - accuracy: 0.6632
# Epoch 00058: val_loss did not improve from 0.84931
# 36/35 [==============================] - 37s 1s/step - loss: 0.8782 - accuracy: 0.6632 - val_loss: 1.0705 - val_accuracy: 0.6003
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8542 - accuracy: 0.6793
# Epoch 00059: val_loss did not improve from 0.84931
# 36/35 [==============================] - 37s 1s/step - loss: 0.8542 - accuracy: 0.6793 - val_loss: 0.8722 - val_accuracy: 0.6576
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8248 - accuracy: 0.6866
# Epoch 00060: val_loss improved from 0.84931 to 0.84766, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 0.8248 - accuracy: 0.6866 - val_loss: 0.8477 - val_accuracy: 0.6758
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8127 - accuracy: 0.7037
# Epoch 00061: val_loss did not improve from 0.84766
# 36/35 [==============================] - 37s 1s/step - loss: 0.8127 - accuracy: 0.7037 - val_loss: 0.9515 - val_accuracy: 0.6497
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8092 - accuracy: 0.7001
# Epoch 00062: val_loss did not improve from 0.84766
# 36/35 [==============================] - 36s 1s/step - loss: 0.8092 - accuracy: 0.7001 - val_loss: 0.8989 - val_accuracy: 0.6510
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7932 - accuracy: 0.7031
# Epoch 00063: val_loss did not improve from 0.84766
# 36/35 [==============================] - 38s 1s/step - loss: 0.7932 - accuracy: 0.7031 - val_loss: 0.9037 - val_accuracy: 0.6471
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8163 - accuracy: 0.6962
# Epoch 00064: val_loss did not improve from 0.84766
# 36/35 [==============================] - 37s 1s/step - loss: 0.8163 - accuracy: 0.6962 - val_loss: 0.9245 - val_accuracy: 0.6393
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8013 - accuracy: 0.7024
# Epoch 00065: val_loss did not improve from 0.84766
# 36/35 [==============================] - 37s 1s/step - loss: 0.8013 - accuracy: 0.7024 - val_loss: 0.9461 - val_accuracy: 0.6367
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7885 - accuracy: 0.7011
# Epoch 00066: val_loss improved from 0.84766 to 0.80849, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 0.7885 - accuracy: 0.7011 - val_loss: 0.8085 - val_accuracy: 0.6953
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7626 - accuracy: 0.7142
# Epoch 00067: val_loss did not improve from 0.80849
# 36/35 [==============================] - 38s 1s/step - loss: 0.7626 - accuracy: 0.7142 - val_loss: 1.1453 - val_accuracy: 0.5703
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7798 - accuracy: 0.6989
# Epoch 00068: val_loss did not improve from 0.80849
# 36/35 [==============================] - 39s 1s/step - loss: 0.7798 - accuracy: 0.6989 - val_loss: 0.8703 - val_accuracy: 0.6732
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7581 - accuracy: 0.7169
# Epoch 00069: val_loss did not improve from 0.80849
# 36/35 [==============================] - 40s 1s/step - loss: 0.7581 - accuracy: 0.7169 - val_loss: 0.8554 - val_accuracy: 0.6823
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7701 - accuracy: 0.7227
# Epoch 00070: val_loss did not improve from 0.80849
# 36/35 [==============================] - 38s 1s/step - loss: 0.7701 - accuracy: 0.7227 - val_loss: 0.8466 - val_accuracy: 0.6823
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7290 - accuracy: 0.7235
# Epoch 00071: val_loss did not improve from 0.80849
# 36/35 [==============================] - 38s 1s/step - loss: 0.7290 - accuracy: 0.7235 - val_loss: 0.9160 - val_accuracy: 0.6576
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7294 - accuracy: 0.7234
# Epoch 00072: val_loss did not improve from 0.80849
# 36/35 [==============================] - 38s 1s/step - loss: 0.7294 - accuracy: 0.7234 - val_loss: 0.9289 - val_accuracy: 0.6510
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7395 - accuracy: 0.7252
# Epoch 00073: val_loss did not improve from 0.80849
# 36/35 [==============================] - 36s 1s/step - loss: 0.7395 - accuracy: 0.7252 - val_loss: 0.8766 - val_accuracy: 0.6641
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.7340
# Epoch 00074: val_loss did not improve from 0.80849
# 36/35 [==============================] - 36s 1s/step - loss: 0.7070 - accuracy: 0.7340 - val_loss: 0.8563 - val_accuracy: 0.6862
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.7305
# Epoch 00075: val_loss did not improve from 0.80849
# 36/35 [==============================] - 38s 1s/step - loss: 0.7209 - accuracy: 0.7305 - val_loss: 0.8138 - val_accuracy: 0.6823
# Epoch 76/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.7452
# Epoch 00076: val_loss did not improve from 0.80849
# 36/35 [==============================] - 36s 1s/step - loss: 0.7009 - accuracy: 0.7452 - val_loss: 0.8847 - val_accuracy: 0.6680
# Epoch 77/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.7629
# Epoch 00077: val_loss did not improve from 0.80849
# 36/35 [==============================] - 37s 1s/step - loss: 0.6513 - accuracy: 0.7629 - val_loss: 0.8347 - val_accuracy: 0.6875
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6480 - accuracy: 0.7561
# Epoch 00078: val_loss improved from 0.80849 to 0.79030, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 0.6480 - accuracy: 0.7561 - val_loss: 0.7903 - val_accuracy: 0.7044
# Epoch 79/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6255 - accuracy: 0.7660
# Epoch 00079: val_loss improved from 0.79030 to 0.77108, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 0.6255 - accuracy: 0.7660 - val_loss: 0.7711 - val_accuracy: 0.7122
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6384 - accuracy: 0.7673
# Epoch 00080: val_loss did not improve from 0.77108
# 36/35 [==============================] - 37s 1s/step - loss: 0.6384 - accuracy: 0.7673 - val_loss: 0.8324 - val_accuracy: 0.6966
# Epoch 81/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6386 - accuracy: 0.7643
# Epoch 00081: val_loss did not improve from 0.77108
# 36/35 [==============================] - 37s 1s/step - loss: 0.6386 - accuracy: 0.7643 - val_loss: 0.7767 - val_accuracy: 0.7188
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.7801
# Epoch 00082: val_loss did not improve from 0.77108
# 36/35 [==============================] - 36s 1s/step - loss: 0.6070 - accuracy: 0.7801 - val_loss: 0.8275 - val_accuracy: 0.7005
# Epoch 83/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6086 - accuracy: 0.7765
# Epoch 00083: val_loss did not improve from 0.77108
# 36/35 [==============================] - 39s 1s/step - loss: 0.6086 - accuracy: 0.7765 - val_loss: 0.8597 - val_accuracy: 0.6862
# Epoch 84/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6176 - accuracy: 0.7717
# Epoch 00084: val_loss did not improve from 0.77108
# 36/35 [==============================] - 37s 1s/step - loss: 0.6176 - accuracy: 0.7717 - val_loss: 0.8920 - val_accuracy: 0.7057
# Epoch 85/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5917 - accuracy: 0.7779
# Epoch 00085: val_loss did not improve from 0.77108
# 36/35 [==============================] - 40s 1s/step - loss: 0.5917 - accuracy: 0.7779 - val_loss: 0.9267 - val_accuracy: 0.6758
# Epoch 86/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.7739
# Epoch 00086: val_loss did not improve from 0.77108
# 36/35 [==============================] - 39s 1s/step - loss: 0.6031 - accuracy: 0.7739 - val_loss: 0.9144 - val_accuracy: 0.6680
# Epoch 87/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7726
# Epoch 00087: val_loss did not improve from 0.77108
# 36/35 [==============================] - 40s 1s/step - loss: 0.6214 - accuracy: 0.7726 - val_loss: 0.8172 - val_accuracy: 0.6888
# Epoch 88/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6261 - accuracy: 0.7700
# Epoch 00088: val_loss did not improve from 0.77108
# 36/35 [==============================] - 39s 1s/step - loss: 0.6261 - accuracy: 0.7700 - val_loss: 0.7928 - val_accuracy: 0.7070
# Epoch 89/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6004 - accuracy: 0.7752
# Epoch 00089: val_loss did not improve from 0.77108
# 36/35 [==============================] - 41s 1s/step - loss: 0.6004 - accuracy: 0.7752 - val_loss: 0.8168 - val_accuracy: 0.7096
# Epoch 90/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5538 - accuracy: 0.8051
# Epoch 00090: val_loss did not improve from 0.77108
# 36/35 [==============================] - 39s 1s/step - loss: 0.5538 - accuracy: 0.8051 - val_loss: 0.8265 - val_accuracy: 0.7161
# Epoch 91/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5442 - accuracy: 0.8060
# Epoch 00091: val_loss did not improve from 0.77108
# 36/35 [==============================] - 41s 1s/step - loss: 0.5442 - accuracy: 0.8060 - val_loss: 0.7839 - val_accuracy: 0.7214
# Epoch 92/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.8108
# Epoch 00092: val_loss improved from 0.77108 to 0.75372, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.5131 - accuracy: 0.8108 - val_loss: 0.7537 - val_accuracy: 0.7383
# Epoch 93/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5496 - accuracy: 0.7924
# Epoch 00093: val_loss did not improve from 0.75372
# 36/35 [==============================] - 40s 1s/step - loss: 0.5496 - accuracy: 0.7924 - val_loss: 0.7925 - val_accuracy: 0.7188
# Epoch 94/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5626 - accuracy: 0.7937
# Epoch 00094: val_loss did not improve from 0.75372
# 36/35 [==============================] - 39s 1s/step - loss: 0.5626 - accuracy: 0.7937 - val_loss: 0.9340 - val_accuracy: 0.6784
# Epoch 95/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5322 - accuracy: 0.8099
# Epoch 00095: val_loss did not improve from 0.75372
# 36/35 [==============================] - 41s 1s/step - loss: 0.5322 - accuracy: 0.8099 - val_loss: 0.7545 - val_accuracy: 0.7161
# Epoch 96/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5419 - accuracy: 0.7924
# Epoch 00096: val_loss did not improve from 0.75372
# 36/35 [==============================] - 40s 1s/step - loss: 0.5419 - accuracy: 0.7924 - val_loss: 0.8050 - val_accuracy: 0.7148
# Epoch 97/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5242 - accuracy: 0.8016
# Epoch 00097: val_loss did not improve from 0.75372
# 36/35 [==============================] - 39s 1s/step - loss: 0.5242 - accuracy: 0.8016 - val_loss: 0.8867 - val_accuracy: 0.7005
# Epoch 98/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.8042
# Epoch 00098: val_loss did not improve from 0.75372
# 36/35 [==============================] - 40s 1s/step - loss: 0.5086 - accuracy: 0.8042 - val_loss: 0.8578 - val_accuracy: 0.7161
# Epoch 99/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5271 - accuracy: 0.8047
# Epoch 00099: val_loss did not improve from 0.75372
# 36/35 [==============================] - 42s 1s/step - loss: 0.5271 - accuracy: 0.8047 - val_loss: 0.7581 - val_accuracy: 0.7240
# Epoch 100/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5031 - accuracy: 0.8155
# Epoch 00100: val_loss did not improve from 0.75372
# 36/35 [==============================] - 40s 1s/step - loss: 0.5031 - accuracy: 0.8155 - val_loss: 0.8105 - val_accuracy: 0.7279
# Epoch 101/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4961 - accuracy: 0.8143
# Epoch 00101: val_loss did not improve from 0.75372
# 36/35 [==============================] - 41s 1s/step - loss: 0.4961 - accuracy: 0.8143 - val_loss: 0.8068 - val_accuracy: 0.7214
# Epoch 102/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5088 - accuracy: 0.8126
# Epoch 00102: val_loss did not improve from 0.75372
# 36/35 [==============================] - 41s 1s/step - loss: 0.5088 - accuracy: 0.8126 - val_loss: 0.8298 - val_accuracy: 0.7109
# Epoch 103/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4819 - accuracy: 0.8231
# Epoch 00103: val_loss did not improve from 0.75372
# 36/35 [==============================] - 41s 1s/step - loss: 0.4819 - accuracy: 0.8231 - val_loss: 0.7580 - val_accuracy: 0.7383
# Epoch 104/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.8168
# Epoch 00104: val_loss improved from 0.75372 to 0.73308, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.4941 - accuracy: 0.8168 - val_loss: 0.7331 - val_accuracy: 0.7409
# Epoch 105/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4763 - accuracy: 0.8336
# Epoch 00105: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4763 - accuracy: 0.8336 - val_loss: 0.7747 - val_accuracy: 0.7305
# Epoch 106/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4999 - accuracy: 0.8200
# Epoch 00106: val_loss did not improve from 0.73308
# 36/35 [==============================] - 42s 1s/step - loss: 0.4999 - accuracy: 0.8200 - val_loss: 0.8089 - val_accuracy: 0.7083
# Epoch 107/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8351
# Epoch 00107: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4530 - accuracy: 0.8351 - val_loss: 0.8547 - val_accuracy: 0.7174
# Epoch 108/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4925 - accuracy: 0.8138
# Epoch 00108: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4925 - accuracy: 0.8138 - val_loss: 0.7464 - val_accuracy: 0.7435
# Epoch 109/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8312
# Epoch 00109: val_loss did not improve from 0.73308
# 36/35 [==============================] - 43s 1s/step - loss: 0.4668 - accuracy: 0.8312 - val_loss: 0.7998 - val_accuracy: 0.7305
# Epoch 110/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.8327
# Epoch 00110: val_loss did not improve from 0.73308
# 36/35 [==============================] - 44s 1s/step - loss: 0.4622 - accuracy: 0.8327 - val_loss: 0.8135 - val_accuracy: 0.7266
# Epoch 111/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4666 - accuracy: 0.8297
# Epoch 00111: val_loss did not improve from 0.73308
# 36/35 [==============================] - 40s 1s/step - loss: 0.4666 - accuracy: 0.8297 - val_loss: 0.8351 - val_accuracy: 0.7188
# Epoch 112/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4797 - accuracy: 0.8275
# Epoch 00112: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4797 - accuracy: 0.8275 - val_loss: 0.8201 - val_accuracy: 0.7188
# Epoch 113/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.8290
# Epoch 00113: val_loss did not improve from 0.73308
# 36/35 [==============================] - 40s 1s/step - loss: 0.4514 - accuracy: 0.8290 - val_loss: 0.7777 - val_accuracy: 0.7253
# Epoch 114/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4384 - accuracy: 0.8407
# Epoch 00114: val_loss did not improve from 0.73308
# 36/35 [==============================] - 40s 1s/step - loss: 0.4384 - accuracy: 0.8407 - val_loss: 0.9483 - val_accuracy: 0.6810
# Epoch 115/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.8310
# Epoch 00115: val_loss did not improve from 0.73308
# 36/35 [==============================] - 42s 1s/step - loss: 0.4630 - accuracy: 0.8310 - val_loss: 0.8331 - val_accuracy: 0.7201
# Epoch 116/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8411
# Epoch 00116: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4511 - accuracy: 0.8411 - val_loss: 0.9009 - val_accuracy: 0.7057
# Epoch 117/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4555 - accuracy: 0.8367
# Epoch 00117: val_loss did not improve from 0.73308
# 36/35 [==============================] - 40s 1s/step - loss: 0.4555 - accuracy: 0.8367 - val_loss: 0.8359 - val_accuracy: 0.7174
# Epoch 118/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8385
# Epoch 00118: val_loss did not improve from 0.73308
# 36/35 [==============================] - 43s 1s/step - loss: 0.4334 - accuracy: 0.8385 - val_loss: 0.8724 - val_accuracy: 0.7057
# Epoch 119/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4555 - accuracy: 0.8368
# Epoch 00119: val_loss did not improve from 0.73308
# 36/35 [==============================] - 42s 1s/step - loss: 0.4555 - accuracy: 0.8368 - val_loss: 0.7784 - val_accuracy: 0.7513
# Epoch 120/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8415
# Epoch 00120: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4530 - accuracy: 0.8415 - val_loss: 0.8128 - val_accuracy: 0.7188
# Epoch 121/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.8310
# Epoch 00121: val_loss did not improve from 0.73308
# 36/35 [==============================] - 40s 1s/step - loss: 0.4557 - accuracy: 0.8310 - val_loss: 0.7864 - val_accuracy: 0.7383
# Epoch 122/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.8437
# Epoch 00122: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4279 - accuracy: 0.8437 - val_loss: 0.7919 - val_accuracy: 0.7305
# Epoch 123/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4459 - accuracy: 0.8403
# Epoch 00123: val_loss did not improve from 0.73308
# 36/35 [==============================] - 41s 1s/step - loss: 0.4459 - accuracy: 0.8403 - val_loss: 0.8304 - val_accuracy: 0.7174
# Epoch 124/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4589 - accuracy: 0.8316
# Epoch 00124: val_loss did not improve from 0.73308
# 36/35 [==============================] - 40s 1s/step - loss: 0.4589 - accuracy: 0.8316 - val_loss: 0.7692 - val_accuracy: 0.7461

# %%
#plotting the observations
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
#Generation of image with ImageDataGenerator
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 1250 images belonging to 5 classes.

# %%
#returning accuracy
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 71.9%

# %%
list(classtolabel.keys())
# Out:
# [0, 1, 2, 3, 4]

# %%
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
