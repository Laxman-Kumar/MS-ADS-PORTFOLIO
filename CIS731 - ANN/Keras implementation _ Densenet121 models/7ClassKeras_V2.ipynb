# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the train and test folders
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

#creating test and train folders for 7 classes selected at random from the dataset
generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=7)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=7)

# %%
#creating a list to store the selected classes
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#displaying the selected classes
classtolabel
# Out:
# {0: 'tiramisu',
#  1: 'fish_and_chips',
#  2: 'pancakes',
#  3: 'sashimi',
#  4: 'chicken_quesadilla',
#  5: 'panna_cotta',
#  6: 'pulled_pork_sandwich'}

# %%
#calculating number of images in the train and test folders respectively.
#performing data augmentation on the train and test images
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 5250 images belonging to 7 classes.
# Found 1750 images belonging to 7 classes.

# %%
#Building the CNN model. adding CNN layers, Max pooling layers and Dropout layers and 1 Dense layer 
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(7, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 2.1294 - accuracy: 0.1423
# Epoch 00001: val_loss improved from inf to 2.04786, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 2.1294 - accuracy: 0.1423 - val_loss: 2.0479 - val_accuracy: 0.1354
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 2.0291 - accuracy: 0.1619
# Epoch 00002: val_loss improved from 2.04786 to 1.99614, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 2.0291 - accuracy: 0.1619 - val_loss: 1.9961 - val_accuracy: 0.1745
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9764 - accuracy: 0.2040
# Epoch 00003: val_loss improved from 1.99614 to 1.95114, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.9764 - accuracy: 0.2040 - val_loss: 1.9511 - val_accuracy: 0.2148
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9464 - accuracy: 0.2018
# Epoch 00004: val_loss improved from 1.95114 to 1.94497, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.9464 - accuracy: 0.2018 - val_loss: 1.9450 - val_accuracy: 0.2135
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9402 - accuracy: 0.2074
# Epoch 00005: val_loss improved from 1.94497 to 1.92585, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.9402 - accuracy: 0.2074 - val_loss: 1.9259 - val_accuracy: 0.2227
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9431 - accuracy: 0.2087
# Epoch 00006: val_loss improved from 1.92585 to 1.91941, saving model to model.hdf5
# 36/35 [==============================] - 36s 1s/step - loss: 1.9431 - accuracy: 0.2087 - val_loss: 1.9194 - val_accuracy: 0.2318
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9055 - accuracy: 0.2235
# Epoch 00007: val_loss improved from 1.91941 to 1.87739, saving model to model.hdf5
# 36/35 [==============================] - 35s 979ms/step - loss: 1.9055 - accuracy: 0.2235 - val_loss: 1.8774 - val_accuracy: 0.2435
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9453 - accuracy: 0.2062
# Epoch 00008: val_loss did not improve from 1.87739
# 36/35 [==============================] - 38s 1s/step - loss: 1.9453 - accuracy: 0.2062 - val_loss: 1.9340 - val_accuracy: 0.2148
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9026 - accuracy: 0.2296
# Epoch 00009: val_loss did not improve from 1.87739
# 36/35 [==============================] - 37s 1s/step - loss: 1.9026 - accuracy: 0.2296 - val_loss: 1.9740 - val_accuracy: 0.2174
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 1.9017 - accuracy: 0.2400
# Epoch 00010: val_loss did not improve from 1.87739
# 36/35 [==============================] - 36s 1s/step - loss: 1.9017 - accuracy: 0.2400 - val_loss: 1.9529 - val_accuracy: 0.2201
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8932 - accuracy: 0.2404
# Epoch 00011: val_loss improved from 1.87739 to 1.86025, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.8932 - accuracy: 0.2404 - val_loss: 1.8603 - val_accuracy: 0.2643
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8060 - accuracy: 0.3112
# Epoch 00012: val_loss improved from 1.86025 to 1.79604, saving model to model.hdf5
# 36/35 [==============================] - 37s 1s/step - loss: 1.8060 - accuracy: 0.3112 - val_loss: 1.7960 - val_accuracy: 0.3216
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8279 - accuracy: 0.2694
# Epoch 00013: val_loss did not improve from 1.79604
# 36/35 [==============================] - 37s 1s/step - loss: 1.8279 - accuracy: 0.2694 - val_loss: 1.8385 - val_accuracy: 0.2604
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 1.8105 - accuracy: 0.2747
# Epoch 00014: val_loss did not improve from 1.79604
# 36/35 [==============================] - 38s 1s/step - loss: 1.8105 - accuracy: 0.2747 - val_loss: 1.8204 - val_accuracy: 0.2839
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7680 - accuracy: 0.2939
# Epoch 00015: val_loss did not improve from 1.79604
# 36/35 [==============================] - 36s 995ms/step - loss: 1.7680 - accuracy: 0.2939 - val_loss: 2.0769 - val_accuracy: 0.1510
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7764 - accuracy: 0.2873
# Epoch 00016: val_loss did not improve from 1.79604
# 36/35 [==============================] - 38s 1s/step - loss: 1.7764 - accuracy: 0.2873 - val_loss: 1.9224 - val_accuracy: 0.2786
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7268 - accuracy: 0.3207
# Epoch 00017: val_loss improved from 1.79604 to 1.74327, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.7268 - accuracy: 0.3207 - val_loss: 1.7433 - val_accuracy: 0.3190
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7417 - accuracy: 0.2930
# Epoch 00018: val_loss did not improve from 1.74327
# 36/35 [==============================] - 36s 1s/step - loss: 1.7417 - accuracy: 0.2930 - val_loss: 1.8256 - val_accuracy: 0.2734
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6927 - accuracy: 0.3511
# Epoch 00019: val_loss did not improve from 1.74327
# 36/35 [==============================] - 38s 1s/step - loss: 1.6927 - accuracy: 0.3511 - val_loss: 1.7497 - val_accuracy: 0.3216
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6507 - accuracy: 0.3485
# Epoch 00020: val_loss improved from 1.74327 to 1.67197, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.6507 - accuracy: 0.3485 - val_loss: 1.6720 - val_accuracy: 0.3464
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6563 - accuracy: 0.3421
# Epoch 00021: val_loss did not improve from 1.67197
# 36/35 [==============================] - 37s 1s/step - loss: 1.6563 - accuracy: 0.3421 - val_loss: 1.6858 - val_accuracy: 0.3529
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6862 - accuracy: 0.3381
# Epoch 00022: val_loss improved from 1.67197 to 1.64217, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.6862 - accuracy: 0.3381 - val_loss: 1.6422 - val_accuracy: 0.3411
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6228 - accuracy: 0.3586
# Epoch 00023: val_loss improved from 1.64217 to 1.58727, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.6228 - accuracy: 0.3586 - val_loss: 1.5873 - val_accuracy: 0.3685
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5847 - accuracy: 0.3628
# Epoch 00024: val_loss improved from 1.58727 to 1.56614, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.5847 - accuracy: 0.3628 - val_loss: 1.5661 - val_accuracy: 0.3958
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5918 - accuracy: 0.3759
# Epoch 00025: val_loss did not improve from 1.56614
# 36/35 [==============================] - 38s 1s/step - loss: 1.5918 - accuracy: 0.3759 - val_loss: 1.5842 - val_accuracy: 0.3464
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5550 - accuracy: 0.3950
# Epoch 00026: val_loss improved from 1.56614 to 1.46358, saving model to model.hdf5
# 36/35 [==============================] - 38s 1s/step - loss: 1.5550 - accuracy: 0.3950 - val_loss: 1.4636 - val_accuracy: 0.4167
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 1.7285 - accuracy: 0.3078
# Epoch 00027: val_loss did not improve from 1.46358
# 36/35 [==============================] - 38s 1s/step - loss: 1.7285 - accuracy: 0.3078 - val_loss: 1.7406 - val_accuracy: 0.3359
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6123 - accuracy: 0.3787
# Epoch 00028: val_loss did not improve from 1.46358
# 36/35 [==============================] - 38s 1s/step - loss: 1.6123 - accuracy: 0.3787 - val_loss: 1.5968 - val_accuracy: 0.3594
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6103 - accuracy: 0.3671
# Epoch 00029: val_loss did not improve from 1.46358
# 36/35 [==============================] - 37s 1s/step - loss: 1.6103 - accuracy: 0.3671 - val_loss: 1.5246 - val_accuracy: 0.4245
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 1.6033 - accuracy: 0.3733
# Epoch 00030: val_loss improved from 1.46358 to 1.44730, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.6033 - accuracy: 0.3733 - val_loss: 1.4473 - val_accuracy: 0.4453
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5458 - accuracy: 0.3880
# Epoch 00031: val_loss did not improve from 1.44730
# 36/35 [==============================] - 40s 1s/step - loss: 1.5458 - accuracy: 0.3880 - val_loss: 1.5541 - val_accuracy: 0.4167
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5226 - accuracy: 0.4170
# Epoch 00032: val_loss did not improve from 1.44730
# 36/35 [==============================] - 38s 1s/step - loss: 1.5226 - accuracy: 0.4170 - val_loss: 1.5430 - val_accuracy: 0.4076
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5959 - accuracy: 0.3800
# Epoch 00033: val_loss did not improve from 1.44730
# 36/35 [==============================] - 40s 1s/step - loss: 1.5959 - accuracy: 0.3800 - val_loss: 1.5883 - val_accuracy: 0.3555
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5550 - accuracy: 0.3760
# Epoch 00034: val_loss improved from 1.44730 to 1.44653, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 1.5550 - accuracy: 0.3760 - val_loss: 1.4465 - val_accuracy: 0.4388
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4764 - accuracy: 0.4319
# Epoch 00035: val_loss did not improve from 1.44653
# 36/35 [==============================] - 39s 1s/step - loss: 1.4764 - accuracy: 0.4319 - val_loss: 1.5253 - val_accuracy: 0.3906
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4740 - accuracy: 0.4227
# Epoch 00036: val_loss improved from 1.44653 to 1.39770, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.4740 - accuracy: 0.4227 - val_loss: 1.3977 - val_accuracy: 0.4844
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4367 - accuracy: 0.4527
# Epoch 00037: val_loss did not improve from 1.39770
# 36/35 [==============================] - 41s 1s/step - loss: 1.4367 - accuracy: 0.4527 - val_loss: 1.5310 - val_accuracy: 0.3984
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4375 - accuracy: 0.4563
# Epoch 00038: val_loss did not improve from 1.39770
# 36/35 [==============================] - 39s 1s/step - loss: 1.4375 - accuracy: 0.4563 - val_loss: 1.5954 - val_accuracy: 0.3854
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4592 - accuracy: 0.4478
# Epoch 00039: val_loss did not improve from 1.39770
# 36/35 [==============================] - 39s 1s/step - loss: 1.4592 - accuracy: 0.4478 - val_loss: 1.8529 - val_accuracy: 0.3542
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 1.5008 - accuracy: 0.4123
# Epoch 00040: val_loss did not improve from 1.39770
# 36/35 [==============================] - 42s 1s/step - loss: 1.5008 - accuracy: 0.4123 - val_loss: 1.4224 - val_accuracy: 0.4635
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4839 - accuracy: 0.4242
# Epoch 00041: val_loss improved from 1.39770 to 1.38796, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.4839 - accuracy: 0.4242 - val_loss: 1.3880 - val_accuracy: 0.4674
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4615 - accuracy: 0.4414
# Epoch 00042: val_loss improved from 1.38796 to 1.35778, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 1.4615 - accuracy: 0.4414 - val_loss: 1.3578 - val_accuracy: 0.5169
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3880 - accuracy: 0.4787
# Epoch 00043: val_loss did not improve from 1.35778
# 36/35 [==============================] - 41s 1s/step - loss: 1.3880 - accuracy: 0.4787 - val_loss: 1.3956 - val_accuracy: 0.4779
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4191 - accuracy: 0.4570
# Epoch 00044: val_loss did not improve from 1.35778
# 36/35 [==============================] - 42s 1s/step - loss: 1.4191 - accuracy: 0.4570 - val_loss: 1.3797 - val_accuracy: 0.4531
# Epoch 45/200
# 35/35 [============================>.] - ETA: 0s - loss: 1.3609 - accuracy: 0.4741
# Epoch 00045: val_loss did not improve from 1.35778
# 36/35 [==============================] - 39s 1s/step - loss: 1.3603 - accuracy: 0.4746 - val_loss: 1.3823 - val_accuracy: 0.4818
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4644 - accuracy: 0.4420
# Epoch 00046: val_loss did not improve from 1.35778
# 36/35 [==============================] - 41s 1s/step - loss: 1.4644 - accuracy: 0.4420 - val_loss: 1.3749 - val_accuracy: 0.4674
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3857 - accuracy: 0.4596
# Epoch 00047: val_loss improved from 1.35778 to 1.30761, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.3857 - accuracy: 0.4596 - val_loss: 1.3076 - val_accuracy: 0.4948
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3663 - accuracy: 0.4909
# Epoch 00048: val_loss improved from 1.30761 to 1.29033, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.3663 - accuracy: 0.4909 - val_loss: 1.2903 - val_accuracy: 0.5195
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3107 - accuracy: 0.5109
# Epoch 00049: val_loss improved from 1.29033 to 1.25634, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.3107 - accuracy: 0.5109 - val_loss: 1.2563 - val_accuracy: 0.5234
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4080 - accuracy: 0.4679
# Epoch 00050: val_loss did not improve from 1.25634
# 36/35 [==============================] - 40s 1s/step - loss: 1.4080 - accuracy: 0.4679 - val_loss: 1.4202 - val_accuracy: 0.4753
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4799 - accuracy: 0.4438
# Epoch 00051: val_loss did not improve from 1.25634
# 36/35 [==============================] - 41s 1s/step - loss: 1.4799 - accuracy: 0.4438 - val_loss: 1.3272 - val_accuracy: 0.5026
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3360 - accuracy: 0.5009
# Epoch 00052: val_loss did not improve from 1.25634
# 36/35 [==============================] - 40s 1s/step - loss: 1.3360 - accuracy: 0.5009 - val_loss: 1.3656 - val_accuracy: 0.5052
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 1.4037 - accuracy: 0.4773
# Epoch 00053: val_loss did not improve from 1.25634
# 36/35 [==============================] - 41s 1s/step - loss: 1.4037 - accuracy: 0.4773 - val_loss: 1.4085 - val_accuracy: 0.4531
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3267 - accuracy: 0.5061
# Epoch 00054: val_loss did not improve from 1.25634
# 36/35 [==============================] - 42s 1s/step - loss: 1.3267 - accuracy: 0.5061 - val_loss: 1.3236 - val_accuracy: 0.5208
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3003 - accuracy: 0.5091
# Epoch 00055: val_loss did not improve from 1.25634
# 36/35 [==============================] - 40s 1s/step - loss: 1.3003 - accuracy: 0.5091 - val_loss: 1.2568 - val_accuracy: 0.5443
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2639 - accuracy: 0.5352
# Epoch 00056: val_loss improved from 1.25634 to 1.14981, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.2639 - accuracy: 0.5352 - val_loss: 1.1498 - val_accuracy: 0.5807
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2024 - accuracy: 0.5508
# Epoch 00057: val_loss did not improve from 1.14981
# 36/35 [==============================] - 42s 1s/step - loss: 1.2024 - accuracy: 0.5508 - val_loss: 1.2354 - val_accuracy: 0.5716
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2628 - accuracy: 0.5442
# Epoch 00058: val_loss did not improve from 1.14981
# 36/35 [==============================] - 41s 1s/step - loss: 1.2628 - accuracy: 0.5442 - val_loss: 1.3621 - val_accuracy: 0.4805
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 1.3692 - accuracy: 0.4800
# Epoch 00059: val_loss did not improve from 1.14981
# 36/35 [==============================] - 41s 1s/step - loss: 1.3692 - accuracy: 0.4800 - val_loss: 1.2549 - val_accuracy: 0.5365
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2971 - accuracy: 0.5091
# Epoch 00060: val_loss did not improve from 1.14981
# 36/35 [==============================] - 42s 1s/step - loss: 1.2971 - accuracy: 0.5091 - val_loss: 1.1855 - val_accuracy: 0.5495
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2222 - accuracy: 0.5512
# Epoch 00061: val_loss did not improve from 1.14981
# 36/35 [==============================] - 42s 1s/step - loss: 1.2222 - accuracy: 0.5512 - val_loss: 1.2990 - val_accuracy: 0.5117
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2588 - accuracy: 0.5410
# Epoch 00062: val_loss improved from 1.14981 to 1.13885, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 1.2588 - accuracy: 0.5410 - val_loss: 1.1388 - val_accuracy: 0.5951
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1693 - accuracy: 0.5712
# Epoch 00063: val_loss improved from 1.13885 to 1.10800, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.1693 - accuracy: 0.5712 - val_loss: 1.1080 - val_accuracy: 0.6042
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1809 - accuracy: 0.5655
# Epoch 00064: val_loss did not improve from 1.10800
# 36/35 [==============================] - 43s 1s/step - loss: 1.1809 - accuracy: 0.5655 - val_loss: 1.3941 - val_accuracy: 0.5104
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2541 - accuracy: 0.5285
# Epoch 00065: val_loss did not improve from 1.10800
# 36/35 [==============================] - 40s 1s/step - loss: 1.2541 - accuracy: 0.5285 - val_loss: 1.3295 - val_accuracy: 0.5026
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2571 - accuracy: 0.5433
# Epoch 00066: val_loss did not improve from 1.10800
# 36/35 [==============================] - 40s 1s/step - loss: 1.2571 - accuracy: 0.5433 - val_loss: 1.1386 - val_accuracy: 0.5911
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1907 - accuracy: 0.5789
# Epoch 00067: val_loss did not improve from 1.10800
# 36/35 [==============================] - 41s 1s/step - loss: 1.1907 - accuracy: 0.5789 - val_loss: 1.3708 - val_accuracy: 0.5039
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1508 - accuracy: 0.5964
# Epoch 00068: val_loss did not improve from 1.10800
# 36/35 [==============================] - 43s 1s/step - loss: 1.1508 - accuracy: 0.5964 - val_loss: 1.2327 - val_accuracy: 0.5820
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1561 - accuracy: 0.5830
# Epoch 00069: val_loss did not improve from 1.10800
# 36/35 [==============================] - 40s 1s/step - loss: 1.1561 - accuracy: 0.5830 - val_loss: 1.2219 - val_accuracy: 0.5651
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0750 - accuracy: 0.6133
# Epoch 00070: val_loss improved from 1.10800 to 1.08010, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0750 - accuracy: 0.6133 - val_loss: 1.0801 - val_accuracy: 0.6211
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1469 - accuracy: 0.5929
# Epoch 00071: val_loss improved from 1.08010 to 1.06754, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 1.1469 - accuracy: 0.5929 - val_loss: 1.0675 - val_accuracy: 0.5964
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0783 - accuracy: 0.6042
# Epoch 00072: val_loss did not improve from 1.06754
# 36/35 [==============================] - 41s 1s/step - loss: 1.0783 - accuracy: 0.6042 - val_loss: 1.3081 - val_accuracy: 0.5430
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1346 - accuracy: 0.5995
# Epoch 00073: val_loss did not improve from 1.06754
# 36/35 [==============================] - 41s 1s/step - loss: 1.1346 - accuracy: 0.5995 - val_loss: 1.0742 - val_accuracy: 0.6146
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1046 - accuracy: 0.6115
# Epoch 00074: val_loss did not improve from 1.06754
# 36/35 [==============================] - 43s 1s/step - loss: 1.1046 - accuracy: 0.6115 - val_loss: 1.3099 - val_accuracy: 0.5430
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0884 - accuracy: 0.6033
# Epoch 00075: val_loss improved from 1.06754 to 1.04106, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0884 - accuracy: 0.6033 - val_loss: 1.0411 - val_accuracy: 0.6484
# Epoch 76/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0518 - accuracy: 0.6168
# Epoch 00076: val_loss did not improve from 1.04106
# 36/35 [==============================] - 42s 1s/step - loss: 1.0518 - accuracy: 0.6168 - val_loss: 1.4127 - val_accuracy: 0.5352
# Epoch 77/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0907 - accuracy: 0.6107
# Epoch 00077: val_loss did not improve from 1.04106
# 36/35 [==============================] - 43s 1s/step - loss: 1.0907 - accuracy: 0.6107 - val_loss: 1.0912 - val_accuracy: 0.6003
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0921 - accuracy: 0.6075
# Epoch 00078: val_loss improved from 1.04106 to 0.95521, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0921 - accuracy: 0.6075 - val_loss: 0.9552 - val_accuracy: 0.6654
# Epoch 79/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1221 - accuracy: 0.6030
# Epoch 00079: val_loss did not improve from 0.95521
# 36/35 [==============================] - 40s 1s/step - loss: 1.1221 - accuracy: 0.6030 - val_loss: 1.2727 - val_accuracy: 0.5586
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0659 - accuracy: 0.6228
# Epoch 00080: val_loss did not improve from 0.95521
# 36/35 [==============================] - 42s 1s/step - loss: 1.0659 - accuracy: 0.6228 - val_loss: 1.2272 - val_accuracy: 0.5768
# Epoch 81/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0459 - accuracy: 0.6298
# Epoch 00081: val_loss did not improve from 0.95521
# 36/35 [==============================] - 41s 1s/step - loss: 1.0459 - accuracy: 0.6298 - val_loss: 1.0588 - val_accuracy: 0.6250
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1180 - accuracy: 0.6030
# Epoch 00082: val_loss did not improve from 0.95521
# 36/35 [==============================] - 41s 1s/step - loss: 1.1180 - accuracy: 0.6030 - val_loss: 1.0276 - val_accuracy: 0.6380
# Epoch 83/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0065 - accuracy: 0.6437
# Epoch 00083: val_loss did not improve from 0.95521
# 36/35 [==============================] - 42s 1s/step - loss: 1.0065 - accuracy: 0.6437 - val_loss: 1.0191 - val_accuracy: 0.6419
# Epoch 84/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0318 - accuracy: 0.6347
# Epoch 00084: val_loss did not improve from 0.95521
# 36/35 [==============================] - 42s 1s/step - loss: 1.0318 - accuracy: 0.6347 - val_loss: 1.0074 - val_accuracy: 0.6341
# Epoch 85/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0553 - accuracy: 0.6231
# Epoch 00085: val_loss did not improve from 0.95521
# 36/35 [==============================] - 41s 1s/step - loss: 1.0553 - accuracy: 0.6231 - val_loss: 0.9970 - val_accuracy: 0.6380
# Epoch 86/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0058 - accuracy: 0.6541
# Epoch 00086: val_loss did not improve from 0.95521
# 36/35 [==============================] - 43s 1s/step - loss: 1.0058 - accuracy: 0.6541 - val_loss: 0.9816 - val_accuracy: 0.6458
# Epoch 87/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9365 - accuracy: 0.6628
# Epoch 00087: val_loss improved from 0.95521 to 0.93047, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.9365 - accuracy: 0.6628 - val_loss: 0.9305 - val_accuracy: 0.6576
# Epoch 88/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9920 - accuracy: 0.6552
# Epoch 00088: val_loss did not improve from 0.93047
# 36/35 [==============================] - 41s 1s/step - loss: 0.9920 - accuracy: 0.6552 - val_loss: 1.0491 - val_accuracy: 0.6380
# Epoch 89/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9954 - accuracy: 0.6490
# Epoch 00089: val_loss did not improve from 0.93047
# 36/35 [==============================] - 42s 1s/step - loss: 0.9954 - accuracy: 0.6490 - val_loss: 0.9762 - val_accuracy: 0.6471
# Epoch 90/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0167 - accuracy: 0.6398
# Epoch 00090: val_loss did not improve from 0.93047
# 36/35 [==============================] - 41s 1s/step - loss: 1.0167 - accuracy: 0.6398 - val_loss: 0.9747 - val_accuracy: 0.6732
# Epoch 91/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9278 - accuracy: 0.6704
# Epoch 00091: val_loss did not improve from 0.93047
# 36/35 [==============================] - 41s 1s/step - loss: 0.9278 - accuracy: 0.6704 - val_loss: 0.9514 - val_accuracy: 0.6432
# Epoch 92/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9859 - accuracy: 0.6508
# Epoch 00092: val_loss did not improve from 0.93047
# 36/35 [==============================] - 41s 1s/step - loss: 0.9859 - accuracy: 0.6508 - val_loss: 1.1576 - val_accuracy: 0.5938
# Epoch 93/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2553 - accuracy: 0.5433
# Epoch 00093: val_loss did not improve from 0.93047
# 36/35 [==============================] - 40s 1s/step - loss: 1.2553 - accuracy: 0.5433 - val_loss: 1.1008 - val_accuracy: 0.6133
# Epoch 94/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0146 - accuracy: 0.6315
# Epoch 00094: val_loss did not improve from 0.93047
# 36/35 [==============================] - 43s 1s/step - loss: 1.0146 - accuracy: 0.6315 - val_loss: 0.9698 - val_accuracy: 0.6445
# Epoch 95/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0515 - accuracy: 0.6237
# Epoch 00095: val_loss did not improve from 0.93047
# 36/35 [==============================] - 42s 1s/step - loss: 1.0515 - accuracy: 0.6237 - val_loss: 0.9723 - val_accuracy: 0.6367
# Epoch 96/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9909 - accuracy: 0.6521
# Epoch 00096: val_loss did not improve from 0.93047
# 36/35 [==============================] - 42s 1s/step - loss: 0.9909 - accuracy: 0.6521 - val_loss: 0.9888 - val_accuracy: 0.6315
# Epoch 97/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9833 - accuracy: 0.6566
# Epoch 00097: val_loss did not improve from 0.93047
# 36/35 [==============================] - 41s 1s/step - loss: 0.9833 - accuracy: 0.6566 - val_loss: 1.0857 - val_accuracy: 0.6185
# Epoch 98/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9411 - accuracy: 0.6645
# Epoch 00098: val_loss improved from 0.93047 to 0.88878, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.9411 - accuracy: 0.6645 - val_loss: 0.8888 - val_accuracy: 0.6927
# Epoch 99/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8679 - accuracy: 0.6998
# Epoch 00099: val_loss did not improve from 0.88878
# 36/35 [==============================] - 41s 1s/step - loss: 0.8679 - accuracy: 0.6998 - val_loss: 0.9262 - val_accuracy: 0.6732
# Epoch 100/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8293 - accuracy: 0.7053
# Epoch 00100: val_loss did not improve from 0.88878
# 36/35 [==============================] - 41s 1s/step - loss: 0.8293 - accuracy: 0.7053 - val_loss: 0.9286 - val_accuracy: 0.6901
# Epoch 101/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8642 - accuracy: 0.6905
# Epoch 00101: val_loss did not improve from 0.88878
# 36/35 [==============================] - 43s 1s/step - loss: 0.8642 - accuracy: 0.6905 - val_loss: 1.0259 - val_accuracy: 0.6549
# Epoch 102/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8454 - accuracy: 0.7029
# Epoch 00102: val_loss improved from 0.88878 to 0.82177, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.8454 - accuracy: 0.7029 - val_loss: 0.8218 - val_accuracy: 0.6953
# Epoch 103/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8197 - accuracy: 0.7087
# Epoch 00103: val_loss did not improve from 0.82177
# 36/35 [==============================] - 41s 1s/step - loss: 0.8197 - accuracy: 0.7087 - val_loss: 0.9103 - val_accuracy: 0.6849
# Epoch 104/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8635 - accuracy: 0.6962
# Epoch 00104: val_loss did not improve from 0.82177
# 36/35 [==============================] - 41s 1s/step - loss: 0.8635 - accuracy: 0.6962 - val_loss: 0.8640 - val_accuracy: 0.6940
# Epoch 105/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8280 - accuracy: 0.7119
# Epoch 00105: val_loss did not improve from 0.82177
# 36/35 [==============================] - 40s 1s/step - loss: 0.8280 - accuracy: 0.7119 - val_loss: 0.8367 - val_accuracy: 0.7161
# Epoch 106/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8282 - accuracy: 0.7088
# Epoch 00106: val_loss improved from 0.82177 to 0.80653, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.8282 - accuracy: 0.7088 - val_loss: 0.8065 - val_accuracy: 0.7174
# Epoch 107/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.7257
# Epoch 00107: val_loss did not improve from 0.80653
# 36/35 [==============================] - 41s 1s/step - loss: 0.7986 - accuracy: 0.7257 - val_loss: 0.8570 - val_accuracy: 0.6992
# Epoch 108/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7651 - accuracy: 0.7352
# Epoch 00108: val_loss did not improve from 0.80653
# 36/35 [==============================] - 42s 1s/step - loss: 0.7651 - accuracy: 0.7352 - val_loss: 0.9358 - val_accuracy: 0.6823
# Epoch 109/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7851 - accuracy: 0.7214
# Epoch 00109: val_loss did not improve from 0.80653
# 36/35 [==============================] - 41s 1s/step - loss: 0.7851 - accuracy: 0.7214 - val_loss: 0.8572 - val_accuracy: 0.7044
# Epoch 110/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7790 - accuracy: 0.7337
# Epoch 00110: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.7790 - accuracy: 0.7337 - val_loss: 0.8953 - val_accuracy: 0.6966
# Epoch 111/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.7119
# Epoch 00111: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.8409 - accuracy: 0.7119 - val_loss: 0.8903 - val_accuracy: 0.7044
# Epoch 112/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 0.7131
# Epoch 00112: val_loss did not improve from 0.80653
# 36/35 [==============================] - 42s 1s/step - loss: 0.8120 - accuracy: 0.7131 - val_loss: 0.8723 - val_accuracy: 0.7031
# Epoch 113/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7947 - accuracy: 0.7181
# Epoch 00113: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.7947 - accuracy: 0.7181 - val_loss: 0.9023 - val_accuracy: 0.7070
# Epoch 114/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7710 - accuracy: 0.7235
# Epoch 00114: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.7710 - accuracy: 0.7235 - val_loss: 0.9556 - val_accuracy: 0.6875
# Epoch 115/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7903 - accuracy: 0.7293
# Epoch 00115: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.7903 - accuracy: 0.7293 - val_loss: 0.9009 - val_accuracy: 0.6862
# Epoch 116/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7566 - accuracy: 0.7365
# Epoch 00116: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.7566 - accuracy: 0.7365 - val_loss: 0.8813 - val_accuracy: 0.6979
# Epoch 117/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7511 - accuracy: 0.7465
# Epoch 00117: val_loss did not improve from 0.80653
# 36/35 [==============================] - 39s 1s/step - loss: 0.7511 - accuracy: 0.7465 - val_loss: 0.8903 - val_accuracy: 0.6966
# Epoch 118/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7362 - accuracy: 0.7500
# Epoch 00118: val_loss did not improve from 0.80653
# 36/35 [==============================] - 42s 1s/step - loss: 0.7362 - accuracy: 0.7500 - val_loss: 0.8595 - val_accuracy: 0.7214
# Epoch 119/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.7467
# Epoch 00119: val_loss did not improve from 0.80653
# 36/35 [==============================] - 39s 1s/step - loss: 0.7217 - accuracy: 0.7467 - val_loss: 0.8387 - val_accuracy: 0.7148
# Epoch 120/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.7552
# Epoch 00120: val_loss did not improve from 0.80653
# 36/35 [==============================] - 39s 1s/step - loss: 0.7092 - accuracy: 0.7552 - val_loss: 0.8586 - val_accuracy: 0.6966
# Epoch 121/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6832 - accuracy: 0.7665
# Epoch 00121: val_loss did not improve from 0.80653
# 36/35 [==============================] - 40s 1s/step - loss: 0.6832 - accuracy: 0.7665 - val_loss: 0.8196 - val_accuracy: 0.7305
# Epoch 122/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7171 - accuracy: 0.7487
# Epoch 00122: val_loss did not improve from 0.80653
# 36/35 [==============================] - 42s 1s/step - loss: 0.7171 - accuracy: 0.7487 - val_loss: 0.8551 - val_accuracy: 0.7344
# Epoch 123/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.7489
# Epoch 00123: val_loss improved from 0.80653 to 0.77775, saving model to model.hdf5
# 36/35 [==============================] - 39s 1s/step - loss: 0.7341 - accuracy: 0.7489 - val_loss: 0.7777 - val_accuracy: 0.7396
# Epoch 124/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7388 - accuracy: 0.7391
# Epoch 00124: val_loss did not improve from 0.77775
# 36/35 [==============================] - 41s 1s/step - loss: 0.7388 - accuracy: 0.7391 - val_loss: 0.8034 - val_accuracy: 0.7122
# Epoch 125/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7350 - accuracy: 0.7449
# Epoch 00125: val_loss did not improve from 0.77775
# 36/35 [==============================] - 41s 1s/step - loss: 0.7350 - accuracy: 0.7449 - val_loss: 1.0925 - val_accuracy: 0.6523
# Epoch 126/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7517 - accuracy: 0.7422
# Epoch 00126: val_loss did not improve from 0.77775
# 36/35 [==============================] - 42s 1s/step - loss: 0.7517 - accuracy: 0.7422 - val_loss: 0.7818 - val_accuracy: 0.7396
# Epoch 127/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7532 - accuracy: 0.7426
# Epoch 00127: val_loss did not improve from 0.77775
# 36/35 [==============================] - 40s 1s/step - loss: 0.7532 - accuracy: 0.7426 - val_loss: 0.8603 - val_accuracy: 0.7174
# Epoch 128/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.7507
# Epoch 00128: val_loss did not improve from 0.77775
# 36/35 [==============================] - 41s 1s/step - loss: 0.6869 - accuracy: 0.7507 - val_loss: 0.7941 - val_accuracy: 0.7331
# Epoch 129/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7257 - accuracy: 0.7409
# Epoch 00129: val_loss did not improve from 0.77775
# 36/35 [==============================] - 42s 1s/step - loss: 0.7257 - accuracy: 0.7409 - val_loss: 0.8801 - val_accuracy: 0.6940
# Epoch 130/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7245 - accuracy: 0.7496
# Epoch 00130: val_loss did not improve from 0.77775
# 36/35 [==============================] - 42s 1s/step - loss: 0.7245 - accuracy: 0.7496 - val_loss: 0.8641 - val_accuracy: 0.7083
# Epoch 131/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6971 - accuracy: 0.7667
# Epoch 00131: val_loss did not improve from 0.77775
# 36/35 [==============================] - 40s 1s/step - loss: 0.6971 - accuracy: 0.7667 - val_loss: 1.0893 - val_accuracy: 0.6406
# Epoch 132/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6705 - accuracy: 0.7630
# Epoch 00132: val_loss improved from 0.77775 to 0.77285, saving model to model.hdf5
# 36/35 [==============================] - 40s 1s/step - loss: 0.6705 - accuracy: 0.7630 - val_loss: 0.7729 - val_accuracy: 0.7214
# Epoch 133/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.7604
# Epoch 00133: val_loss did not improve from 0.77285
# 36/35 [==============================] - 39s 1s/step - loss: 0.6669 - accuracy: 0.7604 - val_loss: 0.9679 - val_accuracy: 0.6940
# Epoch 134/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7016 - accuracy: 0.7609
# Epoch 00134: val_loss did not improve from 0.77285
# 36/35 [==============================] - 42s 1s/step - loss: 0.7016 - accuracy: 0.7609 - val_loss: 0.8978 - val_accuracy: 0.6992
# Epoch 135/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7674
# Epoch 00135: val_loss did not improve from 0.77285
# 36/35 [==============================] - 40s 1s/step - loss: 0.6636 - accuracy: 0.7674 - val_loss: 0.8586 - val_accuracy: 0.7201
# Epoch 136/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.7708
# Epoch 00136: val_loss did not improve from 0.77285
# 36/35 [==============================] - 39s 1s/step - loss: 0.6743 - accuracy: 0.7708 - val_loss: 0.8177 - val_accuracy: 0.7227
# Epoch 137/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6741 - accuracy: 0.7604
# Epoch 00137: val_loss did not improve from 0.77285
# 36/35 [==============================] - 40s 1s/step - loss: 0.6741 - accuracy: 0.7604 - val_loss: 0.9921 - val_accuracy: 0.6680
# Epoch 138/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6629 - accuracy: 0.7630
# Epoch 00138: val_loss did not improve from 0.77285
# 36/35 [==============================] - 40s 1s/step - loss: 0.6629 - accuracy: 0.7630 - val_loss: 0.7880 - val_accuracy: 0.7266
# Epoch 139/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.7623
# Epoch 00139: val_loss did not improve from 0.77285
# 36/35 [==============================] - 38s 1s/step - loss: 0.6854 - accuracy: 0.7623 - val_loss: 0.9139 - val_accuracy: 0.6966
# Epoch 140/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.7626
# Epoch 00140: val_loss did not improve from 0.77285
# 36/35 [==============================] - 40s 1s/step - loss: 0.6682 - accuracy: 0.7626 - val_loss: 0.8463 - val_accuracy: 0.7240
# Epoch 141/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6779 - accuracy: 0.7587
# Epoch 00141: val_loss did not improve from 0.77285
# 36/35 [==============================] - 38s 1s/step - loss: 0.6779 - accuracy: 0.7587 - val_loss: 0.7817 - val_accuracy: 0.7344
# Epoch 142/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.7622
# Epoch 00142: val_loss did not improve from 0.77285
# 36/35 [==============================] - 38s 1s/step - loss: 0.6877 - accuracy: 0.7622 - val_loss: 0.9566 - val_accuracy: 0.6940
# Epoch 143/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.7630
# Epoch 00143: val_loss did not improve from 0.77285
# 36/35 [==============================] - 39s 1s/step - loss: 0.6618 - accuracy: 0.7630 - val_loss: 0.8163 - val_accuracy: 0.7396

# %%
#Plotting accuracy
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 1750 images belonging to 7 classes.

# %%
#calculating test accuracy score
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 75.0%

# %%
#labeling sequence of the 7 classes
list(classtolabel.keys())
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
#plotting confusion matrix
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
