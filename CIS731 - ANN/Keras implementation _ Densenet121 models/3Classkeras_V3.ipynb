# %%
import pandas as pd
import numpy as np
import keras
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K

import os

# %matplotlib inline
from sklearn.model_selection import train_test_split
import shutil

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

import random
from tqdm import tqdm

# %%
#Preparing the data
def generateDataBasedOnNumberOfClass(src, dst,  symlinks = False, ignore = None,count=1,nclasses=3):
    if not os.path.exists(dst):
        os.makedirs(dst)
        shutil.copystat(src, dst)
    
    random.seed(100)
    lst = os.listdir(src)
    if(count==1):
        lst = random.sample(lst,nclasses)
    if ignore:
        excl = ignore(src, lst)
        lst = [x for x in lst if x not in excl]
    
        
    for item in lst:
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        
        if symlinks and os.path.islink(s):
            if os.path.lexists(d):
                os.remove(d)
            os.symlink(os.readlink(s), d)
            try:
                st = os.lstat(s)
                mode = stat.S_IMODE(st.st_mode)
                os.lchmod(d, mode)
            except:
                pass # lchmod not available
        elif os.path.isdir(s):
            generateDataBasedOnNumberOfClass(s, d, symlinks, ignore,count+1,nclasses)
        else:
            shutil.copy2(s, d)

def generate_dir_file_map(path):
    dir_files = defaultdict(list)
    with open(path, 'r') as txt:
        files = [l.strip() for l in txt.readlines()]
        for f in files:
            dir_name, id = f.split('/')
            dir_files[dir_name].append(id + '.jpg')
    return dir_files

train_dir_files = generate_dir_file_map('../input/food41/meta/meta/train.txt')
test_dir_files = generate_dir_file_map('../input/food41/meta/meta/test.txt')

def ignore_train(d, filenames):
    subdir = d.split('/')[-1]
    to_ignore = train_dir_files[subdir]
    return to_ignore

def ignore_test(d, filenames):
    #print(d)
    subdir = d.split('/')[-1]
    to_ignore = test_dir_files[subdir]
    return to_ignore

generateDataBasedOnNumberOfClass('../input/food41/images', './test',
                                 ignore=ignore_train,count=1,nclasses=3)
generateDataBasedOnNumberOfClass('../input/food41/images', './train',
                                 ignore=ignore_test,count=1,nclasses=3)

# %%
classtolabel ={}
for i in range(0,len(os.listdir("./test"))):
    classtolabel[i]=os.listdir("./test")[i]

# %%
#listing the 3 selected classes at random
classtolabel
# Out:
# {0: 'steak', 1: 'red_velvet_cake', 2: 'ravioli'}

# %%
#performing data augmentation on train and test images
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #rescale to [0-1], add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory(
        "./train",
        target_size=(224,224),
        batch_size=64)
test_datagen = ImageDataGenerator(rescale=1/255) # just rescale to [0-1] for testing set
test_generator = test_datagen.flow_from_directory(
        "./test",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 2250 images belonging to 3 classes.
# Found 750 images belonging to 3 classes.

# %%
#preparing the model
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu', input_shape = (224,224,3), kernel_initializer='he_normal'))
model.add(Conv2D(filters = 32, kernel_size = (5,5), strides = 2, 
                 padding = 'Same', activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', 
                 activation ='relu',kernel_initializer='he_normal'))
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation = "relu",kernel_initializer='he_normal'))
model.add(Dropout(0.2))
model.add(Dense(3, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2()))

#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
#creating the model
history = model.fit_generator(train_generator,steps_per_epoch=2250/64,
                              validation_data=test_generator,validation_steps=750/64, 
                              epochs=200, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# Epoch 1/200
# 36/35 [==============================] - ETA: 0s - loss: 1.2122 - accuracy: 0.3316
# Epoch 00001: val_loss improved from inf to 1.14275, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 1.2122 - accuracy: 0.3316 - val_loss: 1.1428 - val_accuracy: 0.3320
# Epoch 2/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1379 - accuracy: 0.3698
# Epoch 00002: val_loss improved from 1.14275 to 1.13393, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 1.1379 - accuracy: 0.3698 - val_loss: 1.1339 - val_accuracy: 0.3333
# Epoch 3/200
# 36/35 [==============================] - ETA: 0s - loss: 1.1231 - accuracy: 0.3942
# Epoch 00003: val_loss improved from 1.13393 to 1.07448, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 1.1231 - accuracy: 0.3942 - val_loss: 1.0745 - val_accuracy: 0.3947
# Epoch 4/200
# 36/35 [==============================] - ETA: 0s - loss: 1.0213 - accuracy: 0.5080
# Epoch 00004: val_loss improved from 1.07448 to 0.94643, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 1.0213 - accuracy: 0.5080 - val_loss: 0.9464 - val_accuracy: 0.5560
# Epoch 5/200
# 36/35 [==============================] - ETA: 0s - loss: 0.9141 - accuracy: 0.5680
# Epoch 00005: val_loss improved from 0.94643 to 0.84178, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.9141 - accuracy: 0.5680 - val_loss: 0.8418 - val_accuracy: 0.5973
# Epoch 6/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8677 - accuracy: 0.5884
# Epoch 00006: val_loss improved from 0.84178 to 0.84169, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.8677 - accuracy: 0.5884 - val_loss: 0.8417 - val_accuracy: 0.6227
# Epoch 7/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8480 - accuracy: 0.6182
# Epoch 00007: val_loss improved from 0.84169 to 0.82175, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.8480 - accuracy: 0.6182 - val_loss: 0.8217 - val_accuracy: 0.6280
# Epoch 8/200
# 36/35 [==============================] - ETA: 0s - loss: 0.8206 - accuracy: 0.6347
# Epoch 00008: val_loss improved from 0.82175 to 0.77488, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.8206 - accuracy: 0.6347 - val_loss: 0.7749 - val_accuracy: 0.6693
# Epoch 9/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7988 - accuracy: 0.6573
# Epoch 00009: val_loss improved from 0.77488 to 0.70891, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.7988 - accuracy: 0.6573 - val_loss: 0.7089 - val_accuracy: 0.7107
# Epoch 10/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7657 - accuracy: 0.6831
# Epoch 00010: val_loss improved from 0.70891 to 0.68570, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.7657 - accuracy: 0.6831 - val_loss: 0.6857 - val_accuracy: 0.7227
# Epoch 11/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7525 - accuracy: 0.6836
# Epoch 00011: val_loss improved from 0.68570 to 0.65938, saving model to model.hdf5
# 36/35 [==============================] - 41s 1s/step - loss: 0.7525 - accuracy: 0.6836 - val_loss: 0.6594 - val_accuracy: 0.7227
# Epoch 12/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7292 - accuracy: 0.6960
# Epoch 00012: val_loss did not improve from 0.65938
# 36/35 [==============================] - 43s 1s/step - loss: 0.7292 - accuracy: 0.6960 - val_loss: 0.7088 - val_accuracy: 0.7067
# Epoch 13/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7183 - accuracy: 0.7009
# Epoch 00013: val_loss improved from 0.65938 to 0.63617, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.7183 - accuracy: 0.7009 - val_loss: 0.6362 - val_accuracy: 0.7467
# Epoch 14/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6764 - accuracy: 0.7187
# Epoch 00014: val_loss improved from 0.63617 to 0.60281, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.6764 - accuracy: 0.7187 - val_loss: 0.6028 - val_accuracy: 0.7587
# Epoch 15/200
# 36/35 [==============================] - ETA: 0s - loss: 0.7174 - accuracy: 0.6960
# Epoch 00015: val_loss did not improve from 0.60281
# 36/35 [==============================] - 43s 1s/step - loss: 0.7174 - accuracy: 0.6960 - val_loss: 0.6154 - val_accuracy: 0.7413
# Epoch 16/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.7151
# Epoch 00016: val_loss did not improve from 0.60281
# 36/35 [==============================] - 44s 1s/step - loss: 0.6941 - accuracy: 0.7151 - val_loss: 0.6190 - val_accuracy: 0.7733
# Epoch 17/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.7249
# Epoch 00017: val_loss improved from 0.60281 to 0.56937, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.6595 - accuracy: 0.7249 - val_loss: 0.5694 - val_accuracy: 0.7867
# Epoch 18/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.7382
# Epoch 00018: val_loss did not improve from 0.56937
# 36/35 [==============================] - 41s 1s/step - loss: 0.6440 - accuracy: 0.7382 - val_loss: 0.5724 - val_accuracy: 0.7747
# Epoch 19/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6045 - accuracy: 0.7547
# Epoch 00019: val_loss improved from 0.56937 to 0.55656, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.6045 - accuracy: 0.7547 - val_loss: 0.5566 - val_accuracy: 0.7720
# Epoch 20/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5934 - accuracy: 0.7662
# Epoch 00020: val_loss improved from 0.55656 to 0.55105, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.5934 - accuracy: 0.7662 - val_loss: 0.5511 - val_accuracy: 0.7800
# Epoch 21/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5638 - accuracy: 0.7804
# Epoch 00021: val_loss improved from 0.55105 to 0.49307, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.5638 - accuracy: 0.7804 - val_loss: 0.4931 - val_accuracy: 0.7893
# Epoch 22/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5910 - accuracy: 0.7764
# Epoch 00022: val_loss did not improve from 0.49307
# 36/35 [==============================] - 43s 1s/step - loss: 0.5910 - accuracy: 0.7764 - val_loss: 0.5444 - val_accuracy: 0.7947
# Epoch 23/200
# 36/35 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.7440
# Epoch 00023: val_loss did not improve from 0.49307
# 36/35 [==============================] - 43s 1s/step - loss: 0.6181 - accuracy: 0.7440 - val_loss: 0.5517 - val_accuracy: 0.7747
# Epoch 24/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5476 - accuracy: 0.7920
# Epoch 00024: val_loss did not improve from 0.49307
# 36/35 [==============================] - 43s 1s/step - loss: 0.5476 - accuracy: 0.7920 - val_loss: 0.5425 - val_accuracy: 0.7867
# Epoch 25/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5271 - accuracy: 0.7924
# Epoch 00025: val_loss did not improve from 0.49307
# 36/35 [==============================] - 43s 1s/step - loss: 0.5271 - accuracy: 0.7924 - val_loss: 0.4986 - val_accuracy: 0.8067
# Epoch 26/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.7956
# Epoch 00026: val_loss did not improve from 0.49307
# 36/35 [==============================] - 42s 1s/step - loss: 0.5298 - accuracy: 0.7956 - val_loss: 0.5018 - val_accuracy: 0.8040
# Epoch 27/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5398 - accuracy: 0.7902
# Epoch 00027: val_loss improved from 0.49307 to 0.48425, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.5398 - accuracy: 0.7902 - val_loss: 0.4843 - val_accuracy: 0.8027
# Epoch 28/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5245 - accuracy: 0.7973
# Epoch 00028: val_loss did not improve from 0.48425
# 36/35 [==============================] - 43s 1s/step - loss: 0.5245 - accuracy: 0.7973 - val_loss: 0.6006 - val_accuracy: 0.7707
# Epoch 29/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.7947
# Epoch 00029: val_loss did not improve from 0.48425
# 36/35 [==============================] - 42s 1s/step - loss: 0.5253 - accuracy: 0.7947 - val_loss: 0.5073 - val_accuracy: 0.8027
# Epoch 30/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5165 - accuracy: 0.7893
# Epoch 00030: val_loss improved from 0.48425 to 0.47176, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.5165 - accuracy: 0.7893 - val_loss: 0.4718 - val_accuracy: 0.8067
# Epoch 31/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5259 - accuracy: 0.8004
# Epoch 00031: val_loss improved from 0.47176 to 0.45281, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.5259 - accuracy: 0.8004 - val_loss: 0.4528 - val_accuracy: 0.8240
# Epoch 32/200
# 36/35 [==============================] - ETA: 0s - loss: 0.5083 - accuracy: 0.8027
# Epoch 00032: val_loss improved from 0.45281 to 0.43954, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.5083 - accuracy: 0.8027 - val_loss: 0.4395 - val_accuracy: 0.8347
# Epoch 33/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.8293
# Epoch 00033: val_loss improved from 0.43954 to 0.42392, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.4541 - accuracy: 0.8293 - val_loss: 0.4239 - val_accuracy: 0.8280
# Epoch 34/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.8133
# Epoch 00034: val_loss did not improve from 0.42392
# 36/35 [==============================] - 42s 1s/step - loss: 0.4922 - accuracy: 0.8133 - val_loss: 0.5508 - val_accuracy: 0.7893
# Epoch 35/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.8133
# Epoch 00035: val_loss improved from 0.42392 to 0.39662, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.4942 - accuracy: 0.8133 - val_loss: 0.3966 - val_accuracy: 0.8587
# Epoch 36/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4432 - accuracy: 0.8338
# Epoch 00036: val_loss improved from 0.39662 to 0.37188, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.4432 - accuracy: 0.8338 - val_loss: 0.3719 - val_accuracy: 0.8587
# Epoch 37/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4473 - accuracy: 0.8307
# Epoch 00037: val_loss did not improve from 0.37188
# 36/35 [==============================] - 42s 1s/step - loss: 0.4473 - accuracy: 0.8307 - val_loss: 0.4519 - val_accuracy: 0.8320
# Epoch 38/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.8267
# Epoch 00038: val_loss did not improve from 0.37188
# 36/35 [==============================] - 43s 1s/step - loss: 0.4647 - accuracy: 0.8267 - val_loss: 0.3922 - val_accuracy: 0.8453
# Epoch 39/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4763 - accuracy: 0.8142
# Epoch 00039: val_loss did not improve from 0.37188
# 36/35 [==============================] - 44s 1s/step - loss: 0.4763 - accuracy: 0.8142 - val_loss: 0.4667 - val_accuracy: 0.8213
# Epoch 40/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8227
# Epoch 00040: val_loss did not improve from 0.37188
# 36/35 [==============================] - 43s 1s/step - loss: 0.4668 - accuracy: 0.8227 - val_loss: 0.4548 - val_accuracy: 0.8080
# Epoch 41/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4658 - accuracy: 0.8164
# Epoch 00041: val_loss did not improve from 0.37188
# 36/35 [==============================] - 42s 1s/step - loss: 0.4658 - accuracy: 0.8164 - val_loss: 0.3956 - val_accuracy: 0.8413
# Epoch 42/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8458
# Epoch 00042: val_loss improved from 0.37188 to 0.36311, saving model to model.hdf5
# 36/35 [==============================] - 45s 1s/step - loss: 0.4077 - accuracy: 0.8458 - val_loss: 0.3631 - val_accuracy: 0.8587
# Epoch 43/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8298
# Epoch 00043: val_loss improved from 0.36311 to 0.36099, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.4391 - accuracy: 0.8298 - val_loss: 0.3610 - val_accuracy: 0.8533
# Epoch 44/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8462
# Epoch 00044: val_loss did not improve from 0.36099
# 36/35 [==============================] - 43s 1s/step - loss: 0.4090 - accuracy: 0.8462 - val_loss: 0.3852 - val_accuracy: 0.8520
# Epoch 45/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8440
# Epoch 00045: val_loss did not improve from 0.36099
# 36/35 [==============================] - 43s 1s/step - loss: 0.4221 - accuracy: 0.8440 - val_loss: 0.4184 - val_accuracy: 0.8453
# Epoch 46/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.8582
# Epoch 00046: val_loss did not improve from 0.36099
# 36/35 [==============================] - 43s 1s/step - loss: 0.3807 - accuracy: 0.8582 - val_loss: 0.3961 - val_accuracy: 0.8467
# Epoch 47/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.8462
# Epoch 00047: val_loss improved from 0.36099 to 0.34656, saving model to model.hdf5
# 36/35 [==============================] - 43s 1s/step - loss: 0.4070 - accuracy: 0.8462 - val_loss: 0.3466 - val_accuracy: 0.8600
# Epoch 48/200
# 36/35 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.8382
# Epoch 00048: val_loss did not improve from 0.34656
# 36/35 [==============================] - 43s 1s/step - loss: 0.4097 - accuracy: 0.8382 - val_loss: 0.3890 - val_accuracy: 0.8480
# Epoch 49/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3703 - accuracy: 0.8587
# Epoch 00049: val_loss improved from 0.34656 to 0.33929, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.3703 - accuracy: 0.8587 - val_loss: 0.3393 - val_accuracy: 0.8613
# Epoch 50/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3800 - accuracy: 0.8498
# Epoch 00050: val_loss did not improve from 0.33929
# 36/35 [==============================] - 44s 1s/step - loss: 0.3800 - accuracy: 0.8498 - val_loss: 0.4130 - val_accuracy: 0.8307
# Epoch 51/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3790 - accuracy: 0.8564
# Epoch 00051: val_loss did not improve from 0.33929
# 36/35 [==============================] - 44s 1s/step - loss: 0.3790 - accuracy: 0.8564 - val_loss: 0.3721 - val_accuracy: 0.8480
# Epoch 52/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.8747
# Epoch 00052: val_loss improved from 0.33929 to 0.32769, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.3541 - accuracy: 0.8747 - val_loss: 0.3277 - val_accuracy: 0.8693
# Epoch 53/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8693
# Epoch 00053: val_loss did not improve from 0.32769
# 36/35 [==============================] - 42s 1s/step - loss: 0.3520 - accuracy: 0.8693 - val_loss: 0.4333 - val_accuracy: 0.8387
# Epoch 54/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.8702
# Epoch 00054: val_loss improved from 0.32769 to 0.30311, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.3592 - accuracy: 0.8702 - val_loss: 0.3031 - val_accuracy: 0.8720
# Epoch 55/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3428 - accuracy: 0.8716
# Epoch 00055: val_loss did not improve from 0.30311
# 36/35 [==============================] - 43s 1s/step - loss: 0.3428 - accuracy: 0.8716 - val_loss: 0.3837 - val_accuracy: 0.8493
# Epoch 56/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.8667
# Epoch 00056: val_loss did not improve from 0.30311
# 36/35 [==============================] - 42s 1s/step - loss: 0.3508 - accuracy: 0.8667 - val_loss: 0.3251 - val_accuracy: 0.8760
# Epoch 57/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8822
# Epoch 00057: val_loss did not improve from 0.30311
# 36/35 [==============================] - 43s 1s/step - loss: 0.3357 - accuracy: 0.8822 - val_loss: 0.3379 - val_accuracy: 0.8680
# Epoch 58/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8764
# Epoch 00058: val_loss did not improve from 0.30311
# 36/35 [==============================] - 44s 1s/step - loss: 0.3364 - accuracy: 0.8764 - val_loss: 0.3282 - val_accuracy: 0.8627
# Epoch 59/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3276 - accuracy: 0.8804
# Epoch 00059: val_loss did not improve from 0.30311
# 36/35 [==============================] - 43s 1s/step - loss: 0.3276 - accuracy: 0.8804 - val_loss: 0.3735 - val_accuracy: 0.8587
# Epoch 60/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8671
# Epoch 00060: val_loss did not improve from 0.30311
# 36/35 [==============================] - 42s 1s/step - loss: 0.3478 - accuracy: 0.8671 - val_loss: 0.3105 - val_accuracy: 0.8733
# Epoch 61/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8804
# Epoch 00061: val_loss did not improve from 0.30311
# 36/35 [==============================] - 43s 1s/step - loss: 0.3197 - accuracy: 0.8804 - val_loss: 0.3825 - val_accuracy: 0.8533
# Epoch 62/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8764
# Epoch 00062: val_loss did not improve from 0.30311
# 36/35 [==============================] - 44s 1s/step - loss: 0.3392 - accuracy: 0.8764 - val_loss: 0.3969 - val_accuracy: 0.8493
# Epoch 63/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.8933
# Epoch 00063: val_loss did not improve from 0.30311
# 36/35 [==============================] - 44s 1s/step - loss: 0.2823 - accuracy: 0.8933 - val_loss: 0.4939 - val_accuracy: 0.8280
# Epoch 64/200
# 36/35 [==============================] - ETA: 0s - loss: 0.3184 - accuracy: 0.8813
# Epoch 00064: val_loss did not improve from 0.30311
# 36/35 [==============================] - 42s 1s/step - loss: 0.3184 - accuracy: 0.8813 - val_loss: 0.3104 - val_accuracy: 0.8867
# Epoch 65/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2773 - accuracy: 0.8987
# Epoch 00065: val_loss improved from 0.30311 to 0.28208, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.2773 - accuracy: 0.8987 - val_loss: 0.2821 - val_accuracy: 0.8920
# Epoch 66/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.8996
# Epoch 00066: val_loss did not improve from 0.28208
# 36/35 [==============================] - 44s 1s/step - loss: 0.2765 - accuracy: 0.8996 - val_loss: 0.3093 - val_accuracy: 0.8787
# Epoch 67/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.8973
# Epoch 00067: val_loss did not improve from 0.28208
# 36/35 [==============================] - 43s 1s/step - loss: 0.2715 - accuracy: 0.8973 - val_loss: 0.2837 - val_accuracy: 0.8987
# Epoch 68/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9098
# Epoch 00068: val_loss improved from 0.28208 to 0.27350, saving model to model.hdf5
# 36/35 [==============================] - 42s 1s/step - loss: 0.2427 - accuracy: 0.9098 - val_loss: 0.2735 - val_accuracy: 0.9000
# Epoch 69/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9107
# Epoch 00069: val_loss did not improve from 0.27350
# 36/35 [==============================] - 43s 1s/step - loss: 0.2379 - accuracy: 0.9107 - val_loss: 0.3171 - val_accuracy: 0.8840
# Epoch 70/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.9080
# Epoch 00070: val_loss did not improve from 0.27350
# 36/35 [==============================] - 44s 1s/step - loss: 0.2456 - accuracy: 0.9080 - val_loss: 0.2931 - val_accuracy: 0.8987
# Epoch 71/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.8982
# Epoch 00071: val_loss improved from 0.27350 to 0.26034, saving model to model.hdf5
# 36/35 [==============================] - 44s 1s/step - loss: 0.2600 - accuracy: 0.8982 - val_loss: 0.2603 - val_accuracy: 0.9080
# Epoch 72/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9098
# Epoch 00072: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.2394 - accuracy: 0.9098 - val_loss: 0.2878 - val_accuracy: 0.8893
# Epoch 73/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9102
# Epoch 00073: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.2541 - accuracy: 0.9102 - val_loss: 0.2916 - val_accuracy: 0.8987
# Epoch 74/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9204
# Epoch 00074: val_loss did not improve from 0.26034
# 36/35 [==============================] - 45s 1s/step - loss: 0.2302 - accuracy: 0.9204 - val_loss: 0.2938 - val_accuracy: 0.8960
# Epoch 75/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9129
# Epoch 00075: val_loss did not improve from 0.26034
# 36/35 [==============================] - 42s 1s/step - loss: 0.2468 - accuracy: 0.9129 - val_loss: 0.3858 - val_accuracy: 0.8520
# Epoch 76/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9151
# Epoch 00076: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.2379 - accuracy: 0.9151 - val_loss: 0.3278 - val_accuracy: 0.8880
# Epoch 77/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9120
# Epoch 00077: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.2321 - accuracy: 0.9120 - val_loss: 0.3100 - val_accuracy: 0.8920
# Epoch 78/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 0.9218
# Epoch 00078: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.2213 - accuracy: 0.9218 - val_loss: 0.3995 - val_accuracy: 0.8653
# Epoch 79/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9111
# Epoch 00079: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.2466 - accuracy: 0.9111 - val_loss: 0.2815 - val_accuracy: 0.8867
# Epoch 80/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2202 - accuracy: 0.9182
# Epoch 00080: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.2202 - accuracy: 0.9182 - val_loss: 0.3454 - val_accuracy: 0.8640
# Epoch 81/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9031
# Epoch 00081: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.2408 - accuracy: 0.9031 - val_loss: 0.3231 - val_accuracy: 0.8747
# Epoch 82/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9262
# Epoch 00082: val_loss did not improve from 0.26034
# 36/35 [==============================] - 45s 1s/step - loss: 0.1988 - accuracy: 0.9262 - val_loss: 0.2780 - val_accuracy: 0.8893
# Epoch 83/200
# 36/35 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9267
# Epoch 00083: val_loss did not improve from 0.26034
# 36/35 [==============================] - 42s 1s/step - loss: 0.2017 - accuracy: 0.9267 - val_loss: 0.3046 - val_accuracy: 0.8867
# Epoch 84/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9262
# Epoch 00084: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.1973 - accuracy: 0.9262 - val_loss: 0.3059 - val_accuracy: 0.8920
# Epoch 85/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9333
# Epoch 00085: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.1828 - accuracy: 0.9333 - val_loss: 0.2888 - val_accuracy: 0.8907
# Epoch 86/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9302
# Epoch 00086: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.1828 - accuracy: 0.9302 - val_loss: 0.3123 - val_accuracy: 0.8867
# Epoch 87/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9333
# Epoch 00087: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.1929 - accuracy: 0.9333 - val_loss: 0.3237 - val_accuracy: 0.8893
# Epoch 88/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 0.9373
# Epoch 00088: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.1803 - accuracy: 0.9373 - val_loss: 0.3126 - val_accuracy: 0.8907
# Epoch 89/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9409
# Epoch 00089: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.1686 - accuracy: 0.9409 - val_loss: 0.3212 - val_accuracy: 0.8920
# Epoch 90/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9329
# Epoch 00090: val_loss did not improve from 0.26034
# 36/35 [==============================] - 44s 1s/step - loss: 0.1817 - accuracy: 0.9329 - val_loss: 0.3172 - val_accuracy: 0.8960
# Epoch 91/200
# 36/35 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9387
# Epoch 00091: val_loss did not improve from 0.26034
# 36/35 [==============================] - 43s 1s/step - loss: 0.1716 - accuracy: 0.9387 - val_loss: 0.3228 - val_accuracy: 0.8880

# %%
#plotting the observations
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %%
#Generation of image with ImageDataGenerator
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        "./test/",
        target_size=(224,224),
        batch_size=64)
# Out:
# Found 750 images belonging to 3 classes.

# %%
#returning accuracy
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 95.3%

# %%
list(classtolabel.keys())
# Out:
# [0, 1, 2]

# %%
def plot_confusion_matrix(cm):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = list(classtolabel.keys())
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %%
fpr = dict() # false positive rate
tpr = dict() # true positive rate
roc_auc = dict() # area under roc curve
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_conf[:, i]) # roc_curve function apply to binary class only
    roc_auc[i] = auc(fpr[i], tpr[i])  # using the trapezoidal rule to get area under curve
classes = list(classtolabel.values())
def plot_roc(fpr,tpr,roc_auc):
    plt.figure(figsize=(12,8))
    plt.plot(fpr[0], tpr[0], color='C1', lw=1, label='ROC curve of '+classes[0]+'apple_pie (AUC = %0.2f)' % roc_auc[0])
    plt.plot(fpr[1], tpr[1], color='C2', lw=1, label='ROC curve of '+classes[1]+' (AUC = %0.2f)' % roc_auc[1])
    plt.plot(fpr[2], tpr[2], color='C3', lw=1, label='ROC curve of '+classes[2]+' (AUC = %0.2f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--',alpha=0.7)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)
    plt.title('Receiver Operating Characteristics Curve',fontsize=30)
    plt.legend(loc="lower right",fontsize=15)
    plt.show()

plot_roc(fpr,tpr,roc_auc)

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                #print(pred_errors[error])
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error]],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error]],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1886f2901dc0> in <module>
# ----> 1 show_wrongest_label(x_test,y_test,y_pred_conf)
#
# <ipython-input-14-811cd163323b> in show_wrongest_label(x_test, y_test, y_pred_conf)
#      40                 n += 1
#      41
# ---> 42     display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)
#
# <ipython-input-14-811cd163323b> in display_errors(errors_index, img_errors, pred_errors, obs_errors)
#      31         for row in range(nrows):
#      32             for col in range(ncols):
# ---> 33                 error = errors_index[n]
#      34                 ax[row,col].imshow((img_errors[error]))
#      35                 #print(pred_errors[error])
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
